# %% [markdown]
# # SWMAL Exercise
#
# ## Intro
#
#
# We startup by reusing parts of `01_the_machine_learning_landscape.ipynb` from GÃ©ron [GITHOML]. So we begin with what GÃ©ron says about life satisfactions vs GDP per capita.
#
# Halfway down this notebook, a list of questions for SWMAL is presented.

# %% [markdown]
# ## Chapter 1 â€“ The Machine Learning landscape
#
# _This is the code used to generate some of the figures in chapter 1._

# %% [markdown]
# ### Setup
#
# First, let's make sure this notebook works well in both python 2 and 3, import a few common modules, ensure MatplotLib plots figures inline and prepare a function to save the figures:

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "fundamentals"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("IGNORING: Saving figure", fig_id) # SWMAL: I've disabled saving of figures
    #if tight_layout:
    #    plt.tight_layout()
    #plt.savefig(path, format='png', dpi=300)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

print("OK")
# Out:
# OK

# %% [markdown]
# ### Code example 1-1
#
# This function just merges the OECD's life satisfaction data and the IMF's GDP per capita data. It's a bit too long and boring and it's not specific to Machine Learning, which is why I left it out of the book.

# %%
def prepare_country_stats(oecd_bli, gdp_per_capita):
    oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
    oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
    gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
    gdp_per_capita.set_index("Country", inplace=True)
    full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,
                                  left_index=True, right_index=True)
    full_country_stats.sort_values(by="GDP per capita", inplace=True)
    remove_indices = [0, 1, 6, 8, 33, 34, 35]
    keep_indices = list(set(range(36)) - set(remove_indices))
    return full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[keep_indices]

print("OK")
# Out:
# OK

# %% [markdown]
# The code in the book expects the data files to be located in the current directory. I just tweaked it here to fetch the files in datasets/lifesat.

# %%
import os
datapath = os.path.join("./datasets", "lifesat", "")

# NOTE: a ! prefix makes us able to run system commands..
# (command 'dir' for windows, 'ls' for Linux or Macs)
#

! dir

print("\nOK")
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 0451-3530
#
#  Directory of c:\Users\mariu\Desktop\6 semester\MAL\Opgaver\L1-opgave\O1
#
# 21/02/2022  08.11    <DIR>          .
# 21/02/2022  08.11    <DIR>          ..
# 21/02/2022  08.11    <DIR>          datasets
# 21/02/2022  08.11           370.250 intro.ipynb
#                1 File(s)        370.250 bytes
#                3 Dir(s)  116.496.310.272 bytes free
#
# OK

# %%
# Code example
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# Load the data
try:
    oecd_bli = pd.read_csv(datapath + "oecd_bli_2015.csv", thousands=',')
    gdp_per_capita = pd.read_csv(datapath + "gdp_per_capita.csv",thousands=',',delimiter='\t',
                             encoding='latin1', na_values="n/a")
except Exception as e:
    print(f"SWMAL NOTE: well, you need to have the 'datasets' dir in path, please unzip 'datasets.zip' and make sure that its included in the datapath='{datapath}' setting in the cell above..")
    raise e
    
# Prepare the data
country_stats = prepare_country_stats(oecd_bli, gdp_per_capita)
X = np.c_[country_stats["GDP per capita"]]
y = np.c_[country_stats["Life satisfaction"]]

# Visualize the data
country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
plt.show()

# Select a linear model
model = sklearn.linear_model.LinearRegression()

# Train the model
model.fit(X, y)

# Make a prediction for Cyprus
X_new = [[22587]]  # Cyprus' GDP per capita
y_pred = model.predict(X_new)
print(y_pred) # outputs [[ 5.96242338]]

print("OK")
# Out:
# [[5.96242338]]
# OK

# %% [markdown]
# ## SWMAL
#
# Now we plot the linear regression result.
#
# Just ignore all the data plotter code mumbo-jumbo here (code take dirclty from the notebook, [GITHOML])...and see the final plot.

# %%
oecd_bli = pd.read_csv(datapath + "oecd_bli_2015.csv", thousands=',')
oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
#oecd_bli.head(2)

gdp_per_capita = pd.read_csv(datapath+"gdp_per_capita.csv", thousands=',', delimiter='\t',
                             encoding='latin1', na_values="n/a")
gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
gdp_per_capita.set_index("Country", inplace=True)
#gdp_per_capita.head(2)

full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita, left_index=True, right_index=True)
full_country_stats.sort_values(by="GDP per capita", inplace=True)
#full_country_stats

remove_indices = [0, 1, 6, 8, 33, 34, 35]
keep_indices = list(set(range(36)) - set(remove_indices))

sample_data = full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[keep_indices]
#missing_data = full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[remove_indices]

sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(5,3))
plt.axis([0, 60000, 0, 10])
position_text = {
    "Hungary": (5000, 1),
    "Korea": (18000, 1.7),
    "France": (29000, 2.4),
    "Australia": (40000, 3.0),
    "United States": (52000, 3.8),
}
for country, pos_text in position_text.items():
    pos_data_x, pos_data_y = sample_data.loc[country]
    country = "U.S." if country == "United States" else country
    plt.annotate(country, xy=(pos_data_x, pos_data_y), xytext=pos_text,
            arrowprops=dict(facecolor='black', width=0.5, shrink=0.1, headwidth=5))
    plt.plot(pos_data_x, pos_data_y, "ro")
#save_fig('money_happy_scatterplot')
plt.show()

from sklearn import linear_model
lin1 = linear_model.LinearRegression()
Xsample = np.c_[sample_data["GDP per capita"]]
ysample = np.c_[sample_data["Life satisfaction"]]
lin1.fit(Xsample, ysample)

t0 = 4.8530528
t1 = 4.91154459e-05

sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(5,3))
plt.axis([0, 60000, 0, 10])
M=np.linspace(0, 60000, 1000)
plt.plot(M, t0 + t1*M, "b")
plt.text(5000, 3.1, r"$\theta_0 = 4.85$", fontsize=14, color="b")
plt.text(5000, 2.2, r"$\theta_1 = 4.91 \times 10^{-5}$", fontsize=14, color="b")
#save_fig('best_fit_model_plot')
plt.show()

print("OK")
# Out:
# OK

# %% [markdown]
# ## Ultra-brief Intro to the Fit-Predict Interface in Scikit-learn
#
# OK, the important lines in the cells above are really just
# ```python
# #Select a linear model
# model = sklearn.linear_model.LinearRegression()
#
# # Train the model
# model.fit(X, y)
#
# # Make a prediction for Cyprus
# X_new = [[22587]]  # Cyprus' GDP per capita
# y_pred = model.predict(X_new)
# print(y_pred) # outputs [[ 5.96242338]]
#
# ```
#
# What happens here is that we create  model, called LinearRegression (for now just a 100% black-box method), put in our data training $\mathbf{X}$ matrix and corresponding desired training ground thruth vector $\mathbf{y}$ (aka $\mathbf{y}_{true})$, and then train the model.
#
# After training we extract a _predicted_ $\mathbf{y}_{pred}$ vector from the model, for some input scalar $x$=22587.
#
#
# ### Supervised Training via Fit-predict
#
# The train-predict (or train-fit) process on some data can be visualized as
#
# <img src="https://itundervisning.ase.au.dk/SWMAL/L01/Figs/supervised_learning.png" alt="WARNING: could not get image from server." style="height:250px">
#
# In this figure the untrained model is a `sklearn.linear_model.LinearRegression` python object. When trained via  `model.fit()`, using some know answers for the data, $\mathbf{y}_{true}~$, it becomes a blue-boxed trained model.
#
# The trained model can be used to _predict_ values from new, yet-unseen, data, via the `model.predict()` function.
#
# In other words, how high is life-satisfaction for Cyprus' GDP=22587 USD?
#
# Just call `model.predict()` on a matrix with one single numerical element, 22587, well, not a matrix really, but a python list-of-lists, `[[22587]]`
#
# ```y_pred = model.predict([[22587]])```
#
# Apparently 5.96 the models answers!
#
# (you get used to the python built-in containers and numpy on the way..)

# %% [markdown]
# ### Qa) The $\theta$ parameters and the $R^2$ Score
#
# GÃ©ron uses some $\theta$ parameter from this linear regression model, in his examples and plots above.
#
# How do you extract the $\theta_0$ and $\theta_1$ coefficients in his life-satisfaction figure form the linear regression model, via the models python attributes?
#
# Read the documentation for the linear regressor at
#
# http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
#
# Extract the score=0.734 for the model using data (X,y) and explain what $R^2$ score measures in broad terms
#
# $$
# \begin{array}{rcll}
#     R^2 &=& 1 - u/v\\
#     u   &=& \sum (y_{true} - y_{pred}~)^2   ~~~&\small \mbox{residual sum of squares}\\
#     v   &=& \sum (y_{true} - \mu_{true}~)^2 ~~~&\small \mbox{total sum of squares}
# \end{array}
# $$
#
# with $y_{true}~$ being the true data, $y_{pred}~$ being the predicted data from the model and $\mu_{true}~$ being the true mean of the data.
#
# What are the minimum and maximum values for $R^2~$?
#
# Is it best to have a low $R^2$ score or a high $R^2$ score? This means, is $R^2$ a loss/cost function or a function that measures of fitness/goodness?
#
# NOTE$_1$: the $R^2$ is just one of many scoring functions used in ML, we will see plenty more other methods later.
#
# NOTE$_2$: there are different definitions of the $R^2$, 'coefficient of determination', in linear algebra. We stricly use the formulation above.
#
# OPTIONAL: Read the additional in-depth literature on $R^2~$:
#
# > https://en.wikipedia.org/wiki/Coefficient_of_determination

# %%
# This is to find t0 and t1 
X = lin1.intercept_
Y = lin1.coef_

print(X)
print(Y)

#Extract score with test data
test_samples = pd.read_csv(datapath + "lifesat.csv", thousands=',')

Xsample = np.c_[test_samples["GDP per capita"]]
ysample = np.c_[test_samples["Life satisfaction"]]
score = lin1.score(Xsample, ysample)

print(score) #0.734

# The highest score is 1.0, as in 100% of tests were predicted correctly.

# It is better to have a higher score, since the maximum can be 1.0, and the minimum can be negative infinity.
# The coefficient shows that the regression model fits the observed data ~73%. 
# The coefficient is a measure of fitness/goodness, since it describes its relation to a set of data. 
# A coefficient of 1.0, means that all data has been accounted for, it's a perfect fit.
# Out:
# [4.8530528]
# [[4.91154459e-05]]
# 0.734441435543703

# %% [markdown]
# ## The Merits of the Fit-Predict Interface
#
# Now comes the really fun part: all methods in Scikit-learn have this fit-predict interface, and you can easily interchange models in your code just by instantiating a new and perhaps better ML model.
#
# There are still a lot of per-model parameters to tune, but fortunately, the built-in default values provide you with a good initial guess for good model setup.
#
# Later on, you might want to go into the parameter detail trying to optimize some params (opening the lid of the black-box ML algo), but for now, we pretty much stick to the default values.
#
# Let's try to replace the linear regression now, let's test a _k-nearest neighbour algorithm_ instead (still black boxed algorithm-wise)...
#
#
# ### Qb) Using k-Nearest Neighbors
#
# Change the linear regression model to a `sklearn.neighbors.KNeighborsRegressor` with k=3 (as in [HOML:p.22,bottom]), and rerun the `fit` and `predict` using this new model.
#
# What do the k-nearest neighbours estimate for Cyprus, compared to the linear regression (it should yield=5.77)?
#
# What _score-method_ does the k-nearest model use, and is it comparable to the linear regression model?
#
# Seek out the documentation in Scikit-learn, if the scoring methods are not equal, can they be compared to each other at all then?
#
# Remember to put pointer/text from the Sckikit-learn documentation in the journal...(did you find the right kNN model etc.)

# %%
# this is our raw data set:
sample_data
# Out:
#                  GDP per capita  Life satisfaction
# Country
# Russia                 9054.914                6.0
# Turkey                 9437.372                5.6
# Hungary               12239.894                4.9
# Poland                12495.334                5.8
# Slovak Republic       15991.736                6.1
# Estonia               17288.083                5.6
# Greece                18064.288                4.8
# Portugal              19121.592                5.1
# Slovenia              20732.482                5.7
# Spain                 25864.721                6.5
# Korea                 27195.197                5.8
# Italy                 29866.581                6.0
# Japan                 32485.545                5.9
# Israel                35343.336                7.4
# New Zealand           37044.891                7.3
# France                37675.006                6.5
# Belgium               40106.632                6.9
# Germany               40996.511                7.0
# Finland               41973.988                7.4
# Canada                43331.961                7.3
# Netherlands           43603.115                7.3
# Austria               43724.031                6.9
# United Kingdom        43770.688                6.8
# Sweden                49866.266                7.2
# Iceland               50854.583                7.5
# Australia             50961.865                7.3
# Ireland               51350.744                7.0
# Denmark               52114.165                7.5
# United States         55805.204                7.2

# %%
# and this is our preprocessed data
country_stats
# Out:
#                  GDP per capita  Life satisfaction
# Country
# Russia                 9054.914                6.0
# Turkey                 9437.372                5.6
# Hungary               12239.894                4.9
# Poland                12495.334                5.8
# Slovak Republic       15991.736                6.1
# Estonia               17288.083                5.6
# Greece                18064.288                4.8
# Portugal              19121.592                5.1
# Slovenia              20732.482                5.7
# Spain                 25864.721                6.5
# Korea                 27195.197                5.8
# Italy                 29866.581                6.0
# Japan                 32485.545                5.9
# Israel                35343.336                7.4
# New Zealand           37044.891                7.3
# France                37675.006                6.5
# Belgium               40106.632                6.9
# Germany               40996.511                7.0
# Finland               41973.988                7.4
# Canada                43331.961                7.3
# Netherlands           43603.115                7.3
# Austria               43724.031                6.9
# United Kingdom        43770.688                6.8
# Sweden                49866.266                7.2
# Iceland               50854.583                7.5
# Australia             50961.865                7.3
# Ireland               51350.744                7.0
# Denmark               52114.165                7.5
# United States         55805.204                7.2

# %%
# Prepare the data
X = np.c_[country_stats["GDP per capita"]]
y = np.c_[country_stats["Life satisfaction"]]

print("X.shape=",X.shape)
print("y.shape=",y.shape)

# Visualize the data
country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
plt.show()

# Select and train a model
from sklearn.neighbors import KNeighborsRegressor
lin2 = KNeighborsRegressor(n_neighbors=3)
lin2.fit(Xsample, ysample)
cypruspred = lin2.predict([[22587]])    # Predict for Cyprus on the KNearestNeighbour model
print(cypruspred)                       # 5.76 repeating, is pretty close to the expected value.
                                        # The Linear Model was shown to predict 5.96, 
                                        # so the models did predict a little bit differently.

#Extract score with test data
test_samples = pd.read_csv(datapath + "lifesat.csv", thousands=',')

Xsample = np.c_[test_samples["GDP per capita"]]
ysample = np.c_[test_samples["Life satisfaction"]]
score = lin2.score(Xsample, ysample)

print(score) #Output is 0.85

# The two scoring functions for Linear and KNearestNeighbour are the same.
# However, since the models themselves train in different ways,
# we observe a different resulting score.
# Out:
# X.shape= (29, 1)
# y.shape= (29, 1)
# [[5.76666667]]
# 0.8525732853499179

# %% [markdown]
# ### Qc) Tuning Parameter for k-Nearest Neighbors and A Sanity Check
#
# But that not the full story. Try plotting the prediction for both models in the same graph and tune the `k_neighbor` parameter of the `KNeighborsRegressor` model.
#
# Choosing `k_neighbor=1` produces a nice `score=1`, that seems optimal...but is it really so good?
#
# Plotting the two models in a 'Life Satisfaction-vs-GDP capita' 2D plot by creating an array in the range 0 to 60000 (USD) (the `M` matrix below) and then predict the corresponding y value will shed some light to this.
#
# Now reusing the plots stubs below, try to explain why the k-nearest neighbour with `k_neighbor=1` has such a good score.
#
# Does a score=1 with `k_neighbor=1`also mean that this would be the prefered estimator for the job?
#
# Hint here is a similar plot of a KNN for a small set of different k's:
#
# <img src="https://itundervisning.ase.au.dk/SWMAL/L01/Figs/regression_with_knn.png"  alt="WARNING: could not get image from server." style="height:150px">

# %%
sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(12,7))
plt.axis([0, 60000, 0, 10])

# create an test matrix M, with the same dimensionality as X, and in the range [0;60000] 
# and a step size of your choice
m=np.linspace(0, 60000, 1000)
M=np.empty([m.shape[0],1])
M[:,0]=m

lin3 = KNeighborsRegressor(n_neighbors=1)
lin4 = KNeighborsRegressor(n_neighbors=2)
lin3.fit(Xsample, ysample)
lin4.fit(Xsample, ysample)

# from this test M data, predict the y values via the lin.reg. and k-nearest models
y_pred_lin = lin1.predict(M)
y_pred_knn = lin2.predict(M)   # ASSUMING the variable name 'knn' of your KNeighborsRegressor 
y_pred_knn2 = lin3.predict(M)
y_pred_knn3 = lin4.predict(M)   # ASSUMING the variable name 'knn' of your KNeighborsRegressor 

# use plt.plot to plot x-y into the sample_data plot..
plt.plot(m, y_pred_lin, "r")
plt.plot(m, y_pred_knn, "b")
plt.plot(m, y_pred_knn2, "g")
plt.plot(m, y_pred_knn3, "y")

# The fewer n_neighbors, the closer the model trends towards the training points
# n = 1 makes a perfect fit, but it's perfect for the training data and not necessarily all possible data that could end up being tested
# This is what is generally referred to as "Over-fitting" the train data.

# %% [markdown]
# ### Qd) Trying out a Neural Network
#
# Let us then try a Neural Network on the data, using the fit-predict interface allows us to replug a new model into our existing code.
#
# There are a number of different NN's available, let's just hook into Scikit-learns Multi-Layer Perceptron for regression, that is an 'MLPRegressor'.
#
# Now, the data-set for training the MLP is really not well scaled, so we need to tweak a lot of parameters in the MLP just to get it to produce some sensible output: with out preprocessing and scaling of the input data, `X`, the MLP is really a bad choice of model for the job since it so easily produces garbage output.
#
# Try training the `mlp` regression model below, predict the value for Cyprus, and find the `score` value for the training set...just as we did for the linear and KNN models.
#
# Can the `MLPRegressor` score function be compared with the linear and KNN-scores?

# %%
from sklearn.neural_network import MLPRegressor

# Setup MLPRegressor
mlp = MLPRegressor( hidden_layer_sizes=(10,), solver='adam', activation='relu', tol=1E-5, max_iter=100000, verbose=True)
mlp.fit(X, y.ravel())

# lets make a MLP regressor prediction and redo the plots
y_pred_mlp = mlp.predict(M) 

plt.plot(m, y_pred_lin, "r")
plt.plot(m, y_pred_knn, "b")
plt.plot(m, y_pred_mlp, "k")

print(mlp.predict([[22587]]))

#Extract score with test data
test_samples = pd.read_csv(datapath + "lifesat.csv", thousands=',')

Xsample = np.c_[test_samples["GDP per capita"]]
ysample = np.c_[test_samples["Life satisfaction"]]
score = mlp.score(Xsample, ysample)
print(score)
# The score function is identical to Lin.Reg and KNN.Reg, but as we observed previously when comparing Lin and KNN,
# we once again observe the MLP model itself differs from the other two and thus produces a different score.
# Out:
# Iteration 1, loss = 290434295.23044360
# Iteration 2, loss = 286926974.91845930
# Iteration 3, loss = 283445091.80120468
# Iteration 4, loss = 279989007.88284469
# Iteration 5, loss = 276559070.05886549
# Iteration 6, loss = 273155609.32856679
# Iteration 7, loss = 269778940.07033998
# Iteration 8, loss = 266429359.38609853
# Iteration 9, loss = 263107146.52031821
# Iteration 10, loss = 259812562.35816029
# Iteration 11, loss = 256545849.00610605
# Iteration 12, loss = 253307229.45747611
# Iteration 13, loss = 250096907.34413815
# Iteration 14, loss = 246915066.77466321
# Iteration 15, loss = 243761872.25819016
# Iteration 16, loss = 240637468.71230754
# Iteration 17, loss = 237541981.55239332
# Iteration 18, loss = 234475516.85906243
# Iteration 19, loss = 231438161.61967900
# Iteration 20, loss = 228429984.03930050
# Iteration 21, loss = 225451033.91592681
# Iteration 22, loss = 222501343.07455081
# Iteration 23, loss = 219580925.85422322
# Iteration 24, loss = 216689779.64216983
# Iteration 25, loss = 213827885.44891000
# Iteration 26, loss = 210995208.51833686
# Iteration 27, loss = 208191698.96679541
# Iteration 28, loss = 205417292.44535619
# Iteration 29, loss = 202671910.81969425
# Iteration 30, loss = 199955462.86225188
# Iteration 31, loss = 197267844.95167449
# Iteration 32, loss = 194608941.77484995
# Iteration 33, loss = 191978627.02724859
# Iteration 34, loss = 189376764.10764295
# Iteration 35, loss = 186803206.80367702
# Iteration 36, loss = 184257799.96514291
# Iteration 37, loss = 181740380.16221151
# Iteration 38, loss = 179250776.32624131
# Iteration 39, loss = 176788810.37114519
# Iteration 40, loss = 174354297.79365045
# Iteration 41, loss = 171947048.25110018
# Iteration 42, loss = 169566866.11575755
# Iteration 43, loss = 167213551.00484595
# Iteration 44, loss = 164886898.28581721
# Iteration 45, loss = 162586699.55657044
# Iteration 46, loss = 160312743.10055020
# Iteration 47, loss = 158064814.31683558
# Iteration 48, loss = 155842696.12549382
# Iteration 49, loss = 153646169.34860966
# Iteration 50, loss = 151475013.06751981
# Iteration 51, loss = 149329004.95688277
# Iteration 52, loss = 147207921.59629363
# Iteration 53, loss = 145111538.76022065
# Iteration 54, loss = 143039631.68709087
# Iteration 55, loss = 140991975.32838824
# Iteration 56, loss = 138968344.57865524
# Iteration 57, loss = 136968514.48730263
# Iteration 58, loss = 134992260.45313832
# Iteration 59, loss = 133039358.40252551
# Iteration 60, loss = 131109584.95206930
# Iteration 61, loss = 129202717.55671819
# Iteration 62, loss = 127318534.64414711
# Iteration 63, loss = 125456815.73626377
# Iteration 64, loss = 123617341.55865660
# Iteration 65, loss = 121799894.13876976
# Iteration 66, loss = 120004256.89356244
# Iteration 67, loss = 118230214.70737669
# Iteration 68, loss = 116477554.00070480
# Iteration 69, loss = 114746062.79051290
# Iteration 70, loss = 113035530.74274607
# Iteration 71, loss = 111345749.21760386
# Iteration 72, loss = 109676511.30814496
# Iteration 73, loss = 108027611.87274545
# Iteration 74, loss = 106398847.56190489
# Iteration 75, loss = 104790016.83986317
# Iteration 76, loss = 103200920.00146291
# Iteration 77, loss = 101631359.18466167
# Iteration 78, loss = 100081138.37907490
# Iteration 79, loss = 98550063.43090010
# Iteration 80, loss = 97037942.04455307
# Iteration 81, loss = 95544583.78132014
# Iteration 82, loss = 94069800.05530959
# Iteration 83, loss = 92613404.12696616
# Iteration 84, loss = 91175211.09439014
# Iteration 85, loss = 89755037.88268732
# Iteration 86, loss = 88352703.23155566
# Iteration 87, loss = 86968027.68130206
# Iteration 88, loss = 85600833.55746408
# Iteration 89, loss = 84250944.95419994
# Iteration 90, loss = 82918187.71659584
# Iteration 91, loss = 81602389.42202777
# Iteration 92, loss = 80303379.36070360
# Iteration 93, loss = 79020988.51550117
# Iteration 94, loss = 77755049.54120794
# Iteration 95, loss = 76505396.74325839
# Iteration 96, loss = 75271866.05605870
# Iteration 97, loss = 74054295.02097797
# Iteration 98, loss = 72852522.76408069
# Iteration 99, loss = 71666389.97366713
# Iteration 100, loss = 70495738.87768234
# Iteration 101, loss = 69340413.22104983
# Iteration 102, loss = 68200258.24297996
# Iteration 103, loss = 67075120.65429863
# Iteration 104, loss = 65964848.61483804
# Iteration 105, loss = 64869291.71092642
# Iteration 106, loss = 63788300.93301106
# Iteration 107, loss = 62721728.65344451
# Iteration 108, loss = 61669428.60446202
# Iteration 109, loss = 60631255.85637417
# Iteration 110, loss = 59607066.79599745
# Iteration 111, loss = 58596719.10534193
# Iteration 112, loss = 57600071.74057399
# Iteration 113, loss = 56616984.91126953
# Iteration 114, loss = 55647320.05997168
# Iteration 115, loss = 54690939.84206531
# Iteration 116, loss = 53747708.10597886
# Iteration 117, loss = 52817489.87372302
# Iteration 118, loss = 51900151.32177443
# Iteration 119, loss = 50995559.76231125
# Iteration 120, loss = 50103583.62480697
# Iteration 121, loss = 49224092.43798707
# Iteration 122, loss = 48356956.81215288
# Iteration 123, loss = 47502048.42187629
# Iteration 124, loss = 46659239.98906756
# Iteration 125, loss = 45828405.26641854
# Iteration 126, loss = 45009419.02122275
# Iteration 127, loss = 44202157.01957307
# Iteration 128, loss = 43406496.01093756
# Iteration 129, loss = 42622313.71311320
# Iteration 130, loss = 41849488.79755717
# Iteration 131, loss = 41087900.87509485
# Iteration 132, loss = 40337430.48200315
# Iteration 133, loss = 39597959.06646779
# Iteration 134, loss = 38869368.97541259
# Iteration 135, loss = 38151543.44169848
# Iteration 136, loss = 37444366.57169053
# Iteration 137, loss = 36747723.33318929
# Iteration 138, loss = 36061499.54372469
# Iteration 139, loss = 35385581.85920878
# Iteration 140, loss = 34719857.76294433
# Iteration 141, loss = 34064215.55498595
# Iteration 142, loss = 33418544.34184999
# Iteration 143, loss = 32782734.02656958
# Iteration 144, loss = 32156675.29909116
# Iteration 145, loss = 31540259.62700796
# Iteration 146, loss = 30933379.24662696
# Iteration 147, loss = 30335927.15436451
# Iteration 148, loss = 29747797.09846660
# Iteration 149, loss = 29168883.57104910
# Iteration 150, loss = 28599081.80045348
# Iteration 151, loss = 28038287.74391321
# Iteration 152, loss = 27486398.08052622
# Iteration 153, loss = 26943310.20452822
# Iteration 154, loss = 26408922.21886230
# Iteration 155, loss = 25883132.92903953
# Iteration 156, loss = 25365841.83728523
# Iteration 157, loss = 24856949.13696606
# Iteration 158, loss = 24356355.70729241
# Iteration 159, loss = 23863963.10829058
# Iteration 160, loss = 23379673.57603966
# Iteration 161, loss = 22903390.01816720
# Iteration 162, loss = 22435016.00959824
# Iteration 163, loss = 21974455.78855223
# Iteration 164, loss = 21521614.25278156
# Iteration 165, loss = 21076396.95604661
# Iteration 166, loss = 20638710.10482106
# Iteration 167, loss = 20208460.55522152
# Iteration 168, loss = 19785555.81015583
# Iteration 169, loss = 19369904.01668378
# Iteration 170, loss = 18961413.96358429
# Iteration 171, loss = 18559995.07912304
# Iteration 172, loss = 18165557.42901421
# Iteration 173, loss = 17778011.71457046
# Iteration 174, loss = 17397269.27103463
# Iteration 175, loss = 17023242.06608719
# Iteration 176, loss = 16655842.69852301
# Iteration 177, loss = 16294984.39709119
# Iteration 178, loss = 15940581.01949180
# Iteration 179, loss = 15592547.05152283
# Iteration 180, loss = 15250797.60637148
# Iteration 181, loss = 14915248.42404304
# Iteration 182, loss = 14585815.87092120
# Iteration 183, loss = 14262416.93945337
# Iteration 184, loss = 13944969.24795465
# Iteration 185, loss = 13633391.04052399
# Iteration 186, loss = 13327601.18706645
# Iteration 187, loss = 13027519.18341484
# Iteration 188, loss = 12733065.15154476
# Iteration 189, loss = 12444159.83987650
# Iteration 190, loss = 12160724.62365762
# Iteration 191, loss = 11882681.50541995
# Iteration 192, loss = 11609953.11550478
# Iteration 193, loss = 11342462.71265005
# Iteration 194, loss = 11080134.18463338
# Iteration 195, loss = 10822892.04896490
# Iteration 196, loss = 10570661.45362386
# Iteration 197, loss = 10323368.17783287
# Iteration 198, loss = 10080938.63286410
# Iteration 199, loss = 9843299.86287133
# Iteration 200, loss = 9610379.54574224
# Iteration 201, loss = 9382105.99396509
# Iteration 202, loss = 9158408.15550429
# Iteration 203, loss = 8939215.61467916
# Iteration 204, loss = 8724458.59304044
# Iteration 205, loss = 8514067.95023934
# Iteration 206, loss = 8307975.18488352
# Iteration 207, loss = 8106112.43537512
# Iteration 208, loss = 7908412.48072557
# Iteration 209, loss = 7714808.74134230
# Iteration 210, loss = 7525235.27978238
# Iteration 211, loss = 7339626.80146846
# Iteration 212, loss = 7157918.65536230
# Iteration 213, loss = 6980046.83459133
# Iteration 214, loss = 6805947.97702397
# Iteration 215, loss = 6635559.36578939
# Iteration 216, loss = 6468818.92973753
# Iteration 217, loss = 6305665.24383542
# Iteration 218, loss = 6146037.52949602
# Iteration 219, loss = 5989875.65483573
# Iteration 220, loss = 5837120.13485700
# Iteration 221, loss = 5687712.13155279
# Iteration 222, loss = 5541593.45392930
# Iteration 223, loss = 5398706.55794408
# Iteration 224, loss = 5258994.54635637
# Iteration 225, loss = 5122401.16848696
# Iteration 226, loss = 4988870.81988471
# Iteration 227, loss = 4858348.54189740
# Iteration 228, loss = 4730780.02114440
# Iteration 229, loss = 4606111.58888891
# Iteration 230, loss = 4484290.22030787
# Iteration 231, loss = 4365263.53365746
# Iteration 232, loss = 4248979.78933253
# Iteration 233, loss = 4135387.88881833
# Iteration 234, loss = 4024437.37353312
# Iteration 235, loss = 3916078.42356042
# Iteration 236, loss = 3810261.85626962
# Iteration 237, loss = 3706939.12482428
# Iteration 238, loss = 3606062.31657691
# Iteration 239, loss = 3507584.15134995
# Iteration 240, loss = 3411457.97960219
# Iteration 241, loss = 3317637.78048037
# Iteration 242, loss = 3226078.15975571
# Iteration 243, loss = 3136734.34764542
# Iteration 244, loss = 3049562.19651906
# Iteration 245, loss = 2964518.17849018
# Iteration 246, loss = 2881559.38289354
# Iteration 247, loss = 2800643.51364831
# Iteration 248, loss = 2721728.88650806
# Iteration 249, loss = 2644774.42619820
# Iteration 250, loss = 2569739.66344175
# Iteration 251, loss = 2496584.73187455
# Iteration 252, loss = 2425270.36485105
# Iteration 253, loss = 2355757.89214181
# Iteration 254, loss = 2288009.23652427
# Iteration 255, loss = 2221986.91026821
# Iteration 256, loss = 2157654.01151748
# Iteration 257, loss = 2094974.22056970
# Iteration 258, loss = 2033911.79605584
# Iteration 259, loss = 1974431.57102147
# Iteration 260, loss = 1916498.94891168
# Iteration 261, loss = 1860079.89946193
# Iteration 262, loss = 1805140.95449668
# Iteration 263, loss = 1751649.20363845
# Iteration 264, loss = 1699572.28992923
# Iteration 265, loss = 1648878.40536702
# Iteration 266, loss = 1599536.28635959
# Iteration 267, loss = 1551515.20909837
# Iteration 268, loss = 1504784.98485476
# Iteration 269, loss = 1459315.95520161
# Iteration 270, loss = 1415078.98716261
# Iteration 271, loss = 1372045.46829229
# Iteration 272, loss = 1330187.30168933
# Iteration 273, loss = 1289476.90094614
# Iteration 274, loss = 1249887.18503743
# Iteration 275, loss = 1211391.57315076
# Iteration 276, loss = 1173963.97946186
# Iteration 277, loss = 1137578.80785774
# Iteration 278, loss = 1102210.94661042
# Iteration 279, loss = 1067835.76300441
# Iteration 280, loss = 1034429.09792062
# Iteration 281, loss = 1001967.26037998
# Iteration 282, loss = 970427.02204948
# Iteration 283, loss = 939785.61171373
# Iteration 284, loss = 910020.70971492
# Iteration 285, loss = 881110.44236420
# Iteration 286, loss = 853033.37632730
# Iteration 287, loss = 825768.51298742
# Iteration 288, loss = 799295.28278824
# Iteration 289, loss = 773593.53955979
# Iteration 290, loss = 748643.55483030
# Iteration 291, loss = 724426.01212659
# Iteration 292, loss = 700922.00126584
# Iteration 293, loss = 678113.01264161
# Iteration 294, loss = 655980.93150670
# Iteration 295, loss = 634508.03225548
# Iteration 296, loss = 613676.97270847
# Iteration 297, loss = 593470.78840165
# Iteration 298, loss = 573872.88688300
# Iteration 299, loss = 554867.04201892
# Iteration 300, loss = 536437.38831278
# Iteration 301, loss = 518568.41523807
# Iteration 302, loss = 501244.96158855
# Iteration 303, loss = 484452.20984757
# Iteration 304, loss = 468175.68057883
# Iteration 305, loss = 452401.22684076
# Iteration 306, loss = 437115.02862661
# Iteration 307, loss = 422303.58733226
# Iteration 308, loss = 407953.72025383
# Iteration 309, loss = 394052.55511696
# Iteration 310, loss = 380587.52463956
# Iteration 311, loss = 367546.36112998
# Iteration 312, loss = 354917.09112219
# Iteration 313, loss = 342688.03004979
# Iteration 314, loss = 330847.77696028
# Iteration 315, loss = 319385.20927133
# Iteration 316, loss = 308289.47757040
# Iteration 317, loss = 297550.00045922
# Iteration 318, loss = 287156.45944437
# Iteration 319, loss = 277098.79387543
# Iteration 320, loss = 267367.19593172
# Iteration 321, loss = 257952.10565899
# Iteration 322, loss = 248844.20605701
# Iteration 323, loss = 240034.41821925
# Iteration 324, loss = 231513.89652550
# Iteration 325, loss = 223274.02388839
# Iteration 326, loss = 215306.40705476
# Iteration 327, loss = 207602.87196253
# Iteration 328, loss = 200155.45915390
# Iteration 329, loss = 192956.41924562
# Iteration 330, loss = 185998.20845683
# Iteration 331, loss = 179273.48419510
# Iteration 332, loss = 172775.10070123
# Iteration 333, loss = 166496.10475323
# Iteration 334, loss = 160429.73142987
# Iteration 335, loss = 154569.39993423
# Iteration 336, loss = 148908.70947748
# Iteration 337, loss = 143441.43522318
# Iteration 338, loss = 138161.52429237
# Iteration 339, loss = 133063.09182953
# Iteration 340, loss = 128140.41712955
# Iteration 341, loss = 123387.93982578
# Iteration 342, loss = 118800.25613933
# Iteration 343, loss = 114372.11518928
# Iteration 344, loss = 110098.41536419
# Iteration 345, loss = 105974.20075439
# Iteration 346, loss = 101994.65764525
# Iteration 347, loss = 98155.11107106
# Iteration 348, loss = 94451.02142945
# Iteration 349, loss = 90877.98115602
# Iteration 350, loss = 87431.71145899
# Iteration 351, loss = 84108.05911347
# Iteration 352, loss = 80902.99331520
# Iteration 353, loss = 77812.60259315
# Iteration 354, loss = 74833.09178088
# Iteration 355, loss = 71960.77904597
# Iteration 356, loss = 69192.09297731
# Iteration 357, loss = 66523.56972967
# Iteration 358, loss = 63951.85022503
# Iteration 359, loss = 61473.67741035
# Iteration 360, loss = 59085.89357102
# Iteration 361, loss = 56785.43769963
# Iteration 362, loss = 54569.34291936
# Iteration 363, loss = 52434.73396153
# Iteration 364, loss = 50378.82469664
# Iteration 365, loss = 48398.91571830
# Iteration 366, loss = 46492.39197945
# Iteration 367, loss = 44656.72048021
# Iteration 368, loss = 42889.44800671
# Iteration 369, loss = 41188.19892029
# Iteration 370, loss = 39550.67299630
# Iteration 371, loss = 37974.64331193
# Iteration 372, loss = 36457.95418232
# Iteration 373, loss = 34998.51914431
# Iteration 374, loss = 33594.31898701
# Iteration 375, loss = 32243.39982866
# Iteration 376, loss = 30943.87123895
# Iteration 377, loss = 29693.90440610
# Iteration 378, loss = 28491.73034802
# Iteration 379, loss = 27335.63816680
# Iteration 380, loss = 26223.97334588
# Iteration 381, loss = 25155.13608900
# Iteration 382, loss = 24127.57970048
# Iteration 383, loss = 23139.80900582
# Iteration 384, loss = 22190.37881216
# Iteration 385, loss = 21277.89240764
# Iteration 386, loss = 20401.00009918
# Iteration 387, loss = 19558.39778774
# Iteration 388, loss = 18748.82558053
# Iteration 389, loss = 17971.06643932
# Iteration 390, loss = 17223.94486430
# Iteration 391, loss = 16506.32561261
# Iteration 392, loss = 15817.11245098
# Iteration 393, loss = 15155.24694175
# Iteration 394, loss = 14519.70726153
# Iteration 395, loss = 13909.50705197
# Iteration 396, loss = 13323.69430174
# Iteration 397, loss = 12761.35025929
# Iteration 398, loss = 12221.58837552
# Iteration 399, loss = 11703.55327593
# Iteration 400, loss = 11206.41976136
# Iteration 401, loss = 10729.39183687
# Iteration 402, loss = 10271.70176803
# Iteration 403, loss = 9832.60916408
# Iteration 404, loss = 9411.40008723
# Iteration 405, loss = 9007.38618759
# Iteration 406, loss = 8619.90386311
# Iteration 407, loss = 8248.31344388
# Iteration 408, loss = 7891.99840035
# Iteration 409, loss = 7550.36457467
# Iteration 410, loss = 7222.83943487
# Iteration 411, loss = 6908.87135107
# Iteration 412, loss = 6607.92889331
# Iteration 413, loss = 6319.50015045
# Iteration 414, loss = 6043.09206958
# Iteration 415, loss = 5778.22981545
# Iteration 416, loss = 5524.45614935
# Iteration 417, loss = 5281.33082707
# Iteration 418, loss = 5048.43001528
# Iteration 419, loss = 4825.34572598
# Iteration 420, loss = 4611.68526848
# Iteration 421, loss = 4407.07071845
# Iteration 422, loss = 4211.13840366
# Iteration 423, loss = 4023.53840580
# Iteration 424, loss = 3843.93407814
# Iteration 425, loss = 3672.00157846
# Iteration 426, loss = 3507.42941685
# Iteration 427, loss = 3349.91801806
# Iteration 428, loss = 3199.17929789
# Iteration 429, loss = 3054.93625323
# Iteration 430, loss = 2916.92256554
# Iteration 431, loss = 2784.88221707
# Iteration 432, loss = 2658.56911979
# Iteration 433, loss = 2537.74675644
# Iteration 434, loss = 2422.18783348
# Iteration 435, loss = 2311.67394546
# Iteration 436, loss = 2205.99525065
# Iteration 437, loss = 2104.95015746
# Iteration 438, loss = 2008.34502139
# Iteration 439, loss = 1915.99385218
# Iteration 440, loss = 1827.71803087
# Iteration 441, loss = 1743.34603649
# Iteration 442, loss = 1662.71318200
# Iteration 443, loss = 1585.66135934
# Iteration 444, loss = 1512.03879319
# Iteration 445, loss = 1441.69980322
# Iteration 446, loss = 1374.50457461
# Iteration 447, loss = 1310.31893646
# Iteration 448, loss = 1249.01414804
# Iteration 449, loss = 1190.46669240
# Iteration 450, loss = 1134.55807732
# Iteration 451, loss = 1081.17464325
# Iteration 452, loss = 1030.20737799
# Iteration 453, loss = 981.55173806
# Iteration 454, loss = 935.10747635
# Iteration 455, loss = 890.77847592
# Iteration 456, loss = 848.47258987
# Iteration 457, loss = 808.10148685
# Iteration 458, loss = 769.58050225
# Iteration 459, loss = 732.82849474
# Iteration 460, loss = 697.76770800
# Iteration 461, loss = 664.32363759
# Iteration 462, loss = 632.42490262
# Iteration 463, loss = 602.00312215
# Iteration 464, loss = 572.99279616
# Iteration 465, loss = 545.33119094
# Iteration 466, loss = 518.95822871
# Iteration 467, loss = 493.81638134
# Iteration 468, loss = 469.85056810
# Iteration 469, loss = 447.00805716
# Iteration 470, loss = 425.23837086
# Iteration 471, loss = 404.49319453
# Iteration 472, loss = 384.72628879
# Iteration 473, loss = 365.89340510
# Iteration 474, loss = 347.95220461
# Iteration 475, loss = 330.86218011
# Iteration 476, loss = 314.58458088
# Iteration 477, loss = 299.08234054
# Iteration 478, loss = 284.32000763
# Iteration 479, loss = 270.26367887
# Iteration 480, loss = 256.88093502
# Iteration 481, loss = 244.14077925
# Iteration 482, loss = 232.01357787
# Iteration 483, loss = 220.47100346
# Iteration 484, loss = 209.48598017
# Iteration 485, loss = 199.03263116
# Iteration 486, loss = 189.08622820
# Iteration 487, loss = 179.62314319
# Iteration 488, loss = 170.62080160
# Iteration 489, loss = 162.05763788
# Iteration 490, loss = 153.91305248
# Iteration 491, loss = 146.16737074
# Iteration 492, loss = 138.80180337
# Iteration 493, loss = 131.79840849
# Iteration 494, loss = 125.14005531
# Iteration 495, loss = 118.81038914
# Iteration 496, loss = 112.79379797
# Iteration 497, loss = 107.07538029
# Iteration 498, loss = 101.64091432
# Iteration 499, loss = 96.47682842
# Iteration 500, loss = 91.57017278
# Iteration 501, loss = 86.90859226
# Iteration 502, loss = 82.48030033
# Iteration 503, loss = 78.27405411
# Iteration 504, loss = 74.27913046
# Iteration 505, loss = 70.48530304
# Iteration 506, loss = 66.88282033
# Iteration 507, loss = 63.46238462
# Iteration 508, loss = 60.21513180
# Iteration 509, loss = 57.13261206
# Iteration 510, loss = 54.20677144
# Iteration 511, loss = 51.42993403
# Iteration 512, loss = 48.79478507
# Iteration 513, loss = 46.29435472
# Iteration 514, loss = 43.92200244
# Iteration 515, loss = 41.67140219
# Iteration 516, loss = 39.53652816
# Iteration 517, loss = 37.51164113
# Iteration 518, loss = 35.59127543
# Iteration 519, loss = 33.77022648
# Iteration 520, loss = 32.04353886
# Iteration 521, loss = 30.40649487
# Iteration 522, loss = 28.85460361
# Iteration 523, loss = 27.38359058
# Iteration 524, loss = 25.98938766
# Iteration 525, loss = 24.66812356
# Iteration 526, loss = 23.41611472
# Iteration 527, loss = 22.22985658
# Iteration 528, loss = 21.10601525
# Iteration 529, loss = 20.04141953
# Iteration 530, loss = 19.03305331
# Iteration 531, loss = 18.07804829
# Iteration 532, loss = 17.17367705
# Iteration 533, loss = 16.31734639
# Iteration 534, loss = 15.50659103
# Iteration 535, loss = 14.73906751
# Iteration 536, loss = 14.01254846
# Iteration 537, loss = 13.32491706
# Iteration 538, loss = 12.67416175
# Iteration 539, loss = 12.05837127
# Iteration 540, loss = 11.47572978
# Iteration 541, loss = 10.92451237
# Iteration 542, loss = 10.40308060
# Iteration 543, loss = 9.90987840
# Iteration 544, loss = 9.44342808
# Iteration 545, loss = 9.00232653
# Iteration 546, loss = 8.58524158
# Iteration 547, loss = 8.19090859
# Iteration 548, loss = 7.81812717
# Iteration 549, loss = 7.46575797
# Iteration 550, loss = 7.13271980
# Iteration 551, loss = 6.81798668
# Iteration 552, loss = 6.52058518
# Iteration 553, loss = 6.23959184
# Iteration 554, loss = 5.97413066
# Iteration 555, loss = 5.72337079
# Iteration 556, loss = 5.48652428
# Iteration 557, loss = 5.26284395
# Iteration 558, loss = 5.05162134
# Iteration 559, loss = 4.85218482
# Iteration 560, loss = 4.66389772
# Iteration 561, loss = 4.48615657
# Iteration 562, loss = 4.31838945
# Iteration 563, loss = 4.16005441
# Iteration 564, loss = 4.01063793
# Iteration 565, loss = 3.86965350
# Iteration 566, loss = 3.73664027
# Iteration 567, loss = 3.61116169
# Iteration 568, loss = 3.49280435
# Iteration 569, loss = 3.38117673
# Iteration 570, loss = 3.27590814
# Iteration 571, loss = 3.17664761
# Iteration 572, loss = 3.08306289
# Iteration 573, loss = 2.99483951
# Iteration 574, loss = 2.91167983
# Iteration 575, loss = 2.83330219
# Iteration 576, loss = 2.75944007
# Iteration 577, loss = 2.68984135
# Iteration 578, loss = 2.62426747
# Iteration 579, loss = 2.56249282
# Iteration 580, loss = 2.50430401
# Iteration 581, loss = 2.44949925
# Iteration 582, loss = 2.39788773
# Iteration 583, loss = 2.34928904
# Iteration 584, loss = 2.30353264
# Iteration 585, loss = 2.26045735
# Iteration 586, loss = 2.21991080
# Iteration 587, loss = 2.18174902
# Iteration 588, loss = 2.14583598
# Iteration 589, loss = 2.11204314
# Iteration 590, loss = 2.08024909
# Iteration 591, loss = 2.05033914
# Iteration 592, loss = 2.02220498
# Iteration 593, loss = 1.99574431
# Iteration 594, loss = 1.97086057
# Iteration 595, loss = 1.94746256
# Iteration 596, loss = 1.92546421
# Iteration 597, loss = 1.90478426
# Iteration 598, loss = 1.88534605
# Iteration 599, loss = 1.86707719
# Iteration 600, loss = 1.84990944
# Iteration 601, loss = 1.83377835
# Iteration 602, loss = 1.81862319
# Iteration 603, loss = 1.80438662
# Iteration 604, loss = 1.79101460
# Iteration 605, loss = 1.77845616
# Iteration 606, loss = 1.76666324
# Iteration 607, loss = 1.75559054
# Iteration 608, loss = 1.74519535
# Iteration 609, loss = 1.73543741
# Iteration 610, loss = 1.72627878
# Iteration 611, loss = 1.71768373
# Iteration 612, loss = 1.70961858
# Iteration 613, loss = 1.70205158
# Iteration 614, loss = 1.69495287
# Iteration 615, loss = 1.68829429
# Iteration 616, loss = 1.68204933
# Iteration 617, loss = 1.67619304
# Iteration 618, loss = 1.67070191
# Iteration 619, loss = 1.66555383
# Iteration 620, loss = 1.66072797
# Iteration 621, loss = 1.65620474
# Iteration 622, loss = 1.65196570
# Iteration 623, loss = 1.64799350
# Iteration 624, loss = 1.64427181
# Iteration 625, loss = 1.64078529
# Iteration 626, loss = 1.63751949
# Iteration 627, loss = 1.63446084
# Iteration 628, loss = 1.63159656
# Iteration 629, loss = 1.62891464
# Iteration 630, loss = 1.62640381
# Iteration 631, loss = 1.62405345
# Iteration 632, loss = 1.62185359
# Iteration 633, loss = 1.61979487
# Iteration 634, loss = 1.61786847
# Iteration 635, loss = 1.61606614
# Iteration 636, loss = 1.61438011
# Iteration 637, loss = 1.61280307
# Iteration 638, loss = 1.61132817
# Iteration 639, loss = 1.60994899
# Iteration 640, loss = 1.60865948
# Iteration 641, loss = 1.60745397
# Iteration 642, loss = 1.60632715
# Iteration 643, loss = 1.60527401
# Iteration 644, loss = 1.60428986
# Iteration 645, loss = 1.60337032
# Iteration 646, loss = 1.60251126
# Iteration 647, loss = 1.60170880
# Iteration 648, loss = 1.60095933
# Iteration 649, loss = 1.60025943
# Iteration 650, loss = 1.59960591
# Iteration 651, loss = 1.59899579
# Iteration 652, loss = 1.59842626
# Iteration 653, loss = 1.59789469
# Iteration 654, loss = 1.59739862
# Iteration 655, loss = 1.59693575
# Iteration 656, loss = 1.59650390
# Iteration 657, loss = 1.59610106
# Iteration 658, loss = 1.59572533
# Iteration 659, loss = 1.59537494
# Iteration 660, loss = 1.59504821
# Iteration 661, loss = 1.59474360
# Iteration 662, loss = 1.59445965
# Iteration 663, loss = 1.59419499
# Iteration 664, loss = 1.59394834
# Iteration 665, loss = 1.59371852
# Iteration 666, loss = 1.59350440
# Iteration 667, loss = 1.59330494
# Iteration 668, loss = 1.59311916
# Iteration 669, loss = 1.59294614
# Iteration 670, loss = 1.59278504
# Iteration 671, loss = 1.59263505
# Iteration 672, loss = 1.59249543
# Iteration 673, loss = 1.59236547
# Iteration 674, loss = 1.59224453
# Iteration 675, loss = 1.59213199
# Iteration 676, loss = 1.59202729
# Iteration 677, loss = 1.59192989
# Iteration 678, loss = 1.59183929
# Iteration 679, loss = 1.59175504
# Iteration 680, loss = 1.59167670
# Iteration 681, loss = 1.59160386
# Iteration 682, loss = 1.59153615
# Iteration 683, loss = 1.59147321
# Iteration 684, loss = 1.59141472
# Iteration 685, loss = 1.59136037
# Iteration 686, loss = 1.59130986
# Iteration 687, loss = 1.59126295
# Iteration 688, loss = 1.59121937
# Iteration 689, loss = 1.59117889
# Iteration 690, loss = 1.59114130
# Iteration 691, loss = 1.59110640
# Iteration 692, loss = 1.59107399
# Iteration 693, loss = 1.59104391
# Iteration 694, loss = 1.59101598
# Iteration 695, loss = 1.59099007
# Iteration 696, loss = 1.59096602
# Iteration 697, loss = 1.59094370
# Iteration 698, loss = 1.59092299
# Iteration 699, loss = 1.59090378
# Iteration 700, loss = 1.59088596
# Iteration 701, loss = 1.59086942
# Iteration 702, loss = 1.59085409
# Iteration 703, loss = 1.59083987
# Iteration 704, loss = 1.59082668
# Iteration 705, loss = 1.59081445
# Iteration 706, loss = 1.59080311
# Iteration 707, loss = 1.59079259
# Iteration 708, loss = 1.59078284
# Iteration 709, loss = 1.59077379
# Iteration 710, loss = 1.59076541
# Iteration 711, loss = 1.59075763
# Iteration 712, loss = 1.59075042
# Iteration 713, loss = 1.59074374
# Iteration 714, loss = 1.59073754
# Iteration 715, loss = 1.59073179
# Iteration 716, loss = 1.59072646
# Iteration 717, loss = 1.59072151
# Iteration 718, loss = 1.59071692
# Training loss did not improve more than tol=0.000010 for 10 consecutive epochs. Stopping.
# [4.07671125]
# -3.674144052409418

# %% [markdown]
# ###  [OPTIONAL] Qe) Neural Network with pre-scaling
#
# Now, the neurons in neural networks normally expects input data in the range `[0;1]` or sometimes in the range `[-1;1]`, meaning that for value outside this range the you put of the neuron will saturate to it's min or max value (also typical `0` or `1`).
#
# A concrete value of `X` is, say 22.000 USD, that is far away from what the MLP expects. To af fix to the problem in Qd) is to preprocess data by scaling it down to something more sensible.
#
# Try to scale X to a range of `[0;1]`, re-train the MLP, re-plot and find the new score from the rescaled input. Any better?

# %%
normalizedX = (X-min(X))/(max(X)-min(X))
normalizedM = (M-min(X))/(max(X)-min(X))

# Setup MLPRegressor
mlp = MLPRegressor( hidden_layer_sizes=(10,), solver='adam', activation='relu', tol=1E-5, max_iter=100000, verbose=True)
mlp.fit(normalizedX, y.ravel())

# lets make a MLP regressor prediction and redo the plots
y_pred_mlp = mlp.predict(normalizedM) 

plt.plot(m, y_pred_lin, "r")
plt.plot(m, y_pred_knn, "b")
plt.plot(m, y_pred_mlp, "k")

normalizedP = (22587-min(X))/(max(X)-min(X))
print(normalizedP)
print(mlp.predict([normalizedP]))

#Extract score with test data
test_samples = pd.read_csv(datapath + "lifesat.csv", thousands=',')

Xsample = np.c_[test_samples["GDP per capita"]]
ysample = np.c_[test_samples["Life satisfaction"]]

normalizedTestX = (Xsample-min(Xsample))/(max(Xsample)-min(Xsample))

score = mlp.score(normalizedTestX, ysample)
print(score)
# Since MLP expects scaled data from 0.0 to 1.0, the data fed to the model in the previous exercise made it unable to train properly.
# This time we observe much better results, although it does not compare to Lin.Reg and KNN in this case, although we need to remember that KNN currently is overfitting to the train data.
# Out:
# Iteration 1, loss = 13.60847900
# Iteration 2, loss = 13.57146082
# Iteration 3, loss = 13.53443557
# Iteration 4, loss = 13.49739689
# Iteration 5, loss = 13.46037469
# Iteration 6, loss = 13.42334548
# Iteration 7, loss = 13.38620083
# Iteration 8, loss = 13.34900080
# Iteration 9, loss = 13.31182558
# Iteration 10, loss = 13.27465262
# Iteration 11, loss = 13.23746962
# Iteration 12, loss = 13.20027661
# Iteration 13, loss = 13.16307357
# Iteration 14, loss = 13.12590377
# Iteration 15, loss = 13.08862396
# Iteration 16, loss = 13.05133575
# Iteration 17, loss = 13.01401376
# Iteration 18, loss = 12.97660166
# Iteration 19, loss = 12.93916863
# Iteration 20, loss = 12.90181893
# Iteration 21, loss = 12.86449203
# Iteration 22, loss = 12.82716583
# Iteration 23, loss = 12.78982592
# Iteration 24, loss = 12.75247208
# Iteration 25, loss = 12.71510410
# Iteration 26, loss = 12.67772175
# Iteration 27, loss = 12.64032484
# Iteration 28, loss = 12.60298413
# Iteration 29, loss = 12.56568742
# Iteration 30, loss = 12.52838111
# Iteration 31, loss = 12.49099533
# Iteration 32, loss = 12.45354455
# Iteration 33, loss = 12.41607426
# Iteration 34, loss = 12.37858474
# Iteration 35, loss = 12.34107621
# Iteration 36, loss = 12.30346521
# Iteration 37, loss = 12.26577047
# Iteration 38, loss = 12.22799824
# Iteration 39, loss = 12.19010607
# Iteration 40, loss = 12.15217935
# Iteration 41, loss = 12.11422027
# Iteration 42, loss = 12.07608323
# Iteration 43, loss = 12.03788787
# Iteration 44, loss = 11.99965339
# Iteration 45, loss = 11.96138269
# Iteration 46, loss = 11.92307831
# Iteration 47, loss = 11.88474255
# Iteration 48, loss = 11.84637742
# Iteration 49, loss = 11.80798473
# Iteration 50, loss = 11.76956611
# Iteration 51, loss = 11.73112301
# Iteration 52, loss = 11.69265673
# Iteration 53, loss = 11.65416845
# Iteration 54, loss = 11.61565922
# Iteration 55, loss = 11.57713003
# Iteration 56, loss = 11.53858173
# Iteration 57, loss = 11.49992008
# Iteration 58, loss = 11.46119726
# Iteration 59, loss = 11.42246278
# Iteration 60, loss = 11.38373116
# Iteration 61, loss = 11.34497810
# Iteration 62, loss = 11.30620474
# Iteration 63, loss = 11.26741212
# Iteration 64, loss = 11.22860121
# Iteration 65, loss = 11.18977656
# Iteration 66, loss = 11.15094328
# Iteration 67, loss = 11.11209409
# Iteration 68, loss = 11.07321229
# Iteration 69, loss = 11.03429630
# Iteration 70, loss = 10.99536269
# Iteration 71, loss = 10.95641603
# Iteration 72, loss = 10.91748601
# Iteration 73, loss = 10.87858536
# Iteration 74, loss = 10.83967471
# Iteration 75, loss = 10.80075421
# Iteration 76, loss = 10.76182405
# Iteration 77, loss = 10.72288441
# Iteration 78, loss = 10.68393551
# Iteration 79, loss = 10.64490218
# Iteration 80, loss = 10.60583519
# Iteration 81, loss = 10.56675250
# Iteration 82, loss = 10.52765526
# Iteration 83, loss = 10.48852600
# Iteration 84, loss = 10.44930570
# Iteration 85, loss = 10.41008000
# Iteration 86, loss = 10.37077691
# Iteration 87, loss = 10.33145839
# Iteration 88, loss = 10.29213449
# Iteration 89, loss = 10.25279555
# Iteration 90, loss = 10.21344315
# Iteration 91, loss = 10.17403415
# Iteration 92, loss = 10.13456797
# Iteration 93, loss = 10.09509699
# Iteration 94, loss = 10.05561246
# Iteration 95, loss = 10.01614868
# Iteration 96, loss = 9.97671763
# Iteration 97, loss = 9.93728213
# Iteration 98, loss = 9.89784306
# Iteration 99, loss = 9.85842435
# Iteration 100, loss = 9.81896405
# Iteration 101, loss = 9.77942036
# Iteration 102, loss = 9.73986793
# Iteration 103, loss = 9.70030848
# Iteration 104, loss = 9.66074362
# Iteration 105, loss = 9.62123627
# Iteration 106, loss = 9.58175121
# Iteration 107, loss = 9.54226967
# Iteration 108, loss = 9.50279232
# Iteration 109, loss = 9.46328948
# Iteration 110, loss = 9.42368103
# Iteration 111, loss = 9.38406835
# Iteration 112, loss = 9.34445335
# Iteration 113, loss = 9.30483780
# Iteration 114, loss = 9.26522338
# Iteration 115, loss = 9.22561164
# Iteration 116, loss = 9.18600408
# Iteration 117, loss = 9.14640209
# Iteration 118, loss = 9.10680703
# Iteration 119, loss = 9.06722017
# Iteration 120, loss = 9.02764273
# Iteration 121, loss = 8.98807589
# Iteration 122, loss = 8.94852079
# Iteration 123, loss = 8.90901613
# Iteration 124, loss = 8.86953993
# Iteration 125, loss = 8.83011475
# Iteration 126, loss = 8.79065454
# Iteration 127, loss = 8.75117206
# Iteration 128, loss = 8.71167371
# Iteration 129, loss = 8.67213834
# Iteration 130, loss = 8.63261308
# Iteration 131, loss = 8.59309993
# Iteration 132, loss = 8.55360076
# Iteration 133, loss = 8.51411735
# Iteration 134, loss = 8.47465136
# Iteration 135, loss = 8.43521473
# Iteration 136, loss = 8.39582248
# Iteration 137, loss = 8.35645428
# Iteration 138, loss = 8.31701293
# Iteration 139, loss = 8.27756432
# Iteration 140, loss = 8.23813317
# Iteration 141, loss = 8.19872167
# Iteration 142, loss = 8.15933187
# Iteration 143, loss = 8.11997885
# Iteration 144, loss = 8.08066960
# Iteration 145, loss = 8.04138946
# Iteration 146, loss = 8.00213981
# Iteration 147, loss = 7.96292199
# Iteration 148, loss = 7.92373730
# Iteration 149, loss = 7.88458698
# Iteration 150, loss = 7.84547224
# Iteration 151, loss = 7.80637339
# Iteration 152, loss = 7.76726356
# Iteration 153, loss = 7.72807311
# Iteration 154, loss = 7.68887339
# Iteration 155, loss = 7.64959285
# Iteration 156, loss = 7.61033487
# Iteration 157, loss = 7.57112197
# Iteration 158, loss = 7.53195549
# Iteration 159, loss = 7.49283094
# Iteration 160, loss = 7.45374061
# Iteration 161, loss = 7.41468702
# Iteration 162, loss = 7.37567247
# Iteration 163, loss = 7.33669914
# Iteration 164, loss = 7.29776909
# Iteration 165, loss = 7.25890865
# Iteration 166, loss = 7.22010338
# Iteration 167, loss = 7.18135696
# Iteration 168, loss = 7.14268636
# Iteration 169, loss = 7.10407061
# Iteration 170, loss = 7.06552514
# Iteration 171, loss = 7.02705574
# Iteration 172, loss = 6.98864593
# Iteration 173, loss = 6.95029659
# Iteration 174, loss = 6.91202003
# Iteration 175, loss = 6.87384627
# Iteration 176, loss = 6.83579330
# Iteration 177, loss = 6.79780675
# Iteration 178, loss = 6.75988710
# Iteration 179, loss = 6.72203490
# Iteration 180, loss = 6.68425071
# Iteration 181, loss = 6.64653513
# Iteration 182, loss = 6.60888881
# Iteration 183, loss = 6.57131240
# Iteration 184, loss = 6.53380659
# Iteration 185, loss = 6.49637208
# Iteration 186, loss = 6.45900960
# Iteration 187, loss = 6.42171989
# Iteration 188, loss = 6.38450371
# Iteration 189, loss = 6.34736183
# Iteration 190, loss = 6.31029504
# Iteration 191, loss = 6.27330412
# Iteration 192, loss = 6.23638988
# Iteration 193, loss = 6.19955313
# Iteration 194, loss = 6.16279469
# Iteration 195, loss = 6.12611538
# Iteration 196, loss = 6.08951603
# Iteration 197, loss = 6.05299747
# Iteration 198, loss = 6.01657193
# Iteration 199, loss = 5.98024404
# Iteration 200, loss = 5.94400270
# Iteration 201, loss = 5.90786005
# Iteration 202, loss = 5.87180425
# Iteration 203, loss = 5.83583589
# Iteration 204, loss = 5.79996108
# Iteration 205, loss = 5.76419098
# Iteration 206, loss = 5.72853055
# Iteration 207, loss = 5.69296351
# Iteration 208, loss = 5.65749622
# Iteration 209, loss = 5.62212330
# Iteration 210, loss = 5.58684303
# Iteration 211, loss = 5.55165602
# Iteration 212, loss = 5.51656345
# Iteration 213, loss = 5.48157394
# Iteration 214, loss = 5.44667930
# Iteration 215, loss = 5.41188019
# Iteration 216, loss = 5.37717733
# Iteration 217, loss = 5.34257140
# Iteration 218, loss = 5.30797092
# Iteration 219, loss = 5.27344952
# Iteration 220, loss = 5.23901891
# Iteration 221, loss = 5.20468080
# Iteration 222, loss = 5.17043683
# Iteration 223, loss = 5.13628853
# Iteration 224, loss = 5.10223736
# Iteration 225, loss = 5.06828470
# Iteration 226, loss = 5.03443185
# Iteration 227, loss = 5.00068008
# Iteration 228, loss = 4.96703059
# Iteration 229, loss = 4.93348451
# Iteration 230, loss = 4.90004296
# Iteration 231, loss = 4.86670698
# Iteration 232, loss = 4.83347761
# Iteration 233, loss = 4.80035582
# Iteration 234, loss = 4.76734257
# Iteration 235, loss = 4.73443879
# Iteration 236, loss = 4.70164535
# Iteration 237, loss = 4.66896314
# Iteration 238, loss = 4.63639300
# Iteration 239, loss = 4.60393575
# Iteration 240, loss = 4.57159219
# Iteration 241, loss = 4.53936207
# Iteration 242, loss = 4.50716398
# Iteration 243, loss = 4.47507577
# Iteration 244, loss = 4.44309897
# Iteration 245, loss = 4.41123499
# Iteration 246, loss = 4.37948515
# Iteration 247, loss = 4.34785070
# Iteration 248, loss = 4.31633283
# Iteration 249, loss = 4.28493265
# Iteration 250, loss = 4.25365121
# Iteration 251, loss = 4.22248952
# Iteration 252, loss = 4.19144854
# Iteration 253, loss = 4.16052917
# Iteration 254, loss = 4.12973228
# Iteration 255, loss = 4.09905870
# Iteration 256, loss = 4.06850923
# Iteration 257, loss = 4.03808462
# Iteration 258, loss = 4.00776285
# Iteration 259, loss = 3.97752097
# Iteration 260, loss = 3.94740121
# Iteration 261, loss = 3.91740485
# Iteration 262, loss = 3.88753312
# Iteration 263, loss = 3.85778716
# Iteration 264, loss = 3.82816802
# Iteration 265, loss = 3.79867670
# Iteration 266, loss = 3.76931413
# Iteration 267, loss = 3.74008120
# Iteration 268, loss = 3.71097873
# Iteration 269, loss = 3.68200750
# Iteration 270, loss = 3.65316824
# Iteration 271, loss = 3.62441051
# Iteration 272, loss = 3.59574126
# Iteration 273, loss = 3.56719889
# Iteration 274, loss = 3.53878491
# Iteration 275, loss = 3.51050067
# Iteration 276, loss = 3.48234745
# Iteration 277, loss = 3.45432642
# Iteration 278, loss = 3.42643864
# Iteration 279, loss = 3.39868511
# Iteration 280, loss = 3.37106674
# Iteration 281, loss = 3.34358440
# Iteration 282, loss = 3.31623886
# Iteration 283, loss = 3.28903086
# Iteration 284, loss = 3.26196107
# Iteration 285, loss = 3.23503013
# Iteration 286, loss = 3.20823861
# Iteration 287, loss = 3.18158708
# Iteration 288, loss = 3.15507602
# Iteration 289, loss = 3.12870592
# Iteration 290, loss = 3.10247722
# Iteration 291, loss = 3.07639032
# Iteration 292, loss = 3.05044643
# Iteration 293, loss = 3.02462580
# Iteration 294, loss = 2.99885869
# Iteration 295, loss = 2.97322667
# Iteration 296, loss = 2.94773105
# Iteration 297, loss = 2.92237300
# Iteration 298, loss = 2.89715360
# Iteration 299, loss = 2.87207382
# Iteration 300, loss = 2.84713452
# Iteration 301, loss = 2.82233650
# Iteration 302, loss = 2.79768047
# Iteration 303, loss = 2.77316707
# Iteration 304, loss = 2.74879688
# Iteration 305, loss = 2.72457042
# Iteration 306, loss = 2.70048816
# Iteration 307, loss = 2.67655051
# Iteration 308, loss = 2.65275785
# Iteration 309, loss = 2.62911051
# Iteration 310, loss = 2.60560877
# Iteration 311, loss = 2.58225289
# Iteration 312, loss = 2.55904309
# Iteration 313, loss = 2.53597957
# Iteration 314, loss = 2.51306249
# Iteration 315, loss = 2.49029198
# Iteration 316, loss = 2.46767712
# Iteration 317, loss = 2.44520996
# Iteration 318, loss = 2.42289003
# Iteration 319, loss = 2.40071731
# Iteration 320, loss = 2.37869180
# Iteration 321, loss = 2.35681345
# Iteration 322, loss = 2.33508222
# Iteration 323, loss = 2.31349804
# Iteration 324, loss = 2.29206085
# Iteration 325, loss = 2.27077056
# Iteration 326, loss = 2.24962707
# Iteration 327, loss = 2.22863026
# Iteration 328, loss = 2.20778003
# Iteration 329, loss = 2.18707622
# Iteration 330, loss = 2.16651871
# Iteration 331, loss = 2.14610733
# Iteration 332, loss = 2.12584192
# Iteration 333, loss = 2.10572231
# Iteration 334, loss = 2.08574829
# Iteration 335, loss = 2.06591968
# Iteration 336, loss = 2.04623628
# Iteration 337, loss = 2.02669785
# Iteration 338, loss = 2.00730563
# Iteration 339, loss = 1.98806248
# Iteration 340, loss = 1.96896353
# Iteration 341, loss = 1.95000852
# Iteration 342, loss = 1.93119719
# Iteration 343, loss = 1.91252928
# Iteration 344, loss = 1.89400451
# Iteration 345, loss = 1.87562257
# Iteration 346, loss = 1.85738318
# Iteration 347, loss = 1.83928603
# Iteration 348, loss = 1.82133079
# Iteration 349, loss = 1.80351714
# Iteration 350, loss = 1.78584476
# Iteration 351, loss = 1.76831329
# Iteration 352, loss = 1.75092238
# Iteration 353, loss = 1.73367167
# Iteration 354, loss = 1.71656080
# Iteration 355, loss = 1.69958938
# Iteration 356, loss = 1.68275704
# Iteration 357, loss = 1.66606338
# Iteration 358, loss = 1.64950799
# Iteration 359, loss = 1.63309048
# Iteration 360, loss = 1.61681042
# Iteration 361, loss = 1.60066738
# Iteration 362, loss = 1.58466094
# Iteration 363, loss = 1.56879066
# Iteration 364, loss = 1.55305609
# Iteration 365, loss = 1.53745678
# Iteration 366, loss = 1.52194595
# Iteration 367, loss = 1.50654536
# Iteration 368, loss = 1.49127358
# Iteration 369, loss = 1.47613078
# Iteration 370, loss = 1.46111708
# Iteration 371, loss = 1.44623254
# Iteration 372, loss = 1.43146739
# Iteration 373, loss = 1.41679853
# Iteration 374, loss = 1.40225561
# Iteration 375, loss = 1.38783889
# Iteration 376, loss = 1.37354855
# Iteration 377, loss = 1.35938470
# Iteration 378, loss = 1.34534734
# Iteration 379, loss = 1.33143646
# Iteration 380, loss = 1.31765195
# Iteration 381, loss = 1.30399365
# Iteration 382, loss = 1.29046138
# Iteration 383, loss = 1.27705488
# Iteration 384, loss = 1.26377387
# Iteration 385, loss = 1.25061804
# Iteration 386, loss = 1.23758701
# Iteration 387, loss = 1.22468042
# Iteration 388, loss = 1.21189783
# Iteration 389, loss = 1.19923882
# Iteration 390, loss = 1.18670292
# Iteration 391, loss = 1.17428964
# Iteration 392, loss = 1.16199848
# Iteration 393, loss = 1.14982891
# Iteration 394, loss = 1.13778039
# Iteration 395, loss = 1.12585237
# Iteration 396, loss = 1.11404428
# Iteration 397, loss = 1.10235552
# Iteration 398, loss = 1.09078552
# Iteration 399, loss = 1.07933365
# Iteration 400, loss = 1.06799930
# Iteration 401, loss = 1.05678185
# Iteration 402, loss = 1.04568065
# Iteration 403, loss = 1.03469506
# Iteration 404, loss = 1.02382444
# Iteration 405, loss = 1.01306811
# Iteration 406, loss = 1.00242541
# Iteration 407, loss = 0.99189567
# Iteration 408, loss = 0.98147821
# Iteration 409, loss = 0.97117235
# Iteration 410, loss = 0.96097739
# Iteration 411, loss = 0.95089264
# Iteration 412, loss = 0.94091740
# Iteration 413, loss = 0.93105097
# Iteration 414, loss = 0.92129263
# Iteration 415, loss = 0.91164169
# Iteration 416, loss = 0.90209742
# Iteration 417, loss = 0.89265911
# Iteration 418, loss = 0.88332603
# Iteration 419, loss = 0.87409747
# Iteration 420, loss = 0.86497269
# Iteration 421, loss = 0.85595097
# Iteration 422, loss = 0.84703158
# Iteration 423, loss = 0.83821378
# Iteration 424, loss = 0.82949684
# Iteration 425, loss = 0.82088002
# Iteration 426, loss = 0.81236259
# Iteration 427, loss = 0.80394381
# Iteration 428, loss = 0.79562293
# Iteration 429, loss = 0.78739922
# Iteration 430, loss = 0.77927193
# Iteration 431, loss = 0.77124031
# Iteration 432, loss = 0.76330363
# Iteration 433, loss = 0.75546113
# Iteration 434, loss = 0.74771208
# Iteration 435, loss = 0.74005572
# Iteration 436, loss = 0.73249131
# Iteration 437, loss = 0.72501811
# Iteration 438, loss = 0.71763536
# Iteration 439, loss = 0.71034232
# Iteration 440, loss = 0.70313825
# Iteration 441, loss = 0.69602240
# Iteration 442, loss = 0.68899401
# Iteration 443, loss = 0.68205236
# Iteration 444, loss = 0.67519669
# Iteration 445, loss = 0.66842626
# Iteration 446, loss = 0.66174032
# Iteration 447, loss = 0.65513814
# Iteration 448, loss = 0.64861897
# Iteration 449, loss = 0.64218208
# Iteration 450, loss = 0.63582672
# Iteration 451, loss = 0.62955215
# Iteration 452, loss = 0.62335765
# Iteration 453, loss = 0.61724247
# Iteration 454, loss = 0.61120588
# Iteration 455, loss = 0.60524715
# Iteration 456, loss = 0.59936555
# Iteration 457, loss = 0.59356035
# Iteration 458, loss = 0.58783082
# Iteration 459, loss = 0.58217625
# Iteration 460, loss = 0.57656336
# Iteration 461, loss = 0.57101919
# Iteration 462, loss = 0.56554518
# Iteration 463, loss = 0.56014099
# Iteration 464, loss = 0.55480622
# Iteration 465, loss = 0.54954049
# Iteration 466, loss = 0.54434334
# Iteration 467, loss = 0.53921430
# Iteration 468, loss = 0.53415290
# Iteration 469, loss = 0.52915862
# Iteration 470, loss = 0.52423094
# Iteration 471, loss = 0.51936931
# Iteration 472, loss = 0.51457319
# Iteration 473, loss = 0.50984200
# Iteration 474, loss = 0.50517517
# Iteration 475, loss = 0.50057210
# Iteration 476, loss = 0.49600101
# Iteration 477, loss = 0.49148025
# Iteration 478, loss = 0.48701819
# Iteration 479, loss = 0.48261468
# Iteration 480, loss = 0.47826950
# Iteration 481, loss = 0.47398239
# Iteration 482, loss = 0.46975305
# Iteration 483, loss = 0.46558116
# Iteration 484, loss = 0.46146634
# Iteration 485, loss = 0.45740821
# Iteration 486, loss = 0.45340635
# Iteration 487, loss = 0.44946031
# Iteration 488, loss = 0.44556965
# Iteration 489, loss = 0.44173389
# Iteration 490, loss = 0.43795254
# Iteration 491, loss = 0.43422509
# Iteration 492, loss = 0.43055104
# Iteration 493, loss = 0.42692985
# Iteration 494, loss = 0.42336101
# Iteration 495, loss = 0.41984396
# Iteration 496, loss = 0.41637818
# Iteration 497, loss = 0.41296310
# Iteration 498, loss = 0.40959818
# Iteration 499, loss = 0.40628285
# Iteration 500, loss = 0.40301657
# Iteration 501, loss = 0.39979878
# Iteration 502, loss = 0.39662891
# Iteration 503, loss = 0.39350639
# Iteration 504, loss = 0.39043069
# Iteration 505, loss = 0.38740122
# Iteration 506, loss = 0.38441743
# Iteration 507, loss = 0.38147878
# Iteration 508, loss = 0.37858469
# Iteration 509, loss = 0.37573461
# Iteration 510, loss = 0.37292800
# Iteration 511, loss = 0.37016431
# Iteration 512, loss = 0.36744298
# Iteration 513, loss = 0.36476348
# Iteration 514, loss = 0.36212527
# Iteration 515, loss = 0.35952780
# Iteration 516, loss = 0.35697055
# Iteration 517, loss = 0.35445299
# Iteration 518, loss = 0.35197458
# Iteration 519, loss = 0.34953482
# Iteration 520, loss = 0.34713317
# Iteration 521, loss = 0.34476912
# Iteration 522, loss = 0.34244217
# Iteration 523, loss = 0.34015181
# Iteration 524, loss = 0.33789754
# Iteration 525, loss = 0.33567885
# Iteration 526, loss = 0.33349526
# Iteration 527, loss = 0.33134628
# Iteration 528, loss = 0.32923142
# Iteration 529, loss = 0.32715020
# Iteration 530, loss = 0.32510215
# Iteration 531, loss = 0.32308679
# Iteration 532, loss = 0.32110367
# Iteration 533, loss = 0.31915231
# Iteration 534, loss = 0.31723226
# Iteration 535, loss = 0.31534307
# Iteration 536, loss = 0.31348428
# Iteration 537, loss = 0.31165546
# Iteration 538, loss = 0.30985617
# Iteration 539, loss = 0.30808597
# Iteration 540, loss = 0.30634443
# Iteration 541, loss = 0.30463112
# Iteration 542, loss = 0.30294563
# Iteration 543, loss = 0.30128753
# Iteration 544, loss = 0.29965642
# Iteration 545, loss = 0.29805189
# Iteration 546, loss = 0.29647354
# Iteration 547, loss = 0.29492096
# Iteration 548, loss = 0.29339377
# Iteration 549, loss = 0.29189157
# Iteration 550, loss = 0.29041397
# Iteration 551, loss = 0.28896061
# Iteration 552, loss = 0.28753110
# Iteration 553, loss = 0.28612508
# Iteration 554, loss = 0.28474216
# Iteration 555, loss = 0.28338200
# Iteration 556, loss = 0.28204423
# Iteration 557, loss = 0.28072850
# Iteration 558, loss = 0.27943446
# Iteration 559, loss = 0.27816176
# Iteration 560, loss = 0.27691007
# Iteration 561, loss = 0.27567904
# Iteration 562, loss = 0.27446834
# Iteration 563, loss = 0.27327765
# Iteration 564, loss = 0.27210663
# Iteration 565, loss = 0.27095498
# Iteration 566, loss = 0.26982236
# Iteration 567, loss = 0.26870848
# Iteration 568, loss = 0.26761302
# Iteration 569, loss = 0.26653568
# Iteration 570, loss = 0.26547616
# Iteration 571, loss = 0.26443416
# Iteration 572, loss = 0.26340939
# Iteration 573, loss = 0.26240156
# Iteration 574, loss = 0.26141039
# Iteration 575, loss = 0.26043560
# Iteration 576, loss = 0.25947691
# Iteration 577, loss = 0.25853404
# Iteration 578, loss = 0.25760673
# Iteration 579, loss = 0.25669472
# Iteration 580, loss = 0.25579774
# Iteration 581, loss = 0.25491553
# Iteration 582, loss = 0.25404783
# Iteration 583, loss = 0.25319441
# Iteration 584, loss = 0.25235501
# Iteration 585, loss = 0.25152938
# Iteration 586, loss = 0.25071729
# Iteration 587, loss = 0.24991849
# Iteration 588, loss = 0.24913277
# Iteration 589, loss = 0.24835988
# Iteration 590, loss = 0.24759960
# Iteration 591, loss = 0.24685170
# Iteration 592, loss = 0.24611597
# Iteration 593, loss = 0.24539219
# Iteration 594, loss = 0.24468015
# Iteration 595, loss = 0.24397963
# Iteration 596, loss = 0.24329043
# Iteration 597, loss = 0.24261234
# Iteration 598, loss = 0.24194517
# Iteration 599, loss = 0.24128871
# Iteration 600, loss = 0.24064277
# Iteration 601, loss = 0.24000716
# Iteration 602, loss = 0.23938170
# Iteration 603, loss = 0.23876618
# Iteration 604, loss = 0.23816044
# Iteration 605, loss = 0.23756429
# Iteration 606, loss = 0.23697755
# Iteration 607, loss = 0.23640005
# Iteration 608, loss = 0.23583162
# Iteration 609, loss = 0.23527209
# Iteration 610, loss = 0.23472129
# Iteration 611, loss = 0.23417906
# Iteration 612, loss = 0.23364524
# Iteration 613, loss = 0.23311967
# Iteration 614, loss = 0.23260219
# Iteration 615, loss = 0.23209265
# Iteration 616, loss = 0.23159091
# Iteration 617, loss = 0.23109680
# Iteration 618, loss = 0.23061019
# Iteration 619, loss = 0.23013093
# Iteration 620, loss = 0.22965889
# Iteration 621, loss = 0.22919392
# Iteration 622, loss = 0.22873588
# Iteration 623, loss = 0.22828465
# Iteration 624, loss = 0.22784009
# Iteration 625, loss = 0.22740207
# Iteration 626, loss = 0.22697047
# Iteration 627, loss = 0.22654515
# Iteration 628, loss = 0.22612600
# Iteration 629, loss = 0.22571290
# Iteration 630, loss = 0.22530573
# Iteration 631, loss = 0.22490436
# Iteration 632, loss = 0.22450869
# Iteration 633, loss = 0.22411861
# Iteration 634, loss = 0.22373400
# Iteration 635, loss = 0.22335475
# Iteration 636, loss = 0.22298076
# Iteration 637, loss = 0.22261192
# Iteration 638, loss = 0.22224813
# Iteration 639, loss = 0.22188929
# Iteration 640, loss = 0.22153530
# Iteration 641, loss = 0.22118605
# Iteration 642, loss = 0.22084147
# Iteration 643, loss = 0.22050145
# Iteration 644, loss = 0.22016589
# Iteration 645, loss = 0.21983472
# Iteration 646, loss = 0.21950783
# Iteration 647, loss = 0.21918515
# Iteration 648, loss = 0.21886658
# Iteration 649, loss = 0.21855204
# Iteration 650, loss = 0.21824146
# Iteration 651, loss = 0.21793474
# Iteration 652, loss = 0.21763181
# Iteration 653, loss = 0.21733259
# Iteration 654, loss = 0.21703701
# Iteration 655, loss = 0.21674498
# Iteration 656, loss = 0.21645644
# Iteration 657, loss = 0.21617132
# Iteration 658, loss = 0.21588953
# Iteration 659, loss = 0.21561102
# Iteration 660, loss = 0.21533571
# Iteration 661, loss = 0.21506354
# Iteration 662, loss = 0.21479444
# Iteration 663, loss = 0.21452834
# Iteration 664, loss = 0.21426519
# Iteration 665, loss = 0.21400492
# Iteration 666, loss = 0.21374747
# Iteration 667, loss = 0.21349278
# Iteration 668, loss = 0.21324080
# Iteration 669, loss = 0.21299146
# Iteration 670, loss = 0.21274470
# Iteration 671, loss = 0.21250049
# Iteration 672, loss = 0.21225875
# Iteration 673, loss = 0.21201944
# Iteration 674, loss = 0.21178250
# Iteration 675, loss = 0.21154789
# Iteration 676, loss = 0.21131556
# Iteration 677, loss = 0.21108545
# Iteration 678, loss = 0.21085751
# Iteration 679, loss = 0.21063171
# Iteration 680, loss = 0.21040800
# Iteration 681, loss = 0.21018632
# Iteration 682, loss = 0.20996664
# Iteration 683, loss = 0.20974892
# Iteration 684, loss = 0.20953310
# Iteration 685, loss = 0.20931915
# Iteration 686, loss = 0.20910703
# Iteration 687, loss = 0.20889670
# Iteration 688, loss = 0.20868812
# Iteration 689, loss = 0.20848126
# Iteration 690, loss = 0.20827606
# Iteration 691, loss = 0.20807251
# Iteration 692, loss = 0.20787055
# Iteration 693, loss = 0.20767017
# Iteration 694, loss = 0.20747131
# Iteration 695, loss = 0.20727396
# Iteration 696, loss = 0.20707807
# Iteration 697, loss = 0.20688361
# Iteration 698, loss = 0.20669056
# Iteration 699, loss = 0.20649888
# Iteration 700, loss = 0.20630854
# Iteration 701, loss = 0.20611951
# Iteration 702, loss = 0.20593177
# Iteration 703, loss = 0.20574528
# Iteration 704, loss = 0.20556002
# Iteration 705, loss = 0.20537595
# Iteration 706, loss = 0.20519306
# Iteration 707, loss = 0.20501132
# Iteration 708, loss = 0.20483070
# Iteration 709, loss = 0.20465117
# Iteration 710, loss = 0.20447272
# Iteration 711, loss = 0.20429532
# Iteration 712, loss = 0.20411894
# Iteration 713, loss = 0.20394357
# Iteration 714, loss = 0.20376918
# Iteration 715, loss = 0.20359574
# Iteration 716, loss = 0.20342325
# Iteration 717, loss = 0.20325167
# Iteration 718, loss = 0.20308099
# Iteration 719, loss = 0.20291118
# Iteration 720, loss = 0.20274223
# Iteration 721, loss = 0.20257412
# Iteration 722, loss = 0.20240683
# Iteration 723, loss = 0.20224034
# Iteration 724, loss = 0.20207464
# Iteration 725, loss = 0.20190970
# Iteration 726, loss = 0.20174551
# Iteration 727, loss = 0.20158205
# Iteration 728, loss = 0.20141931
# Iteration 729, loss = 0.20125727
# Iteration 730, loss = 0.20109592
# Iteration 731, loss = 0.20093523
# Iteration 732, loss = 0.20077520
# Iteration 733, loss = 0.20061582
# Iteration 734, loss = 0.20045705
# Iteration 735, loss = 0.20029891
# Iteration 736, loss = 0.20014136
# Iteration 737, loss = 0.19998440
# Iteration 738, loss = 0.19982801
# Iteration 739, loss = 0.19967218
# Iteration 740, loss = 0.19951690
# Iteration 741, loss = 0.19936216
# Iteration 742, loss = 0.19920794
# Iteration 743, loss = 0.19905424
# Iteration 744, loss = 0.19890103
# Iteration 745, loss = 0.19874832
# Iteration 746, loss = 0.19859610
# Iteration 747, loss = 0.19844434
# Iteration 748, loss = 0.19829304
# Iteration 749, loss = 0.19814219
# Iteration 750, loss = 0.19799178
# Iteration 751, loss = 0.19784181
# Iteration 752, loss = 0.19769225
# Iteration 753, loss = 0.19754311
# Iteration 754, loss = 0.19739438
# Iteration 755, loss = 0.19724604
# Iteration 756, loss = 0.19709809
# Iteration 757, loss = 0.19695051
# Iteration 758, loss = 0.19680331
# Iteration 759, loss = 0.19665647
# Iteration 760, loss = 0.19650999
# Iteration 761, loss = 0.19636386
# Iteration 762, loss = 0.19621807
# Iteration 763, loss = 0.19607261
# Iteration 764, loss = 0.19592748
# Iteration 765, loss = 0.19578267
# Iteration 766, loss = 0.19563817
# Iteration 767, loss = 0.19549399
# Iteration 768, loss = 0.19535010
# Iteration 769, loss = 0.19520651
# Iteration 770, loss = 0.19506321
# Iteration 771, loss = 0.19492020
# Iteration 772, loss = 0.19477746
# Iteration 773, loss = 0.19463500
# Iteration 774, loss = 0.19449280
# Iteration 775, loss = 0.19435087
# Iteration 776, loss = 0.19420919
# Iteration 777, loss = 0.19406777
# Iteration 778, loss = 0.19392659
# Iteration 779, loss = 0.19378566
# Iteration 780, loss = 0.19364497
# Iteration 781, loss = 0.19350451
# Iteration 782, loss = 0.19336428
# Iteration 783, loss = 0.19322427
# Iteration 784, loss = 0.19308449
# Iteration 785, loss = 0.19294492
# Iteration 786, loss = 0.19280557
# Iteration 787, loss = 0.19266642
# Iteration 788, loss = 0.19252749
# Iteration 789, loss = 0.19238875
# Iteration 790, loss = 0.19225022
# Iteration 791, loss = 0.19211187
# Iteration 792, loss = 0.19197373
# Iteration 793, loss = 0.19183576
# Iteration 794, loss = 0.19169799
# Iteration 795, loss = 0.19156040
# Iteration 796, loss = 0.19142299
# Iteration 797, loss = 0.19128575
# Iteration 798, loss = 0.19114869
# Iteration 799, loss = 0.19101180
# Iteration 800, loss = 0.19087507
# Iteration 801, loss = 0.19073852
# Iteration 802, loss = 0.19060212
# Iteration 803, loss = 0.19046589
# Iteration 804, loss = 0.19032982
# Iteration 805, loss = 0.19019390
# Iteration 806, loss = 0.19005813
# Iteration 807, loss = 0.18992252
# Iteration 808, loss = 0.18978706
# Iteration 809, loss = 0.18965174
# Iteration 810, loss = 0.18951657
# Iteration 811, loss = 0.18938154
# Iteration 812, loss = 0.18924666
# Iteration 813, loss = 0.18911191
# Iteration 814, loss = 0.18897730
# Iteration 815, loss = 0.18884283
# Iteration 816, loss = 0.18870849
# Iteration 817, loss = 0.18857428
# Iteration 818, loss = 0.18844021
# Iteration 819, loss = 0.18830626
# Iteration 820, loss = 0.18817245
# Iteration 821, loss = 0.18803876
# Iteration 822, loss = 0.18790519
# Iteration 823, loss = 0.18777175
# Iteration 824, loss = 0.18763843
# Iteration 825, loss = 0.18750523
# Iteration 826, loss = 0.18737215
# Iteration 827, loss = 0.18723919
# Iteration 828, loss = 0.18710634
# Iteration 829, loss = 0.18697361
# Iteration 830, loss = 0.18684100
# Iteration 831, loss = 0.18670850
# Iteration 832, loss = 0.18657612
# Iteration 833, loss = 0.18644384
# Iteration 834, loss = 0.18631168
# Iteration 835, loss = 0.18617962
# Iteration 836, loss = 0.18604768
# Iteration 837, loss = 0.18591584
# Iteration 838, loss = 0.18578411
# Iteration 839, loss = 0.18565249
# Iteration 840, loss = 0.18552097
# Iteration 841, loss = 0.18538956
# Iteration 842, loss = 0.18525825
# Iteration 843, loss = 0.18512704
# Iteration 844, loss = 0.18499594
# Iteration 845, loss = 0.18486494
# Iteration 846, loss = 0.18473404
# Iteration 847, loss = 0.18460324
# Iteration 848, loss = 0.18447254
# Iteration 849, loss = 0.18434193
# Iteration 850, loss = 0.18421143
# Iteration 851, loss = 0.18408103
# Iteration 852, loss = 0.18395072
# Iteration 853, loss = 0.18382051
# Iteration 854, loss = 0.18369040
# Iteration 855, loss = 0.18356038
# Iteration 856, loss = 0.18343046
# Iteration 857, loss = 0.18330063
# Iteration 858, loss = 0.18317090
# Iteration 859, loss = 0.18304126
# Iteration 860, loss = 0.18291171
# Iteration 861, loss = 0.18278226
# Iteration 862, loss = 0.18265290
# Iteration 863, loss = 0.18252364
# Iteration 864, loss = 0.18239447
# Iteration 865, loss = 0.18226539
# Iteration 866, loss = 0.18213640
# Iteration 867, loss = 0.18200750
# Iteration 868, loss = 0.18187869
# Iteration 869, loss = 0.18174998
# Iteration 870, loss = 0.18162135
# Iteration 871, loss = 0.18149281
# Iteration 872, loss = 0.18136437
# Iteration 873, loss = 0.18123601
# Iteration 874, loss = 0.18110775
# Iteration 875, loss = 0.18097957
# Iteration 876, loss = 0.18085149
# Iteration 877, loss = 0.18072349
# Iteration 878, loss = 0.18059558
# Iteration 879, loss = 0.18046776
# Iteration 880, loss = 0.18034003
# Iteration 881, loss = 0.18021238
# Iteration 882, loss = 0.18008483
# Iteration 883, loss = 0.17995736
# Iteration 884, loss = 0.17982998
# Iteration 885, loss = 0.17970269
# Iteration 886, loss = 0.17957548
# Iteration 887, loss = 0.17944837
# Iteration 888, loss = 0.17932134
# Iteration 889, loss = 0.17919439
# Iteration 890, loss = 0.17906754
# Iteration 891, loss = 0.17894077
# Iteration 892, loss = 0.17881409
# Iteration 893, loss = 0.17868750
# Iteration 894, loss = 0.17856099
# Iteration 895, loss = 0.17843457
# Iteration 896, loss = 0.17830824
# Iteration 897, loss = 0.17818200
# Iteration 898, loss = 0.17805584
# Iteration 899, loss = 0.17792976
# Iteration 900, loss = 0.17780378
# Iteration 901, loss = 0.17767788
# Iteration 902, loss = 0.17755207
# Iteration 903, loss = 0.17742634
# Iteration 904, loss = 0.17730071
# Iteration 905, loss = 0.17717515
# Iteration 906, loss = 0.17704969
# Iteration 907, loss = 0.17692431
# Iteration 908, loss = 0.17679902
# Iteration 909, loss = 0.17667381
# Iteration 910, loss = 0.17654869
# Iteration 911, loss = 0.17642366
# Iteration 912, loss = 0.17629872
# Iteration 913, loss = 0.17617386
# Iteration 914, loss = 0.17604909
# Iteration 915, loss = 0.17592440
# Iteration 916, loss = 0.17579980
# Iteration 917, loss = 0.17567529
# Iteration 918, loss = 0.17555087
# Iteration 919, loss = 0.17542653
# Iteration 920, loss = 0.17530228
# Iteration 921, loss = 0.17517812
# Iteration 922, loss = 0.17505404
# Iteration 923, loss = 0.17493005
# Iteration 924, loss = 0.17480615
# Iteration 925, loss = 0.17468233
# Iteration 926, loss = 0.17455861
# Iteration 927, loss = 0.17443497
# Iteration 928, loss = 0.17431141
# Iteration 929, loss = 0.17418795
# Iteration 930, loss = 0.17406457
# Iteration 931, loss = 0.17394128
# Iteration 932, loss = 0.17381808
# Iteration 933, loss = 0.17369496
# Iteration 934, loss = 0.17357194
# Iteration 935, loss = 0.17344900
# Iteration 936, loss = 0.17332615
# Iteration 937, loss = 0.17320339
# Iteration 938, loss = 0.17308071
# Iteration 939, loss = 0.17295812
# Iteration 940, loss = 0.17283563
# Iteration 941, loss = 0.17271322
# Iteration 942, loss = 0.17259089
# Iteration 943, loss = 0.17246866
# Iteration 944, loss = 0.17234652
# Iteration 945, loss = 0.17222446
# Iteration 946, loss = 0.17210249
# Iteration 947, loss = 0.17198062
# Iteration 948, loss = 0.17185883
# Iteration 949, loss = 0.17173713
# Iteration 950, loss = 0.17161552
# Iteration 951, loss = 0.17149399
# Iteration 952, loss = 0.17137256
# Iteration 953, loss = 0.17125122
# Iteration 954, loss = 0.17112996
# Iteration 955, loss = 0.17100880
# Iteration 956, loss = 0.17088773
# Iteration 957, loss = 0.17076674
# Iteration 958, loss = 0.17064585
# Iteration 959, loss = 0.17052504
# Iteration 960, loss = 0.17040433
# Iteration 961, loss = 0.17028370
# Iteration 962, loss = 0.17016317
# Iteration 963, loss = 0.17004273
# Iteration 964, loss = 0.16992237
# Iteration 965, loss = 0.16980211
# Iteration 966, loss = 0.16968194
# Iteration 967, loss = 0.16956186
# Iteration 968, loss = 0.16944187
# Iteration 969, loss = 0.16932197
# Iteration 970, loss = 0.16920216
# Iteration 971, loss = 0.16908244
# Iteration 972, loss = 0.16896281
# Iteration 973, loss = 0.16884328
# Iteration 974, loss = 0.16872384
# Iteration 975, loss = 0.16860448
# Iteration 976, loss = 0.16848522
# Iteration 977, loss = 0.16836605
# Iteration 978, loss = 0.16824698
# Iteration 979, loss = 0.16812799
# Iteration 980, loss = 0.16800910
# Iteration 981, loss = 0.16789030
# Iteration 982, loss = 0.16777159
# Iteration 983, loss = 0.16765298
# Iteration 984, loss = 0.16753445
# Iteration 985, loss = 0.16741602
# Iteration 986, loss = 0.16729768
# Iteration 987, loss = 0.16717944
# Iteration 988, loss = 0.16706128
# Iteration 989, loss = 0.16694322
# Iteration 990, loss = 0.16682526
# Iteration 991, loss = 0.16670738
# Iteration 992, loss = 0.16658960
# Iteration 993, loss = 0.16647192
# Iteration 994, loss = 0.16635432
# Iteration 995, loss = 0.16623682
# Iteration 996, loss = 0.16611941
# Iteration 997, loss = 0.16600210
# Iteration 998, loss = 0.16588488
# Iteration 999, loss = 0.16576776
# Iteration 1000, loss = 0.16565073
# Iteration 1001, loss = 0.16553379
# Iteration 1002, loss = 0.16541695
# Iteration 1003, loss = 0.16530020
# Iteration 1004, loss = 0.16518354
# Iteration 1005, loss = 0.16506699
# Iteration 1006, loss = 0.16495052
# Iteration 1007, loss = 0.16483415
# Iteration 1008, loss = 0.16471787
# Iteration 1009, loss = 0.16460169
# Iteration 1010, loss = 0.16448561
# Iteration 1011, loss = 0.16436962
# Iteration 1012, loss = 0.16425372
# Iteration 1013, loss = 0.16413792
# Iteration 1014, loss = 0.16402222
# Iteration 1015, loss = 0.16390661
# Iteration 1016, loss = 0.16379110
# Iteration 1017, loss = 0.16367568
# Iteration 1018, loss = 0.16356036
# Iteration 1019, loss = 0.16344513
# Iteration 1020, loss = 0.16333000
# Iteration 1021, loss = 0.16321497
# Iteration 1022, loss = 0.16310003
# Iteration 1023, loss = 0.16298519
# Iteration 1024, loss = 0.16287044
# Iteration 1025, loss = 0.16275579
# Iteration 1026, loss = 0.16264124
# Iteration 1027, loss = 0.16252678
# Iteration 1028, loss = 0.16241242
# Iteration 1029, loss = 0.16229816
# Iteration 1030, loss = 0.16218400
# Iteration 1031, loss = 0.16206993
# Iteration 1032, loss = 0.16195596
# Iteration 1033, loss = 0.16184208
# Iteration 1034, loss = 0.16172830
# Iteration 1035, loss = 0.16161462
# Iteration 1036, loss = 0.16150104
# Iteration 1037, loss = 0.16138756
# Iteration 1038, loss = 0.16127417
# Iteration 1039, loss = 0.16116088
# Iteration 1040, loss = 0.16104769
# Iteration 1041, loss = 0.16093459
# Iteration 1042, loss = 0.16082160
# Iteration 1043, loss = 0.16070870
# Iteration 1044, loss = 0.16059590
# Iteration 1045, loss = 0.16048319
# Iteration 1046, loss = 0.16037059
# Iteration 1047, loss = 0.16025808
# Iteration 1048, loss = 0.16014568
# Iteration 1049, loss = 0.16003337
# Iteration 1050, loss = 0.15992116
# Iteration 1051, loss = 0.15980905
# Iteration 1052, loss = 0.15969703
# Iteration 1053, loss = 0.15958512
# Iteration 1054, loss = 0.15947331
# Iteration 1055, loss = 0.15936159
# Iteration 1056, loss = 0.15924997
# Iteration 1057, loss = 0.15913846
# Iteration 1058, loss = 0.15902704
# Iteration 1059, loss = 0.15891572
# Iteration 1060, loss = 0.15880450
# Iteration 1061, loss = 0.15869338
# Iteration 1062, loss = 0.15858236
# Iteration 1063, loss = 0.15847144
# Iteration 1064, loss = 0.15836061
# Iteration 1065, loss = 0.15824989
# Iteration 1066, loss = 0.15813927
# Iteration 1067, loss = 0.15802875
# Iteration 1068, loss = 0.15791833
# Iteration 1069, loss = 0.15780800
# Iteration 1070, loss = 0.15769778
# Iteration 1071, loss = 0.15758766
# Iteration 1072, loss = 0.15747764
# Iteration 1073, loss = 0.15736772
# Iteration 1074, loss = 0.15725790
# Iteration 1075, loss = 0.15714818
# Iteration 1076, loss = 0.15703856
# Iteration 1077, loss = 0.15692904
# Iteration 1078, loss = 0.15681962
# Iteration 1079, loss = 0.15671031
# Iteration 1080, loss = 0.15660109
# Iteration 1081, loss = 0.15649198
# Iteration 1082, loss = 0.15638296
# Iteration 1083, loss = 0.15627405
# Iteration 1084, loss = 0.15616524
# Iteration 1085, loss = 0.15605653
# Iteration 1086, loss = 0.15594792
# Iteration 1087, loss = 0.15583941
# Iteration 1088, loss = 0.15573100
# Iteration 1089, loss = 0.15562270
# Iteration 1090, loss = 0.15551449
# Iteration 1091, loss = 0.15540639
# Iteration 1092, loss = 0.15529839
# Iteration 1093, loss = 0.15519049
# Iteration 1094, loss = 0.15508270
# Iteration 1095, loss = 0.15497500
# Iteration 1096, loss = 0.15486741
# Iteration 1097, loss = 0.15475992
# Iteration 1098, loss = 0.15465253
# Iteration 1099, loss = 0.15454524
# Iteration 1100, loss = 0.15443806
# Iteration 1101, loss = 0.15433098
# Iteration 1102, loss = 0.15422400
# Iteration 1103, loss = 0.15411712
# Iteration 1104, loss = 0.15401034
# Iteration 1105, loss = 0.15390367
# Iteration 1106, loss = 0.15379710
# Iteration 1107, loss = 0.15369064
# Iteration 1108, loss = 0.15358427
# Iteration 1109, loss = 0.15347801
# Iteration 1110, loss = 0.15337185
# Iteration 1111, loss = 0.15326579
# Iteration 1112, loss = 0.15315984
# Iteration 1113, loss = 0.15305399
# Iteration 1114, loss = 0.15294824
# Iteration 1115, loss = 0.15284260
# Iteration 1116, loss = 0.15273706
# Iteration 1117, loss = 0.15263162
# Iteration 1118, loss = 0.15252629
# Iteration 1119, loss = 0.15242106
# Iteration 1120, loss = 0.15231593
# Iteration 1121, loss = 0.15221091
# Iteration 1122, loss = 0.15210599
# Iteration 1123, loss = 0.15200117
# Iteration 1124, loss = 0.15189646
# Iteration 1125, loss = 0.15179185
# Iteration 1126, loss = 0.15168734
# Iteration 1127, loss = 0.15158294
# Iteration 1128, loss = 0.15147864
# Iteration 1129, loss = 0.15137445
# Iteration 1130, loss = 0.15127035
# Iteration 1131, loss = 0.15116637
# Iteration 1132, loss = 0.15106249
# Iteration 1133, loss = 0.15095871
# Iteration 1134, loss = 0.15085503
# Iteration 1135, loss = 0.15075146
# Iteration 1136, loss = 0.15064800
# Iteration 1137, loss = 0.15054463
# Iteration 1138, loss = 0.15044138
# Iteration 1139, loss = 0.15033822
# Iteration 1140, loss = 0.15023517
# Iteration 1141, loss = 0.15013223
# Iteration 1142, loss = 0.15002939
# Iteration 1143, loss = 0.14992666
# Iteration 1144, loss = 0.14982402
# Iteration 1145, loss = 0.14972150
# Iteration 1146, loss = 0.14961908
# Iteration 1147, loss = 0.14951676
# Iteration 1148, loss = 0.14941455
# Iteration 1149, loss = 0.14931244
# Iteration 1150, loss = 0.14921044
# Iteration 1151, loss = 0.14910854
# Iteration 1152, loss = 0.14900675
# Iteration 1153, loss = 0.14890506
# Iteration 1154, loss = 0.14880348
# Iteration 1155, loss = 0.14870200
# Iteration 1156, loss = 0.14860063
# Iteration 1157, loss = 0.14849936
# Iteration 1158, loss = 0.14839820
# Iteration 1159, loss = 0.14829714
# Iteration 1160, loss = 0.14819619
# Iteration 1161, loss = 0.14809535
# Iteration 1162, loss = 0.14799461
# Iteration 1163, loss = 0.14789397
# Iteration 1164, loss = 0.14779344
# Iteration 1165, loss = 0.14769302
# Iteration 1166, loss = 0.14759270
# Iteration 1167, loss = 0.14749248
# Iteration 1168, loss = 0.14739238
# Iteration 1169, loss = 0.14729237
# Iteration 1170, loss = 0.14719248
# Iteration 1171, loss = 0.14709269
# Iteration 1172, loss = 0.14699300
# Iteration 1173, loss = 0.14689342
# Iteration 1174, loss = 0.14679395
# Iteration 1175, loss = 0.14669458
# Iteration 1176, loss = 0.14659532
# Iteration 1177, loss = 0.14649616
# Iteration 1178, loss = 0.14639711
# Iteration 1179, loss = 0.14629817
# Iteration 1180, loss = 0.14619933
# Iteration 1181, loss = 0.14610060
# Iteration 1182, loss = 0.14600197
# Iteration 1183, loss = 0.14590345
# Iteration 1184, loss = 0.14580504
# Iteration 1185, loss = 0.14570673
# Iteration 1186, loss = 0.14560853
# Iteration 1187, loss = 0.14551043
# Iteration 1188, loss = 0.14541244
# Iteration 1189, loss = 0.14531456
# Iteration 1190, loss = 0.14521678
# Iteration 1191, loss = 0.14511911
# Iteration 1192, loss = 0.14502155
# Iteration 1193, loss = 0.14492409
# Iteration 1194, loss = 0.14482674
# Iteration 1195, loss = 0.14472949
# Iteration 1196, loss = 0.14463235
# Iteration 1197, loss = 0.14453532
# Iteration 1198, loss = 0.14443840
# Iteration 1199, loss = 0.14434158
# Iteration 1200, loss = 0.14424487
# Iteration 1201, loss = 0.14414826
# Iteration 1202, loss = 0.14405176
# Iteration 1203, loss = 0.14395537
# Iteration 1204, loss = 0.14385908
# Iteration 1205, loss = 0.14376290
# Iteration 1206, loss = 0.14366683
# Iteration 1207, loss = 0.14357086
# Iteration 1208, loss = 0.14347500
# Iteration 1209, loss = 0.14337925
# Iteration 1210, loss = 0.14328361
# Iteration 1211, loss = 0.14318807
# Iteration 1212, loss = 0.14309264
# Iteration 1213, loss = 0.14299731
# Iteration 1214, loss = 0.14290209
# Iteration 1215, loss = 0.14280698
# Iteration 1216, loss = 0.14271198
# Iteration 1217, loss = 0.14261708
# Iteration 1218, loss = 0.14252229
# Iteration 1219, loss = 0.14242760
# Iteration 1220, loss = 0.14233303
# Iteration 1221, loss = 0.14223856
# Iteration 1222, loss = 0.14214419
# Iteration 1223, loss = 0.14204994
# Iteration 1224, loss = 0.14195579
# Iteration 1225, loss = 0.14186175
# Iteration 1226, loss = 0.14176781
# Iteration 1227, loss = 0.14167399
# Iteration 1228, loss = 0.14158027
# Iteration 1229, loss = 0.14148665
# Iteration 1230, loss = 0.14139315
# Iteration 1231, loss = 0.14129975
# Iteration 1232, loss = 0.14120646
# Iteration 1233, loss = 0.14111327
# Iteration 1234, loss = 0.14102019
# Iteration 1235, loss = 0.14092722
# Iteration 1236, loss = 0.14083436
# Iteration 1237, loss = 0.14074161
# Iteration 1238, loss = 0.14064896
# Iteration 1239, loss = 0.14055642
# Iteration 1240, loss = 0.14046398
# Iteration 1241, loss = 0.14037166
# Iteration 1242, loss = 0.14027944
# Iteration 1243, loss = 0.14018732
# Iteration 1244, loss = 0.14009532
# Iteration 1245, loss = 0.14000342
# Iteration 1246, loss = 0.13991163
# Iteration 1247, loss = 0.13981995
# Iteration 1248, loss = 0.13972837
# Iteration 1249, loss = 0.13963691
# Iteration 1250, loss = 0.13954555
# Iteration 1251, loss = 0.13945429
# Iteration 1252, loss = 0.13936315
# Iteration 1253, loss = 0.13927211
# Iteration 1254, loss = 0.13918118
# Iteration 1255, loss = 0.13909035
# Iteration 1256, loss = 0.13899964
# Iteration 1257, loss = 0.13890903
# Iteration 1258, loss = 0.13881853
# Iteration 1259, loss = 0.13872813
# Iteration 1260, loss = 0.13863785
# Iteration 1261, loss = 0.13854767
# Iteration 1262, loss = 0.13845760
# Iteration 1263, loss = 0.13836763
# Iteration 1264, loss = 0.13827778
# Iteration 1265, loss = 0.13818803
# Iteration 1266, loss = 0.13809838
# Iteration 1267, loss = 0.13800885
# Iteration 1268, loss = 0.13791942
# Iteration 1269, loss = 0.13783010
# Iteration 1270, loss = 0.13774089
# Iteration 1271, loss = 0.13765179
# Iteration 1272, loss = 0.13756279
# Iteration 1273, loss = 0.13747390
# Iteration 1274, loss = 0.13738512
# Iteration 1275, loss = 0.13729644
# Iteration 1276, loss = 0.13720788
# Iteration 1277, loss = 0.13711942
# Iteration 1278, loss = 0.13703106
# Iteration 1279, loss = 0.13694282
# Iteration 1280, loss = 0.13685468
# Iteration 1281, loss = 0.13676665
# Iteration 1282, loss = 0.13667873
# Iteration 1283, loss = 0.13659092
# Iteration 1284, loss = 0.13650321
# Iteration 1285, loss = 0.13641561
# Iteration 1286, loss = 0.13632812
# Iteration 1287, loss = 0.13624073
# Iteration 1288, loss = 0.13615345
# Iteration 1289, loss = 0.13606628
# Iteration 1290, loss = 0.13597922
# Iteration 1291, loss = 0.13589226
# Iteration 1292, loss = 0.13580542
# Iteration 1293, loss = 0.13571868
# Iteration 1294, loss = 0.13563204
# Iteration 1295, loss = 0.13554552
# Iteration 1296, loss = 0.13545910
# Iteration 1297, loss = 0.13537279
# Iteration 1298, loss = 0.13528658
# Iteration 1299, loss = 0.13520049
# Iteration 1300, loss = 0.13511450
# Iteration 1301, loss = 0.13502862
# Iteration 1302, loss = 0.13494284
# Iteration 1303, loss = 0.13485718
# Iteration 1304, loss = 0.13477162
# Iteration 1305, loss = 0.13468617
# Iteration 1306, loss = 0.13460082
# Iteration 1307, loss = 0.13451558
# Iteration 1308, loss = 0.13443045
# Iteration 1309, loss = 0.13434543
# Iteration 1310, loss = 0.13426052
# Iteration 1311, loss = 0.13417571
# Iteration 1312, loss = 0.13409101
# Iteration 1313, loss = 0.13400641
# Iteration 1314, loss = 0.13392193
# Iteration 1315, loss = 0.13383755
# Iteration 1316, loss = 0.13375328
# Iteration 1317, loss = 0.13366911
# Iteration 1318, loss = 0.13358505
# Iteration 1319, loss = 0.13350110
# Iteration 1320, loss = 0.13341726
# Iteration 1321, loss = 0.13333352
# Iteration 1322, loss = 0.13324990
# Iteration 1323, loss = 0.13316637
# Iteration 1324, loss = 0.13308296
# Iteration 1325, loss = 0.13299965
# Iteration 1326, loss = 0.13291645
# Iteration 1327, loss = 0.13283336
# Iteration 1328, loss = 0.13275037
# Iteration 1329, loss = 0.13266749
# Iteration 1330, loss = 0.13258472
# Iteration 1331, loss = 0.13250205
# Iteration 1332, loss = 0.13241950
# Iteration 1333, loss = 0.13233704
# Iteration 1334, loss = 0.13225470
# Iteration 1335, loss = 0.13217246
# Iteration 1336, loss = 0.13209033
# Iteration 1337, loss = 0.13200831
# Iteration 1338, loss = 0.13192639
# Iteration 1339, loss = 0.13184458
# Iteration 1340, loss = 0.13176288
# Iteration 1341, loss = 0.13168128
# Iteration 1342, loss = 0.13159979
# Iteration 1343, loss = 0.13151841
# Iteration 1344, loss = 0.13143713
# Iteration 1345, loss = 0.13135597
# Iteration 1346, loss = 0.13127490
# Iteration 1347, loss = 0.13119395
# Iteration 1348, loss = 0.13111310
# Iteration 1349, loss = 0.13103236
# Iteration 1350, loss = 0.13095172
# Iteration 1351, loss = 0.13087119
# Iteration 1352, loss = 0.13079077
# Iteration 1353, loss = 0.13071045
# Iteration 1354, loss = 0.13063024
# Iteration 1355, loss = 0.13055014
# Iteration 1356, loss = 0.13047014
# Iteration 1357, loss = 0.13039025
# Iteration 1358, loss = 0.13031047
# Iteration 1359, loss = 0.13023079
# Iteration 1360, loss = 0.13015122
# Iteration 1361, loss = 0.13007176
# Iteration 1362, loss = 0.12999240
# Iteration 1363, loss = 0.12991315
# Iteration 1364, loss = 0.12983400
# Iteration 1365, loss = 0.12975497
# Iteration 1366, loss = 0.12967603
# Iteration 1367, loss = 0.12959721
# Iteration 1368, loss = 0.12951849
# Iteration 1369, loss = 0.12943987
# Iteration 1370, loss = 0.12936136
# Iteration 1371, loss = 0.12928296
# Iteration 1372, loss = 0.12920467
# Iteration 1373, loss = 0.12912648
# Iteration 1374, loss = 0.12904839
# Iteration 1375, loss = 0.12897042
# Iteration 1376, loss = 0.12889255
# Iteration 1377, loss = 0.12881478
# Iteration 1378, loss = 0.12873712
# Iteration 1379, loss = 0.12865957
# Iteration 1380, loss = 0.12858212
# Iteration 1381, loss = 0.12850478
# Iteration 1382, loss = 0.12842754
# Iteration 1383, loss = 0.12835041
# Iteration 1384, loss = 0.12827339
# Iteration 1385, loss = 0.12819647
# Iteration 1386, loss = 0.12811965
# Iteration 1387, loss = 0.12804295
# Iteration 1388, loss = 0.12796634
# Iteration 1389, loss = 0.12788985
# Iteration 1390, loss = 0.12781346
# Iteration 1391, loss = 0.12773717
# Iteration 1392, loss = 0.12766099
# Iteration 1393, loss = 0.12758492
# Iteration 1394, loss = 0.12750895
# Iteration 1395, loss = 0.12743308
# Iteration 1396, loss = 0.12735733
# Iteration 1397, loss = 0.12728167
# Iteration 1398, loss = 0.12720613
# Iteration 1399, loss = 0.12713068
# Iteration 1400, loss = 0.12705535
# Iteration 1401, loss = 0.12698011
# Iteration 1402, loss = 0.12690499
# Iteration 1403, loss = 0.12682997
# Iteration 1404, loss = 0.12675505
# Iteration 1405, loss = 0.12668024
# Iteration 1406, loss = 0.12660553
# Iteration 1407, loss = 0.12653093
# Iteration 1408, loss = 0.12645643
# Iteration 1409, loss = 0.12638204
# Iteration 1410, loss = 0.12630776
# Iteration 1411, loss = 0.12623357
# Iteration 1412, loss = 0.12615950
# Iteration 1413, loss = 0.12608553
# Iteration 1414, loss = 0.12601166
# Iteration 1415, loss = 0.12593790
# Iteration 1416, loss = 0.12586424
# Iteration 1417, loss = 0.12579068
# Iteration 1418, loss = 0.12571723
# Iteration 1419, loss = 0.12564389
# Iteration 1420, loss = 0.12557065
# Iteration 1421, loss = 0.12549751
# Iteration 1422, loss = 0.12542448
# Iteration 1423, loss = 0.12535156
# Iteration 1424, loss = 0.12527873
# Iteration 1425, loss = 0.12520602
# Iteration 1426, loss = 0.12513340
# Iteration 1427, loss = 0.12506089
# Iteration 1428, loss = 0.12498849
# Iteration 1429, loss = 0.12491618
# Iteration 1430, loss = 0.12484399
# Iteration 1431, loss = 0.12477189
# Iteration 1432, loss = 0.12469991
# Iteration 1433, loss = 0.12462802
# Iteration 1434, loss = 0.12455624
# Iteration 1435, loss = 0.12448456
# Iteration 1436, loss = 0.12441299
# Iteration 1437, loss = 0.12434152
# Iteration 1438, loss = 0.12427015
# Iteration 1439, loss = 0.12419889
# Iteration 1440, loss = 0.12412773
# Iteration 1441, loss = 0.12405667
# ...
# Iteration 1876, loss = 0.10209553
# Iteration 1877, loss = 0.10206313
# Iteration 1878, loss = 0.10203080
# Iteration 1879, loss = 0.10199853
# Iteration 1880, loss = 0.10196634
# Iteration 1881, loss = 0.10193421
# Iteration 1882, loss = 0.10190216
# Iteration 1883, loss = 0.10187017
# Iteration 1884, loss = 0.10183826
# Iteration 1885, loss = 0.10180641
# Iteration 1886, loss = 0.10177464
# Iteration 1887, loss = 0.10174293
# Iteration 1888, loss = 0.10171129
# Iteration 1889, loss = 0.10167972
# Iteration 1890, loss = 0.10164822
# Iteration 1891, loss = 0.10161679
# Iteration 1892, loss = 0.10158542
# Iteration 1893, loss = 0.10155413
# Iteration 1894, loss = 0.10152290
# Iteration 1895, loss = 0.10149174
# Iteration 1896, loss = 0.10146065
# Iteration 1897, loss = 0.10142963
# Iteration 1898, loss = 0.10139868
# Iteration 1899, loss = 0.10136779
# Iteration 1900, loss = 0.10133698
# Iteration 1901, loss = 0.10130623
# Iteration 1902, loss = 0.10127555
# Iteration 1903, loss = 0.10124493
# Iteration 1904, loss = 0.10121439
# Iteration 1905, loss = 0.10118391
# Iteration 1906, loss = 0.10115350
# Iteration 1907, loss = 0.10112315
# Iteration 1908, loss = 0.10109287
# Iteration 1909, loss = 0.10106266
# Iteration 1910, loss = 0.10103252
# Iteration 1911, loss = 0.10100245
# Iteration 1912, loss = 0.10097244
# Iteration 1913, loss = 0.10094249
# Iteration 1914, loss = 0.10091262
# Iteration 1915, loss = 0.10088281
# Iteration 1916, loss = 0.10085307
# Iteration 1917, loss = 0.10082339
# Iteration 1918, loss = 0.10079378
# Iteration 1919, loss = 0.10076424
# Iteration 1920, loss = 0.10073476
# Iteration 1921, loss = 0.10070535
# Iteration 1922, loss = 0.10067600
# Iteration 1923, loss = 0.10064672
# Iteration 1924, loss = 0.10061750
# Iteration 1925, loss = 0.10058836
# Iteration 1926, loss = 0.10055927
# Iteration 1927, loss = 0.10053025
# Iteration 1928, loss = 0.10050130
# Iteration 1929, loss = 0.10047241
# Iteration 1930, loss = 0.10044359
# Iteration 1931, loss = 0.10041483
# Iteration 1932, loss = 0.10038614
# Iteration 1933, loss = 0.10035751
# Iteration 1934, loss = 0.10032895
# Iteration 1935, loss = 0.10030045
# Iteration 1936, loss = 0.10027201
# Iteration 1937, loss = 0.10024365
# Iteration 1938, loss = 0.10021534
# Iteration 1939, loss = 0.10018710
# Iteration 1940, loss = 0.10015892
# Iteration 1941, loss = 0.10013081
# Iteration 1942, loss = 0.10010276
# Iteration 1943, loss = 0.10007478
# Iteration 1944, loss = 0.10004685
# Iteration 1945, loss = 0.10001900
# Iteration 1946, loss = 0.09999120
# Iteration 1947, loss = 0.09996347
# Iteration 1948, loss = 0.09993581
# Iteration 1949, loss = 0.09990820
# Iteration 1950, loss = 0.09988066
# Iteration 1951, loss = 0.09985318
# Iteration 1952, loss = 0.09982577
# Iteration 1953, loss = 0.09979842
# Iteration 1954, loss = 0.09977113
# Iteration 1955, loss = 0.09974390
# Iteration 1956, loss = 0.09971674
# Iteration 1957, loss = 0.09968964
# Iteration 1958, loss = 0.09966260
# Iteration 1959, loss = 0.09963562
# Iteration 1960, loss = 0.09960871
# Iteration 1961, loss = 0.09958186
# Iteration 1962, loss = 0.09955507
# Iteration 1963, loss = 0.09952834
# Iteration 1964, loss = 0.09950168
# Iteration 1965, loss = 0.09947507
# Iteration 1966, loss = 0.09944853
# Iteration 1967, loss = 0.09942205
# Iteration 1968, loss = 0.09939563
# Iteration 1969, loss = 0.09936927
# Iteration 1970, loss = 0.09934298
# Iteration 1971, loss = 0.09931674
# Iteration 1972, loss = 0.09929057
# Iteration 1973, loss = 0.09926446
# Iteration 1974, loss = 0.09923840
# Iteration 1975, loss = 0.09921241
# Iteration 1976, loss = 0.09918648
# Iteration 1977, loss = 0.09916061
# Iteration 1978, loss = 0.09913480
# Iteration 1979, loss = 0.09910905
# Iteration 1980, loss = 0.09908337
# Iteration 1981, loss = 0.09905774
# Iteration 1982, loss = 0.09903217
# Iteration 1983, loss = 0.09900666
# Iteration 1984, loss = 0.09898121
# Iteration 1985, loss = 0.09895583
# Iteration 1986, loss = 0.09893050
# Iteration 1987, loss = 0.09890523
# Iteration 1988, loss = 0.09888002
# Iteration 1989, loss = 0.09885487
# Iteration 1990, loss = 0.09882978
# Iteration 1991, loss = 0.09880475
# Iteration 1992, loss = 0.09877978
# Iteration 1993, loss = 0.09875487
# Iteration 1994, loss = 0.09873002
# Iteration 1995, loss = 0.09870522
# Iteration 1996, loss = 0.09868049
# Iteration 1997, loss = 0.09865581
# Iteration 1998, loss = 0.09863119
# Iteration 1999, loss = 0.09860663
# Iteration 2000, loss = 0.09858213
# Iteration 2001, loss = 0.09855769
# Iteration 2002, loss = 0.09853331
# Iteration 2003, loss = 0.09850898
# Iteration 2004, loss = 0.09848471
# Iteration 2005, loss = 0.09846050
# Iteration 2006, loss = 0.09843635
# Iteration 2007, loss = 0.09841226
# Iteration 2008, loss = 0.09838822
# Iteration 2009, loss = 0.09836424
# Iteration 2010, loss = 0.09834032
# Iteration 2011, loss = 0.09831646
# Iteration 2012, loss = 0.09829265
# Iteration 2013, loss = 0.09826890
# Iteration 2014, loss = 0.09824521
# Iteration 2015, loss = 0.09822158
# Iteration 2016, loss = 0.09819800
# Iteration 2017, loss = 0.09817448
# Iteration 2018, loss = 0.09815101
# Iteration 2019, loss = 0.09812761
# Iteration 2020, loss = 0.09810426
# Iteration 2021, loss = 0.09808096
# Iteration 2022, loss = 0.09805773
# Iteration 2023, loss = 0.09803454
# Iteration 2024, loss = 0.09801142
# Iteration 2025, loss = 0.09798835
# Iteration 2026, loss = 0.09796534
# Iteration 2027, loss = 0.09794238
# Iteration 2028, loss = 0.09791948
# Iteration 2029, loss = 0.09789663
# Iteration 2030, loss = 0.09787384
# Iteration 2031, loss = 0.09785111
# Iteration 2032, loss = 0.09782843
# Iteration 2033, loss = 0.09780581
# Iteration 2034, loss = 0.09778324
# Iteration 2035, loss = 0.09776073
# Iteration 2036, loss = 0.09773827
# Iteration 2037, loss = 0.09771587
# Iteration 2038, loss = 0.09769352
# Iteration 2039, loss = 0.09767123
# Iteration 2040, loss = 0.09764899
# Iteration 2041, loss = 0.09762681
# Iteration 2042, loss = 0.09760468
# Iteration 2043, loss = 0.09758261
# Iteration 2044, loss = 0.09756059
# Iteration 2045, loss = 0.09753862
# Iteration 2046, loss = 0.09751671
# Iteration 2047, loss = 0.09749485
# Iteration 2048, loss = 0.09747305
# Iteration 2049, loss = 0.09745130
# Iteration 2050, loss = 0.09742961
# Iteration 2051, loss = 0.09740796
# Iteration 2052, loss = 0.09738638
# Iteration 2053, loss = 0.09736484
# Iteration 2054, loss = 0.09734336
# Iteration 2055, loss = 0.09732193
# Iteration 2056, loss = 0.09730056
# Iteration 2057, loss = 0.09727924
# Iteration 2058, loss = 0.09725797
# Iteration 2059, loss = 0.09723676
# Iteration 2060, loss = 0.09721559
# Iteration 2061, loss = 0.09719449
# Iteration 2062, loss = 0.09717343
# Iteration 2063, loss = 0.09715243
# Iteration 2064, loss = 0.09713147
# Iteration 2065, loss = 0.09711058
# Iteration 2066, loss = 0.09708973
# Iteration 2067, loss = 0.09706894
# Iteration 2068, loss = 0.09704819
# Iteration 2069, loss = 0.09702750
# Iteration 2070, loss = 0.09700687
# Iteration 2071, loss = 0.09698628
# Iteration 2072, loss = 0.09696575
# Iteration 2073, loss = 0.09694526
# Iteration 2074, loss = 0.09692483
# Iteration 2075, loss = 0.09690445
# Iteration 2076, loss = 0.09688413
# Iteration 2077, loss = 0.09686385
# Iteration 2078, loss = 0.09684363
# Iteration 2079, loss = 0.09682345
# Iteration 2080, loss = 0.09680333
# Iteration 2081, loss = 0.09678326
# Iteration 2082, loss = 0.09676324
# Iteration 2083, loss = 0.09674327
# Iteration 2084, loss = 0.09672335
# Iteration 2085, loss = 0.09670348
# Iteration 2086, loss = 0.09668366
# Iteration 2087, loss = 0.09666389
# Iteration 2088, loss = 0.09664418
# Iteration 2089, loss = 0.09662451
# Iteration 2090, loss = 0.09660489
# Iteration 2091, loss = 0.09658533
# Iteration 2092, loss = 0.09656581
# Iteration 2093, loss = 0.09654634
# Iteration 2094, loss = 0.09652693
# Iteration 2095, loss = 0.09650756
# Iteration 2096, loss = 0.09648824
# Iteration 2097, loss = 0.09646897
# Iteration 2098, loss = 0.09644975
# Iteration 2099, loss = 0.09643059
# Iteration 2100, loss = 0.09641147
# Iteration 2101, loss = 0.09639240
# Iteration 2102, loss = 0.09637337
# Iteration 2103, loss = 0.09635440
# Iteration 2104, loss = 0.09633548
# Iteration 2105, loss = 0.09631660
# Iteration 2106, loss = 0.09629778
# Iteration 2107, loss = 0.09627900
# Iteration 2108, loss = 0.09626027
# Iteration 2109, loss = 0.09624159
# Iteration 2110, loss = 0.09622296
# Iteration 2111, loss = 0.09620438
# Iteration 2112, loss = 0.09618584
# Iteration 2113, loss = 0.09616735
# Iteration 2114, loss = 0.09614891
# Iteration 2115, loss = 0.09613052
# Iteration 2116, loss = 0.09611218
# Iteration 2117, loss = 0.09609389
# Iteration 2118, loss = 0.09607564
# Iteration 2119, loss = 0.09605744
# Iteration 2120, loss = 0.09603928
# Iteration 2121, loss = 0.09602118
# Iteration 2122, loss = 0.09600312
# Iteration 2123, loss = 0.09598511
# Iteration 2124, loss = 0.09596715
# Iteration 2125, loss = 0.09594923
# Iteration 2126, loss = 0.09593136
# Iteration 2127, loss = 0.09591354
# Iteration 2128, loss = 0.09589576
# Iteration 2129, loss = 0.09587803
# Iteration 2130, loss = 0.09586035
# Iteration 2131, loss = 0.09584272
# Iteration 2132, loss = 0.09582513
# Iteration 2133, loss = 0.09580758
# Iteration 2134, loss = 0.09579009
# Iteration 2135, loss = 0.09577264
# Iteration 2136, loss = 0.09575523
# Iteration 2137, loss = 0.09573787
# Iteration 2138, loss = 0.09572056
# Iteration 2139, loss = 0.09570329
# Iteration 2140, loss = 0.09568607
# Iteration 2141, loss = 0.09566890
# Iteration 2142, loss = 0.09565177
# Iteration 2143, loss = 0.09563468
# Iteration 2144, loss = 0.09561764
# Iteration 2145, loss = 0.09560065
# Iteration 2146, loss = 0.09558370
# Iteration 2147, loss = 0.09556680
# Iteration 2148, loss = 0.09554994
# Iteration 2149, loss = 0.09553313
# Iteration 2150, loss = 0.09551636
# Iteration 2151, loss = 0.09549964
# Iteration 2152, loss = 0.09548296
# Iteration 2153, loss = 0.09546632
# Iteration 2154, loss = 0.09544973
# Iteration 2155, loss = 0.09543319
# Iteration 2156, loss = 0.09541669
# Iteration 2157, loss = 0.09540023
# Iteration 2158, loss = 0.09538382
# Iteration 2159, loss = 0.09536745
# Iteration 2160, loss = 0.09535113
# Iteration 2161, loss = 0.09533485
# Iteration 2162, loss = 0.09531861
# Iteration 2163, loss = 0.09530242
# Iteration 2164, loss = 0.09528627
# Iteration 2165, loss = 0.09527016
# Iteration 2166, loss = 0.09525410
# Iteration 2167, loss = 0.09523808
# Iteration 2168, loss = 0.09522211
# Iteration 2169, loss = 0.09520618
# Iteration 2170, loss = 0.09519029
# Iteration 2171, loss = 0.09517444
# Iteration 2172, loss = 0.09515864
# Iteration 2173, loss = 0.09514288
# Iteration 2174, loss = 0.09512716
# Iteration 2175, loss = 0.09511149
# Iteration 2176, loss = 0.09509586
# Iteration 2177, loss = 0.09508027
# Iteration 2178, loss = 0.09506472
# Iteration 2179, loss = 0.09504922
# Iteration 2180, loss = 0.09503376
# Iteration 2181, loss = 0.09501834
# Iteration 2182, loss = 0.09500296
# Iteration 2183, loss = 0.09498763
# Iteration 2184, loss = 0.09497233
# Iteration 2185, loss = 0.09495708
# Iteration 2186, loss = 0.09494187
# Iteration 2187, loss = 0.09492670
# Iteration 2188, loss = 0.09491158
# Iteration 2189, loss = 0.09489649
# Iteration 2190, loss = 0.09488145
# Iteration 2191, loss = 0.09486645
# Iteration 2192, loss = 0.09485149
# Iteration 2193, loss = 0.09483657
# Iteration 2194, loss = 0.09482169
# Iteration 2195, loss = 0.09480686
# Iteration 2196, loss = 0.09479206
# Iteration 2197, loss = 0.09477730
# Iteration 2198, loss = 0.09476259
# Iteration 2199, loss = 0.09474792
# Iteration 2200, loss = 0.09473328
# Iteration 2201, loss = 0.09471869
# Iteration 2202, loss = 0.09470414
# Iteration 2203, loss = 0.09468963
# Iteration 2204, loss = 0.09467516
# Iteration 2205, loss = 0.09466073
# Iteration 2206, loss = 0.09464634
# Iteration 2207, loss = 0.09463199
# Iteration 2208, loss = 0.09461767
# Iteration 2209, loss = 0.09460340
# Iteration 2210, loss = 0.09458917
# Iteration 2211, loss = 0.09457498
# Iteration 2212, loss = 0.09456083
# Iteration 2213, loss = 0.09454672
# Iteration 2214, loss = 0.09453265
# Iteration 2215, loss = 0.09451861
# Iteration 2216, loss = 0.09450462
# Iteration 2217, loss = 0.09449066
# Iteration 2218, loss = 0.09447675
# Iteration 2219, loss = 0.09446287
# Iteration 2220, loss = 0.09444904
# Iteration 2221, loss = 0.09443524
# Iteration 2222, loss = 0.09442148
# Iteration 2223, loss = 0.09440776
# Iteration 2224, loss = 0.09439408
# Iteration 2225, loss = 0.09438043
# Iteration 2226, loss = 0.09436683
# Iteration 2227, loss = 0.09435326
# Iteration 2228, loss = 0.09433973
# Iteration 2229, loss = 0.09432624
# Iteration 2230, loss = 0.09431279
# Iteration 2231, loss = 0.09429938
# Iteration 2232, loss = 0.09428600
# Iteration 2233, loss = 0.09427267
# Iteration 2234, loss = 0.09425937
# Iteration 2235, loss = 0.09424610
# Iteration 2236, loss = 0.09423288
# Iteration 2237, loss = 0.09421969
# Iteration 2238, loss = 0.09420654
# Iteration 2239, loss = 0.09419343
# Iteration 2240, loss = 0.09418036
# Iteration 2241, loss = 0.09416732
# Iteration 2242, loss = 0.09415432
# Iteration 2243, loss = 0.09414136
# Iteration 2244, loss = 0.09412844
# Iteration 2245, loss = 0.09411555
# Iteration 2246, loss = 0.09410270
# Iteration 2247, loss = 0.09408988
# Iteration 2248, loss = 0.09407710
# Iteration 2249, loss = 0.09406436
# Iteration 2250, loss = 0.09405166
# Iteration 2251, loss = 0.09403899
# Iteration 2252, loss = 0.09402636
# Iteration 2253, loss = 0.09401376
# Iteration 2254, loss = 0.09400121
# Iteration 2255, loss = 0.09398868
# Iteration 2256, loss = 0.09397620
# Iteration 2257, loss = 0.09396375
# Iteration 2258, loss = 0.09395133
# Iteration 2259, loss = 0.09393895
# Iteration 2260, loss = 0.09392661
# Iteration 2261, loss = 0.09391430
# Iteration 2262, loss = 0.09390203
# Iteration 2263, loss = 0.09388980
# Iteration 2264, loss = 0.09387760
# Iteration 2265, loss = 0.09386543
# Iteration 2266, loss = 0.09385330
# Iteration 2267, loss = 0.09384121
# Iteration 2268, loss = 0.09382915
# Iteration 2269, loss = 0.09381713
# Iteration 2270, loss = 0.09380514
# Iteration 2271, loss = 0.09379318
# Iteration 2272, loss = 0.09378126
# Iteration 2273, loss = 0.09376938
# Iteration 2274, loss = 0.09375753
# Iteration 2275, loss = 0.09374572
# Iteration 2276, loss = 0.09373394
# Iteration 2277, loss = 0.09372219
# Iteration 2278, loss = 0.09371048
# Iteration 2279, loss = 0.09369880
# Iteration 2280, loss = 0.09368716
# Iteration 2281, loss = 0.09367555
# Iteration 2282, loss = 0.09366398
# Iteration 2283, loss = 0.09365244
# Iteration 2284, loss = 0.09364093
# Iteration 2285, loss = 0.09362946
# Iteration 2286, loss = 0.09361802
# Iteration 2287, loss = 0.09360661
# Iteration 2288, loss = 0.09359524
# Iteration 2289, loss = 0.09358391
# Iteration 2290, loss = 0.09357260
# Iteration 2291, loss = 0.09356133
# Iteration 2292, loss = 0.09355010
# Iteration 2293, loss = 0.09353889
# Iteration 2294, loss = 0.09352772
# Iteration 2295, loss = 0.09351658
# Iteration 2296, loss = 0.09350548
# Iteration 2297, loss = 0.09349441
# Iteration 2298, loss = 0.09348337
# Iteration 2299, loss = 0.09347236
# Iteration 2300, loss = 0.09346139
# Iteration 2301, loss = 0.09345045
# Iteration 2302, loss = 0.09343954
# Iteration 2303, loss = 0.09342867
# Iteration 2304, loss = 0.09341783
# Iteration 2305, loss = 0.09340702
# Iteration 2306, loss = 0.09339624
# Iteration 2307, loss = 0.09338549
# Iteration 2308, loss = 0.09337478
# Iteration 2309, loss = 0.09336410
# Iteration 2310, loss = 0.09335345
# Iteration 2311, loss = 0.09334283
# Iteration 2312, loss = 0.09333225
# Iteration 2313, loss = 0.09332169
# Iteration 2314, loss = 0.09331117
# Iteration 2315, loss = 0.09330068
# Iteration 2316, loss = 0.09329022
# Iteration 2317, loss = 0.09327980
# Iteration 2318, loss = 0.09326940
# Iteration 2319, loss = 0.09325904
# Iteration 2320, loss = 0.09324870
# Iteration 2321, loss = 0.09323840
# Iteration 2322, loss = 0.09322813
# Iteration 2323, loss = 0.09321789
# Iteration 2324, loss = 0.09320768
# Iteration 2325, loss = 0.09319751
# Iteration 2326, loss = 0.09318736
# Iteration 2327, loss = 0.09317725
# Iteration 2328, loss = 0.09316716
# Iteration 2329, loss = 0.09315711
# Iteration 2330, loss = 0.09314708
# Iteration 2331, loss = 0.09313709
# Iteration 2332, loss = 0.09312713
# Iteration 2333, loss = 0.09311719
# Iteration 2334, loss = 0.09310729
# Iteration 2335, loss = 0.09309742
# Iteration 2336, loss = 0.09308758
# Iteration 2337, loss = 0.09307777
# Iteration 2338, loss = 0.09306799
# Iteration 2339, loss = 0.09305823
# Iteration 2340, loss = 0.09304851
# Iteration 2341, loss = 0.09303882
# Training loss did not improve more than tol=0.000010 for 10 consecutive epochs. Stopping.
# [0.28945459]
# [5.88713522]
# 0.724263617356077
