# %% [markdown]
# # SWMAL Exercise
#
# ## Intro
#
#
# We startup by reusing parts of `01_the_machine_learning_landscape.ipynb` from GÃ©ron [GITHOML]. So we begin with what GÃ©ron says about life satisfactions vs GDP per capita.
#
# Halfway down this notebook, a list of questions for SWMAL is presented.

# %% [markdown]
# ## Chapter 1 â€“ The Machine Learning landscape
#
# _This is the code used to generate some of the figures in chapter 1._

# %% [markdown]
# ### Setup
#
# First, let's make sure this notebook works well in both python 2 and 3, import a few common modules, ensure MatplotLib plots figures inline and prepare a function to save the figures:

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "fundamentals"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("IGNORING: Saving figure", fig_id) # SWMAL: I've disabled saving of figures
    #if tight_layout:
    #    plt.tight_layout()
    #plt.savefig(path, format='png', dpi=300)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

print("OK")
# Out:
# OK

# %% [markdown]
# ### Code example 1-1
#
# This function just merges the OECD's life satisfaction data and the IMF's GDP per capita data. It's a bit too long and boring and it's not specific to Machine Learning, which is why I left it out of the book.

# %%
def prepare_country_stats(oecd_bli, gdp_per_capita):
    oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
    oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
    gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
    gdp_per_capita.set_index("Country", inplace=True)
    full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,
                                  left_index=True, right_index=True)
    full_country_stats.sort_values(by="GDP per capita", inplace=True)
    remove_indices = [0, 1, 6, 8, 33, 34, 35]
    keep_indices = list(set(range(36)) - set(remove_indices))
    return full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[keep_indices]

print("OK")
# Out:
# OK

# %% [markdown]
# The code in the book expects the data files to be located in the current directory. I just tweaked it here to fetch the files in datasets/lifesat.

# %%
import os
datapath = os.path.join("./datasets", "lifesat", "")

# NOTE: a ! prefix makes us able to run system commands..
# (command 'dir' for windows, 'ls' for Linux or Macs)
#

! dir

print("\nOK")
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 0451-3530
#
#  Directory of c:\Users\mariu\Desktop\6 semester\MAL\Opgaver\L1-opgave\O1
#
# 21/02/2022  08.11    <DIR>          .
# 21/02/2022  08.11    <DIR>          ..
# 21/02/2022  08.11    <DIR>          datasets
# 21/02/2022  08.11           370.250 intro.ipynb
#                1 File(s)        370.250 bytes
#                3 Dir(s)  116.496.310.272 bytes free
#
# OK

# %%
# Code example
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# Load the data
try:
    oecd_bli = pd.read_csv(datapath + "oecd_bli_2015.csv", thousands=',')
    gdp_per_capita = pd.read_csv(datapath + "gdp_per_capita.csv",thousands=',',delimiter='\t',
                             encoding='latin1', na_values="n/a")
except Exception as e:
    print(f"SWMAL NOTE: well, you need to have the 'datasets' dir in path, please unzip 'datasets.zip' and make sure that its included in the datapath='{datapath}' setting in the cell above..")
    raise e
    
# Prepare the data
country_stats = prepare_country_stats(oecd_bli, gdp_per_capita)
X = np.c_[country_stats["GDP per capita"]]
y = np.c_[country_stats["Life satisfaction"]]

# Visualize the data
country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
plt.show()

# Select a linear model
model = sklearn.linear_model.LinearRegression()

# Train the model
model.fit(X, y)

# Make a prediction for Cyprus
X_new = [[22587]]  # Cyprus' GDP per capita
y_pred = model.predict(X_new)
print(y_pred) # outputs [[ 5.96242338]]

print("OK")
# Out:
# [[5.96242338]]
# OK

# %% [markdown]
# ## SWMAL
#
# Now we plot the linear regression result.
#
# Just ignore all the data plotter code mumbo-jumbo here (code take dirclty from the notebook, [GITHOML])...and see the final plot.

# %%
oecd_bli = pd.read_csv(datapath + "oecd_bli_2015.csv", thousands=',')
oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
#oecd_bli.head(2)

gdp_per_capita = pd.read_csv(datapath+"gdp_per_capita.csv", thousands=',', delimiter='\t',
                             encoding='latin1', na_values="n/a")
gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
gdp_per_capita.set_index("Country", inplace=True)
#gdp_per_capita.head(2)

full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita, left_index=True, right_index=True)
full_country_stats.sort_values(by="GDP per capita", inplace=True)
#full_country_stats

remove_indices = [0, 1, 6, 8, 33, 34, 35]
keep_indices = list(set(range(36)) - set(remove_indices))

sample_data = full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[keep_indices]
#missing_data = full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[remove_indices]

sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(5,3))
plt.axis([0, 60000, 0, 10])
position_text = {
    "Hungary": (5000, 1),
    "Korea": (18000, 1.7),
    "France": (29000, 2.4),
    "Australia": (40000, 3.0),
    "United States": (52000, 3.8),
}
for country, pos_text in position_text.items():
    pos_data_x, pos_data_y = sample_data.loc[country]
    country = "U.S." if country == "United States" else country
    plt.annotate(country, xy=(pos_data_x, pos_data_y), xytext=pos_text,
            arrowprops=dict(facecolor='black', width=0.5, shrink=0.1, headwidth=5))
    plt.plot(pos_data_x, pos_data_y, "ro")
#save_fig('money_happy_scatterplot')
plt.show()

from sklearn import linear_model
lin1 = linear_model.LinearRegression()
Xsample = np.c_[sample_data["GDP per capita"]]
ysample = np.c_[sample_data["Life satisfaction"]]
lin1.fit(Xsample, ysample)

t0 = 4.8530528
t1 = 4.91154459e-05

sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(5,3))
plt.axis([0, 60000, 0, 10])
M=np.linspace(0, 60000, 1000)
plt.plot(M, t0 + t1*M, "b")
plt.text(5000, 3.1, r"$\theta_0 = 4.85$", fontsize=14, color="b")
plt.text(5000, 2.2, r"$\theta_1 = 4.91 \times 10^{-5}$", fontsize=14, color="b")
#save_fig('best_fit_model_plot')
plt.show()

print("OK")
# Out:
# OK

# %% [markdown]
# ## Ultra-brief Intro to the Fit-Predict Interface in Scikit-learn
#
# OK, the important lines in the cells above are really just
# ```python
# #Select a linear model
# model = sklearn.linear_model.LinearRegression()
#
# # Train the model
# model.fit(X, y)
#
# # Make a prediction for Cyprus
# X_new = [[22587]]  # Cyprus' GDP per capita
# y_pred = model.predict(X_new)
# print(y_pred) # outputs [[ 5.96242338]]
#
# ```
#
# What happens here is that we create  model, called LinearRegression (for now just a 100% black-box method), put in our data training $\mathbf{X}$ matrix and corresponding desired training ground thruth vector $\mathbf{y}$ (aka $\mathbf{y}_{true})$, and then train the model.
#
# After training we extract a _predicted_ $\mathbf{y}_{pred}$ vector from the model, for some input scalar $x$=22587.
#
#
# ### Supervised Training via Fit-predict
#
# The train-predict (or train-fit) process on some data can be visualized as
#
# <img src="https://itundervisning.ase.au.dk/SWMAL/L01/Figs/supervised_learning.png" alt="WARNING: could not get image from server." style="height:250px">
#
# In this figure the untrained model is a `sklearn.linear_model.LinearRegression` python object. When trained via  `model.fit()`, using some know answers for the data, $\mathbf{y}_{true}~$, it becomes a blue-boxed trained model.
#
# The trained model can be used to _predict_ values from new, yet-unseen, data, via the `model.predict()` function.
#
# In other words, how high is life-satisfaction for Cyprus' GDP=22587 USD?
#
# Just call `model.predict()` on a matrix with one single numerical element, 22587, well, not a matrix really, but a python list-of-lists, `[[22587]]`
#
# ```y_pred = model.predict([[22587]])```
#
# Apparently 5.96 the models answers!
#
# (you get used to the python built-in containers and numpy on the way..)

# %% [markdown]
# ### Qa) The $\theta$ parameters and the $R^2$ Score
#
# GÃ©ron uses some $\theta$ parameter from this linear regression model, in his examples and plots above.
#
# How do you extract the $\theta_0$ and $\theta_1$ coefficients in his life-satisfaction figure form the linear regression model, via the models python attributes?
#
# Read the documentation for the linear regressor at
#
# http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
#
# Extract the score=0.734 for the model using data (X,y) and explain what $R^2$ score measures in broad terms
#
# $$
# \begin{array}{rcll}
#     R^2 &=& 1 - u/v\\
#     u   &=& \sum (y_{true} - y_{pred}~)^2   ~~~&\small \mbox{residual sum of squares}\\
#     v   &=& \sum (y_{true} - \mu_{true}~)^2 ~~~&\small \mbox{total sum of squares}
# \end{array}
# $$
#
# with $y_{true}~$ being the true data, $y_{pred}~$ being the predicted data from the model and $\mu_{true}~$ being the true mean of the data.
#
# What are the minimum and maximum values for $R^2~$?
#
# Is it best to have a low $R^2$ score or a high $R^2$ score? This means, is $R^2$ a loss/cost function or a function that measures of fitness/goodness?
#
# NOTE$_1$: the $R^2$ is just one of many scoring functions used in ML, we will see plenty more other methods later.
#
# NOTE$_2$: there are different definitions of the $R^2$, 'coefficient of determination', in linear algebra. We stricly use the formulation above.
#
# OPTIONAL: Read the additional in-depth literature on $R^2~$:
#
# > https://en.wikipedia.org/wiki/Coefficient_of_determination

# %%
# This is to find t0 and t1 
X = lin1.intercept_
Y = lin1.coef_

print(X)
print(Y)

#Extract score with test data
test_samples = pd.read_csv(datapath + "lifesat.csv", thousands=',')

Xsample = np.c_[test_samples["GDP per capita"]]
ysample = np.c_[test_samples["Life satisfaction"]]
score = lin1.score(Xsample, ysample)

print(score) #0.734

# The highest score is 1.0, as in 100% of tests were predicted correctly.

# It is better to have a higher score, since the maximum can be 1.0, and the minimum can be negative infinity.
# The coefficient shows that the regression model fits the observed data ~73%. 
# The coefficient is a measure of fitness/goodness, since it describes its relation to a set of data. 
# A coefficient of 1.0, means that all data has been accounted for, it's a perfect fit.
# Out:
# [4.8530528]
# [[4.91154459e-05]]
# 0.734441435543703

# %% [markdown]
# ## The Merits of the Fit-Predict Interface
#
# Now comes the really fun part: all methods in Scikit-learn have this fit-predict interface, and you can easily interchange models in your code just by instantiating a new and perhaps better ML model.
#
# There are still a lot of per-model parameters to tune, but fortunately, the built-in default values provide you with a good initial guess for good model setup.
#
# Later on, you might want to go into the parameter detail trying to optimize some params (opening the lid of the black-box ML algo), but for now, we pretty much stick to the default values.
#
# Let's try to replace the linear regression now, let's test a _k-nearest neighbour algorithm_ instead (still black boxed algorithm-wise)...
#
#
# ### Qb) Using k-Nearest Neighbors
#
# Change the linear regression model to a `sklearn.neighbors.KNeighborsRegressor` with k=3 (as in [HOML:p.22,bottom]), and rerun the `fit` and `predict` using this new model.
#
# What do the k-nearest neighbours estimate for Cyprus, compared to the linear regression (it should yield=5.77)?
#
# What _score-method_ does the k-nearest model use, and is it comparable to the linear regression model?
#
# Seek out the documentation in Scikit-learn, if the scoring methods are not equal, can they be compared to each other at all then?
#
# Remember to put pointer/text from the Sckikit-learn documentation in the journal...(did you find the right kNN model etc.)

# %%
# this is our raw data set:
sample_data
# Out:
#                  GDP per capita  Life satisfaction
# Country
# Russia                 9054.914                6.0
# Turkey                 9437.372                5.6
# Hungary               12239.894                4.9
# Poland                12495.334                5.8
# Slovak Republic       15991.736                6.1
# Estonia               17288.083                5.6
# Greece                18064.288                4.8
# Portugal              19121.592                5.1
# Slovenia              20732.482                5.7
# Spain                 25864.721                6.5
# Korea                 27195.197                5.8
# Italy                 29866.581                6.0
# Japan                 32485.545                5.9
# Israel                35343.336                7.4
# New Zealand           37044.891                7.3
# France                37675.006                6.5
# Belgium               40106.632                6.9
# Germany               40996.511                7.0
# Finland               41973.988                7.4
# Canada                43331.961                7.3
# Netherlands           43603.115                7.3
# Austria               43724.031                6.9
# United Kingdom        43770.688                6.8
# Sweden                49866.266                7.2
# Iceland               50854.583                7.5
# Australia             50961.865                7.3
# Ireland               51350.744                7.0
# Denmark               52114.165                7.5
# United States         55805.204                7.2

# %%
# and this is our preprocessed data
country_stats
# Out:
#                  GDP per capita  Life satisfaction
# Country
# Russia                 9054.914                6.0
# Turkey                 9437.372                5.6
# Hungary               12239.894                4.9
# Poland                12495.334                5.8
# Slovak Republic       15991.736                6.1
# Estonia               17288.083                5.6
# Greece                18064.288                4.8
# Portugal              19121.592                5.1
# Slovenia              20732.482                5.7
# Spain                 25864.721                6.5
# Korea                 27195.197                5.8
# Italy                 29866.581                6.0
# Japan                 32485.545                5.9
# Israel                35343.336                7.4
# New Zealand           37044.891                7.3
# France                37675.006                6.5
# Belgium               40106.632                6.9
# Germany               40996.511                7.0
# Finland               41973.988                7.4
# Canada                43331.961                7.3
# Netherlands           43603.115                7.3
# Austria               43724.031                6.9
# United Kingdom        43770.688                6.8
# Sweden                49866.266                7.2
# Iceland               50854.583                7.5
# Australia             50961.865                7.3
# Ireland               51350.744                7.0
# Denmark               52114.165                7.5
# United States         55805.204                7.2

# %%
# Prepare the data
X = np.c_[country_stats["GDP per capita"]]
y = np.c_[country_stats["Life satisfaction"]]

print("X.shape=",X.shape)
print("y.shape=",y.shape)

# Visualize the data
country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
plt.show()

# Select and train a model
from sklearn.neighbors import KNeighborsRegressor
lin2 = KNeighborsRegressor(n_neighbors=3)
lin2.fit(Xsample, ysample)
cypruspred = lin2.predict([[22587]])    # Predict for Cyprus on the KNearestNeighbour model
print(cypruspred)                       # 5.76 repeating, is pretty close to the expected value.
                                        # The Linear Model was shown to predict 5.96, 
                                        # so the models did predict a little bit differently.

#Extract score with test data
test_samples = pd.read_csv(datapath + "lifesat.csv", thousands=',')

Xsample = np.c_[test_samples["GDP per capita"]]
ysample = np.c_[test_samples["Life satisfaction"]]
score = lin2.score(Xsample, ysample)

print(score) #Output is 0.85

# The two scoring functions for Linear and KNearestNeighbour are the same.
# However, since the models themselves train in different ways,
# we observe a different resulting score.
# Out:
# X.shape= (29, 1)
# y.shape= (29, 1)
# [[5.76666667]]
# 0.8525732853499179

# %% [markdown]
# ### Qc) Tuning Parameter for k-Nearest Neighbors and A Sanity Check
#
# But that not the full story. Try plotting the prediction for both models in the same graph and tune the `k_neighbor` parameter of the `KNeighborsRegressor` model.
#
# Choosing `k_neighbor=1` produces a nice `score=1`, that seems optimal...but is it really so good?
#
# Plotting the two models in a 'Life Satisfaction-vs-GDP capita' 2D plot by creating an array in the range 0 to 60000 (USD) (the `M` matrix below) and then predict the corresponding y value will shed some light to this.
#
# Now reusing the plots stubs below, try to explain why the k-nearest neighbour with `k_neighbor=1` has such a good score.
#
# Does a score=1 with `k_neighbor=1`also mean that this would be the prefered estimator for the job?
#
# Hint here is a similar plot of a KNN for a small set of different k's:
#
# <img src="https://itundervisning.ase.au.dk/SWMAL/L01/Figs/regression_with_knn.png"  alt="WARNING: could not get image from server." style="height:150px">

# %%
sample_data.plot(kind='scatter', x="GDP per capita", y='Life satisfaction', figsize=(12,7))
plt.axis([0, 60000, 0, 10])

# create an test matrix M, with the same dimensionality as X, and in the range [0;60000] 
# and a step size of your choice
m=np.linspace(0, 60000, 1000)
M=np.empty([m.shape[0],1])
M[:,0]=m

lin3 = KNeighborsRegressor(n_neighbors=1)
lin4 = KNeighborsRegressor(n_neighbors=2)
lin3.fit(Xsample, ysample)
lin4.fit(Xsample, ysample)

# from this test M data, predict the y values via the lin.reg. and k-nearest models
y_pred_lin = lin1.predict(M)
y_pred_knn = lin2.predict(M)   # ASSUMING the variable name 'knn' of your KNeighborsRegressor 
y_pred_knn2 = lin3.predict(M)
y_pred_knn3 = lin4.predict(M)   # ASSUMING the variable name 'knn' of your KNeighborsRegressor 

# use plt.plot to plot x-y into the sample_data plot..
plt.plot(m, y_pred_lin, "r")
plt.plot(m, y_pred_knn, "b")
plt.plot(m, y_pred_knn2, "g")
plt.plot(m, y_pred_knn3, "y")

# The fewer n_neighbors, the closer the model trends towards the training points
# n = 1 makes a perfect fit, but it's perfect for the training data and not necessarily all possible data that could end up being tested
# This is what is generally referred to as "Over-fitting" the train data.

# %% [markdown]
# ### Qd) Trying out a Neural Network
#
# Let us then try a Neural Network on the data, using the fit-predict interface allows us to replug a new model into our existing code.
#
# There are a number of different NN's available, let's just hook into Scikit-learns Multi-Layer Perceptron for regression, that is an 'MLPRegressor'.
#
# Now, the data-set for training the MLP is really not well scaled, so we need to tweak a lot of parameters in the MLP just to get it to produce some sensible output: with out preprocessing and scaling of the input data, `X`, the MLP is really a bad choice of model for the job since it so easily produces garbage output.
#
# Try training the `mlp` regression model below, predict the value for Cyprus, and find the `score` value for the training set...just as we did for the linear and KNN models.
#
# Can the `MLPRegressor` score function be compared with the linear and KNN-scores?

# %%
from sklearn.neural_network import MLPRegressor

# Setup MLPRegressor
mlp = MLPRegressor( hidden_layer_sizes=(10,), solver='adam', activation='relu', tol=1E-5, max_iter=100000, verbose=True)
mlp.fit(X, y.ravel())

# lets make a MLP regressor prediction and redo the plots
y_pred_mlp = mlp.predict(M) 

plt.plot(m, y_pred_lin, "r")
plt.plot(m, y_pred_knn, "b")
plt.plot(m, y_pred_mlp, "k")

print(mlp.predict([[22587]]))

#Extract score with test data
test_samples = pd.read_csv(datapath + "lifesat.csv", thousands=',')

Xsample = np.c_[test_samples["GDP per capita"]]
ysample = np.c_[test_samples["Life satisfaction"]]
score = mlp.score(Xsample, ysample)
print(score)
# The score function is identical to Lin.Reg and KNN.Reg, but as we observed previously when comparing Lin and KNN,
# we once again observe the MLP model itself differs from the other two and thus produces a different score.
# Out:
# Iteration 1, loss = 290434295.23044360
# Iteration 2, loss = 286926974.91845930
# Iteration 3, loss = 283445091.80120468
# Iteration 4, loss = 279989007.88284469
# Iteration 5, loss = 276559070.05886549
# Iteration 6, loss = 273155609.32856679
# Iteration 7, loss = 269778940.07033998
# Iteration 8, loss = 266429359.38609853
# Iteration 9, loss = 263107146.52031821
# Iteration 10, loss = 259812562.35816029
# Iteration 11, loss = 256545849.00610605
# Iteration 12, loss = 253307229.45747611
# Iteration 13, loss = 250096907.34413815
# Iteration 14, loss = 246915066.77466321
# Iteration 15, loss = 243761872.25819016
# Iteration 16, loss = 240637468.71230754
# Iteration 17, loss = 237541981.55239332
# Iteration 18, loss = 234475516.85906243
# Iteration 19, loss = 231438161.61967900
# Iteration 20, loss = 228429984.03930050
# Iteration 21, loss = 225451033.91592681
# Iteration 22, loss = 222501343.07455081
# Iteration 23, loss = 219580925.85422322
# Iteration 24, loss = 216689779.64216983
# Iteration 25, loss = 213827885.44891000
# Iteration 26, loss = 210995208.51833686
# Iteration 27, loss = 208191698.96679541
# Iteration 28, loss = 205417292.44535619
# Iteration 29, loss = 202671910.81969425
# Iteration 30, loss = 199955462.86225188
# Iteration 31, loss = 197267844.95167449
# Iteration 32, loss = 194608941.77484995
# Iteration 33, loss = 191978627.02724859
# Iteration 34, loss = 189376764.10764295
# Iteration 35, loss = 186803206.80367702
# Iteration 36, loss = 184257799.96514291
# Iteration 37, loss = 181740380.16221151
# Iteration 38, loss = 179250776.32624131
# Iteration 39, loss = 176788810.37114519
# Iteration 40, loss = 174354297.79365045
# Iteration 41, loss = 171947048.25110018
# Iteration 42, loss = 169566866.11575755
# Iteration 43, loss = 167213551.00484595
# Iteration 44, loss = 164886898.28581721
# Iteration 45, loss = 162586699.55657044
# Iteration 46, loss = 160312743.10055020
# Iteration 47, loss = 158064814.31683558
# Iteration 48, loss = 155842696.12549382
# Iteration 49, loss = 153646169.34860966
# Iteration 50, loss = 151475013.06751981
# Iteration 51, loss = 149329004.95688277
# Iteration 52, loss = 147207921.59629363
# Iteration 53, loss = 145111538.76022065
# Iteration 54, loss = 143039631.68709087
# Iteration 55, loss = 140991975.32838824
# Iteration 56, loss = 138968344.57865524
# Iteration 57, loss = 136968514.48730263
# Iteration 58, loss = 134992260.45313832
# Iteration 59, loss = 133039358.40252551
# Iteration 60, loss = 131109584.95206930
# Iteration 61, loss = 129202717.55671819
# Iteration 62, loss = 127318534.64414711
# Iteration 63, loss = 125456815.73626377
# Iteration 64, loss = 123617341.55865660
# Iteration 65, loss = 121799894.13876976
# Iteration 66, loss = 120004256.89356244
# Iteration 67, loss = 118230214.70737669
# Iteration 68, loss = 116477554.00070480
# Iteration 69, loss = 114746062.79051290
# Iteration 70, loss = 113035530.74274607
# Iteration 71, loss = 111345749.21760386
# Iteration 72, loss = 109676511.30814496
# Iteration 73, loss = 108027611.87274545
# Iteration 74, loss = 106398847.56190489
# Iteration 75, loss = 104790016.83986317
# Iteration 76, loss = 103200920.00146291
# Iteration 77, loss = 101631359.18466167
# Iteration 78, loss = 100081138.37907490
# Iteration 79, loss = 98550063.43090010
# Iteration 80, loss = 97037942.04455307
# Iteration 81, loss = 95544583.78132014
# Iteration 82, loss = 94069800.05530959
# Iteration 83, loss = 92613404.12696616
# Iteration 84, loss = 91175211.09439014
# Iteration 85, loss = 89755037.88268732
# Iteration 86, loss = 88352703.23155566
# Iteration 87, loss = 86968027.68130206
# Iteration 88, loss = 85600833.55746408
# Iteration 89, loss = 84250944.95419994
# Iteration 90, loss = 82918187.71659584
# Iteration 91, loss = 81602389.42202777
# Iteration 92, loss = 80303379.36070360
# Iteration 93, loss = 79020988.51550117
# Iteration 94, loss = 77755049.54120794
# Iteration 95, loss = 76505396.74325839
# Iteration 96, loss = 75271866.05605870
# Iteration 97, loss = 74054295.02097797
# Iteration 98, loss = 72852522.76408069
# Iteration 99, loss = 71666389.97366713
# Iteration 100, loss = 70495738.87768234
# Iteration 101, loss = 69340413.22104983
# Iteration 102, loss = 68200258.24297996
# Iteration 103, loss = 67075120.65429863
# Iteration 104, loss = 65964848.61483804
# Iteration 105, loss = 64869291.71092642
# Iteration 106, loss = 63788300.93301106
# Iteration 107, loss = 62721728.65344451
# Iteration 108, loss = 61669428.60446202
# Iteration 109, loss = 60631255.85637417
# Iteration 110, loss = 59607066.79599745
# Iteration 111, loss = 58596719.10534193
# Iteration 112, loss = 57600071.74057399
# Iteration 113, loss = 56616984.91126953
# Iteration 114, loss = 55647320.05997168
# Iteration 115, loss = 54690939.84206531
# Iteration 116, loss = 53747708.10597886
# Iteration 117, loss = 52817489.87372302
# Iteration 118, loss = 51900151.32177443
# Iteration 119, loss = 50995559.76231125
# Iteration 120, loss = 50103583.62480697
# Iteration 121, loss = 49224092.43798707
# Iteration 122, loss = 48356956.81215288
# Iteration 123, loss = 47502048.42187629
# Iteration 124, loss = 46659239.98906756
# Iteration 125, loss = 45828405.26641854
# Iteration 126, loss = 45009419.02122275
# Iteration 127, loss = 44202157.01957307
# Iteration 128, loss = 43406496.01093756
# Iteration 129, loss = 42622313.71311320
# Iteration 130, loss = 41849488.79755717
# Iteration 131, loss = 41087900.87509485
# Iteration 132, loss = 40337430.48200315
# Iteration 133, loss = 39597959.06646779
# Iteration 134, loss = 38869368.97541259
# Iteration 135, loss = 38151543.44169848
# Iteration 136, loss = 37444366.57169053
# Iteration 137, loss = 36747723.33318929
# Iteration 138, loss = 36061499.54372469
# Iteration 139, loss = 35385581.85920878
# Iteration 140, loss = 34719857.76294433
# Iteration 141, loss = 34064215.55498595
# Iteration 142, loss = 33418544.34184999
# Iteration 143, loss = 32782734.02656958
# Iteration 144, loss = 32156675.29909116
# Iteration 145, loss = 31540259.62700796
# Iteration 146, loss = 30933379.24662696
# Iteration 147, loss = 30335927.15436451
# Iteration 148, loss = 29747797.09846660
# Iteration 149, loss = 29168883.57104910
# Iteration 150, loss = 28599081.80045348
# Iteration 151, loss = 28038287.74391321
# Iteration 152, loss = 27486398.08052622
# Iteration 153, loss = 26943310.20452822
# Iteration 154, loss = 26408922.21886230
# Iteration 155, loss = 25883132.92903953
# Iteration 156, loss = 25365841.83728523
# Iteration 157, loss = 24856949.13696606
# Iteration 158, loss = 24356355.70729241
# Iteration 159, loss = 23863963.10829058
# Iteration 160, loss = 23379673.57603966
# Iteration 161, loss = 22903390.01816720
# Iteration 162, loss = 22435016.00959824
# Iteration 163, loss = 21974455.78855223
# Iteration 164, loss = 21521614.25278156
# Iteration 165, loss = 21076396.95604661
# Iteration 166, loss = 20638710.10482106
# Iteration 167, loss = 20208460.55522152
# Iteration 168, loss = 19785555.81015583
# Iteration 169, loss = 19369904.01668378
# Iteration 170, loss = 18961413.96358429
# Iteration 171, loss = 18559995.07912304
# Iteration 172, loss = 18165557.42901421
# Iteration 173, loss = 17778011.71457046
# Iteration 174, loss = 17397269.27103463
# Iteration 175, loss = 17023242.06608719
# Iteration 176, loss = 16655842.69852301
# Iteration 177, loss = 16294984.39709119
# Iteration 178, loss = 15940581.01949180
# Iteration 179, loss = 15592547.05152283
# Iteration 180, loss = 15250797.60637148
# Iteration 181, loss = 14915248.42404304
# Iteration 182, loss = 14585815.87092120
# Iteration 183, loss = 14262416.93945337
# Iteration 184, loss = 13944969.24795465
# Iteration 185, loss = 13633391.04052399
# Iteration 186, loss = 13327601.18706645
# Iteration 187, loss = 13027519.18341484
# Iteration 188, loss = 12733065.15154476
# Iteration 189, loss = 12444159.83987650
# Iteration 190, loss = 12160724.62365762
# Iteration 191, loss = 11882681.50541995
# Iteration 192, loss = 11609953.11550478
# Iteration 193, loss = 11342462.71265005
# Iteration 194, loss = 11080134.18463338
# Iteration 195, loss = 10822892.04896490
# Iteration 196, loss = 10570661.45362386
# Iteration 197, loss = 10323368.17783287
# Iteration 198, loss = 10080938.63286410
# Iteration 199, loss = 9843299.86287133
# Iteration 200, loss = 9610379.54574224
# Iteration 201, loss = 9382105.99396509
# Iteration 202, loss = 9158408.15550429
# Iteration 203, loss = 8939215.61467916
# Iteration 204, loss = 8724458.59304044
# Iteration 205, loss = 8514067.95023934
# Iteration 206, loss = 8307975.18488352
# Iteration 207, loss = 8106112.43537512
# Iteration 208, loss = 7908412.48072557
# Iteration 209, loss = 7714808.74134230
# Iteration 210, loss = 7525235.27978238
# Iteration 211, loss = 7339626.80146846
# Iteration 212, loss = 7157918.65536230
# Iteration 213, loss = 6980046.83459133
# Iteration 214, loss = 6805947.97702397
# Iteration 215, loss = 6635559.36578939
# Iteration 216, loss = 6468818.92973753
# Iteration 217, loss = 6305665.24383542
# Iteration 218, loss = 6146037.52949602
# Iteration 219, loss = 5989875.65483573
# Iteration 220, loss = 5837120.13485700
# Iteration 221, loss = 5687712.13155279
# Iteration 222, loss = 5541593.45392930
# Iteration 223, loss = 5398706.55794408
# Iteration 224, loss = 5258994.54635637
# Iteration 225, loss = 5122401.16848696
# Iteration 226, loss = 4988870.81988471
# Iteration 227, loss = 4858348.54189740
# Iteration 228, loss = 4730780.02114440
# Iteration 229, loss = 4606111.58888891
# Iteration 230, loss = 4484290.22030787
# Iteration 231, loss = 4365263.53365746
# Iteration 232, loss = 4248979.78933253
# Iteration 233, loss = 4135387.88881833
# Iteration 234, loss = 4024437.37353312
# Iteration 235, loss = 3916078.42356042
# Iteration 236, loss = 3810261.85626962
# Iteration 237, loss = 3706939.12482428
# Iteration 238, loss = 3606062.31657691
# Iteration 239, loss = 3507584.15134995
# Iteration 240, loss = 3411457.97960219
# Iteration 241, loss = 3317637.78048037
# Iteration 242, loss = 3226078.15975571
# Iteration 243, loss = 3136734.34764542
# Iteration 244, loss = 3049562.19651906
# Iteration 245, loss = 2964518.17849018
# Iteration 246, loss = 2881559.38289354
# Iteration 247, loss = 2800643.51364831
# Iteration 248, loss = 2721728.88650806
# Iteration 249, loss = 2644774.42619820
# Iteration 250, loss = 2569739.66344175
# Iteration 251, loss = 2496584.73187455
# Iteration 252, loss = 2425270.36485105
# Iteration 253, loss = 2355757.89214181
# Iteration 254, loss = 2288009.23652427
# Iteration 255, loss = 2221986.91026821
# Iteration 256, loss = 2157654.01151748
# Iteration 257, loss = 2094974.22056970
# Iteration 258, loss = 2033911.79605584
# Iteration 259, loss = 1974431.57102147
# Iteration 260, loss = 1916498.94891168
# Iteration 261, loss = 1860079.89946193
# Iteration 262, loss = 1805140.95449668
# Iteration 263, loss = 1751649.20363845
# Iteration 264, loss = 1699572.28992923
# Iteration 265, loss = 1648878.40536702
# Iteration 266, loss = 1599536.28635959
# Iteration 267, loss = 1551515.20909837
# Iteration 268, loss = 1504784.98485476
# Iteration 269, loss = 1459315.95520161
# Iteration 270, loss = 1415078.98716261
# Iteration 271, loss = 1372045.46829229
# Iteration 272, loss = 1330187.30168933
# Iteration 273, loss = 1289476.90094614
# Iteration 274, loss = 1249887.18503743
# Iteration 275, loss = 1211391.57315076
# Iteration 276, loss = 1173963.97946186
# Iteration 277, loss = 1137578.80785774
# Iteration 278, loss = 1102210.94661042
# Iteration 279, loss = 1067835.76300441
# Iteration 280, loss = 1034429.09792062
# Iteration 281, loss = 1001967.26037998
# Iteration 282, loss = 970427.02204948
# Iteration 283, loss = 939785.61171373
# Iteration 284, loss = 910020.70971492
# Iteration 285, loss = 881110.44236420
# Iteration 286, loss = 853033.37632730
# Iteration 287, loss = 825768.51298742
# Iteration 288, loss = 799295.28278824
# Iteration 289, loss = 773593.53955979
# Iteration 290, loss = 748643.55483030
# Iteration 291, loss = 724426.01212659
# Iteration 292, loss = 700922.00126584
# Iteration 293, loss = 678113.01264161
# Iteration 294, loss = 655980.93150670
# Iteration 295, loss = 634508.03225548
# Iteration 296, loss = 613676.97270847
# Iteration 297, loss = 593470.78840165
# Iteration 298, loss = 573872.88688300
# Iteration 299, loss = 554867.04201892
# Iteration 300, loss = 536437.38831278
# Iteration 301, loss = 518568.41523807
# Iteration 302, loss = 501244.96158855
# Iteration 303, loss = 484452.20984757
# Iteration 304, loss = 468175.68057883
# Iteration 305, loss = 452401.22684076
# Iteration 306, loss = 437115.02862661
# Iteration 307, loss = 422303.58733226
# Iteration 308, loss = 407953.72025383
# Iteration 309, loss = 394052.55511696
# Iteration 310, loss = 380587.52463956
# Iteration 311, loss = 367546.36112998
# Iteration 312, loss = 354917.09112219
# Iteration 313, loss = 342688.03004979
# Iteration 314, loss = 330847.77696028
# Iteration 315, loss = 319385.20927133
# Iteration 316, loss = 308289.47757040
# Iteration 317, loss = 297550.00045922
# Iteration 318, loss = 287156.45944437
# Iteration 319, loss = 277098.79387543
# Iteration 320, loss = 267367.19593172
# Iteration 321, loss = 257952.10565899
# Iteration 322, loss = 248844.20605701
# Iteration 323, loss = 240034.41821925
# Iteration 324, loss = 231513.89652550
# Iteration 325, loss = 223274.02388839
# Iteration 326, loss = 215306.40705476
# Iteration 327, loss = 207602.87196253
# Iteration 328, loss = 200155.45915390
# Iteration 329, loss = 192956.41924562
# Iteration 330, loss = 185998.20845683
# Iteration 331, loss = 179273.48419510
# Iteration 332, loss = 172775.10070123
# Iteration 333, loss = 166496.10475323
# Iteration 334, loss = 160429.73142987
# Iteration 335, loss = 154569.39993423
# Iteration 336, loss = 148908.70947748
# Iteration 337, loss = 143441.43522318
# Iteration 338, loss = 138161.52429237
# Iteration 339, loss = 133063.09182953
# Iteration 340, loss = 128140.41712955
# Iteration 341, loss = 123387.93982578
# Iteration 342, loss = 118800.25613933
# Iteration 343, loss = 114372.11518928
# Iteration 344, loss = 110098.41536419
# Iteration 345, loss = 105974.20075439
# Iteration 346, loss = 101994.65764525
# Iteration 347, loss = 98155.11107106
# Iteration 348, loss = 94451.02142945
# Iteration 349, loss = 90877.98115602
# Iteration 350, loss = 87431.71145899
# Iteration 351, loss = 84108.05911347
# Iteration 352, loss = 80902.99331520
# Iteration 353, loss = 77812.60259315
# Iteration 354, loss = 74833.09178088
# Iteration 355, loss = 71960.77904597
# Iteration 356, loss = 69192.09297731
# Iteration 357, loss = 66523.56972967
# Iteration 358, loss = 63951.85022503
# Iteration 359, loss = 61473.67741035
# Iteration 360, loss = 59085.89357102
# Iteration 361, loss = 56785.43769963
# Iteration 362, loss = 54569.34291936
# Iteration 363, loss = 52434.73396153
# Iteration 364, loss = 50378.82469664
# Iteration 365, loss = 48398.91571830
# Iteration 366, loss = 46492.39197945
# Iteration 367, loss = 44656.72048021
# Iteration 368, loss = 42889.44800671
# Iteration 369, loss = 41188.19892029
# Iteration 370, loss = 39550.67299630
# Iteration 371, loss = 37974.64331193
# Iteration 372, loss = 36457.95418232
# Iteration 373, loss = 34998.51914431
# Iteration 374, loss = 33594.31898701
# Iteration 375, loss = 32243.39982866
# Iteration 376, loss = 30943.87123895
# Iteration 377, loss = 29693.90440610
# Iteration 378, loss = 28491.73034802
# Iteration 379, loss = 27335.63816680
# Iteration 380, loss = 26223.97334588
# Iteration 381, loss = 25155.13608900
# Iteration 382, loss = 24127.57970048
# Iteration 383, loss = 23139.80900582
# Iteration 384, loss = 22190.37881216
# Iteration 385, loss = 21277.89240764
# Iteration 386, loss = 20401.00009918
# Iteration 387, loss = 19558.39778774
# Iteration 388, loss = 18748.82558053
# Iteration 389, loss = 17971.06643932
# Iteration 390, loss = 17223.94486430
# Iteration 391, loss = 16506.32561261
# Iteration 392, loss = 15817.11245098
# Iteration 393, loss = 15155.24694175
# Iteration 394, loss = 14519.70726153
# Iteration 395, loss = 13909.50705197
# Iteration 396, loss = 13323.69430174
# Iteration 397, loss = 12761.35025929
# Iteration 398, loss = 12221.58837552
# Iteration 399, loss = 11703.55327593
# Iteration 400, loss = 11206.41976136
# Iteration 401, loss = 10729.39183687
# Iteration 402, loss = 10271.70176803
# Iteration 403, loss = 9832.60916408
# Iteration 404, loss = 9411.40008723
# Iteration 405, loss = 9007.38618759
# Iteration 406, loss = 8619.90386311
# Iteration 407, loss = 8248.31344388
# Iteration 408, loss = 7891.99840035
# Iteration 409, loss = 7550.36457467
# Iteration 410, loss = 7222.83943487
# Iteration 411, loss = 6908.87135107
# Iteration 412, loss = 6607.92889331
# Iteration 413, loss = 6319.50015045
# Iteration 414, loss = 6043.09206958
# Iteration 415, loss = 5778.22981545
# Iteration 416, loss = 5524.45614935
# Iteration 417, loss = 5281.33082707
# Iteration 418, loss = 5048.43001528
# Iteration 419, loss = 4825.34572598
# Iteration 420, loss = 4611.68526848
# Iteration 421, loss = 4407.07071845
# Iteration 422, loss = 4211.13840366
# Iteration 423, loss = 4023.53840580
# Iteration 424, loss = 3843.93407814
# Iteration 425, loss = 3672.00157846
# Iteration 426, loss = 3507.42941685
# Iteration 427, loss = 3349.91801806
# Iteration 428, loss = 3199.17929789
# Iteration 429, loss = 3054.93625323
# Iteration 430, loss = 2916.92256554
# Iteration 431, loss = 2784.88221707
# Iteration 432, loss = 2658.56911979
# Iteration 433, loss = 2537.74675644
# Iteration 434, loss = 2422.18783348
# Iteration 435, loss = 2311.67394546
# Iteration 436, loss = 2205.99525065
# Iteration 437, loss = 2104.95015746
# Iteration 438, loss = 2008.34502139
# Iteration 439, loss = 1915.99385218
# Iteration 440, loss = 1827.71803087
# Iteration 441, loss = 1743.34603649
# Iteration 442, loss = 1662.71318200
# Iteration 443, loss = 1585.66135934
# Iteration 444, loss = 1512.03879319
# Iteration 445, loss = 1441.69980322
# Iteration 446, loss = 1374.50457461
# Iteration 447, loss = 1310.31893646
# Iteration 448, loss = 1249.01414804
# Iteration 449, loss = 1190.46669240
# Iteration 450, loss = 1134.55807732
# Iteration 451, loss = 1081.17464325
# Iteration 452, loss = 1030.20737799
# Iteration 453, loss = 981.55173806
# Iteration 454, loss = 935.10747635
# Iteration 455, loss = 890.77847592
# Iteration 456, loss = 848.47258987
# Iteration 457, loss = 808.10148685
# Iteration 458, loss = 769.58050225
# Iteration 459, loss = 732.82849474
# Iteration 460, loss = 697.76770800
# Iteration 461, loss = 664.32363759
# Iteration 462, loss = 632.42490262
# Iteration 463, loss = 602.00312215
# Iteration 464, loss = 572.99279616
# Iteration 465, loss = 545.33119094
# Iteration 466, loss = 518.95822871
# Iteration 467, loss = 493.81638134
# Iteration 468, loss = 469.85056810
# Iteration 469, loss = 447.00805716
# Iteration 470, loss = 425.23837086
# Iteration 471, loss = 404.49319453
# Iteration 472, loss = 384.72628879
# Iteration 473, loss = 365.89340510
# Iteration 474, loss = 347.95220461
# Iteration 475, loss = 330.86218011
# Iteration 476, loss = 314.58458088
# Iteration 477, loss = 299.08234054
# Iteration 478, loss = 284.32000763
# Iteration 479, loss = 270.26367887
# Iteration 480, loss = 256.88093502
# Iteration 481, loss = 244.14077925
# Iteration 482, loss = 232.01357787
# Iteration 483, loss = 220.47100346
# Iteration 484, loss = 209.48598017
# Iteration 485, loss = 199.03263116
# Iteration 486, loss = 189.08622820
# Iteration 487, loss = 179.62314319
# Iteration 488, loss = 170.62080160
# Iteration 489, loss = 162.05763788
# Iteration 490, loss = 153.91305248
# Iteration 491, loss = 146.16737074
# Iteration 492, loss = 138.80180337
# Iteration 493, loss = 131.79840849
# Iteration 494, loss = 125.14005531
# Iteration 495, loss = 118.81038914
# Iteration 496, loss = 112.79379797
# Iteration 497, loss = 107.07538029
# Iteration 498, loss = 101.64091432
# Iteration 499, loss = 96.47682842
# Iteration 500, loss = 91.57017278
# Iteration 501, loss = 86.90859226
# Iteration 502, loss = 82.48030033
# Iteration 503, loss = 78.27405411
# Iteration 504, loss = 74.27913046
# Iteration 505, loss = 70.48530304
# Iteration 506, loss = 66.88282033
# Iteration 507, loss = 63.46238462
# Iteration 508, loss = 60.21513180
# Iteration 509, loss = 57.13261206
# Iteration 510, loss = 54.20677144
# Iteration 511, loss = 51.42993403
# Iteration 512, loss = 48.79478507
# Iteration 513, loss = 46.29435472
# Iteration 514, loss = 43.92200244
# Iteration 515, loss = 41.67140219
# Iteration 516, loss = 39.53652816
# Iteration 517, loss = 37.51164113
# Iteration 518, loss = 35.59127543
# Iteration 519, loss = 33.77022648
# Iteration 520, loss = 32.04353886
# Iteration 521, loss = 30.40649487
# Iteration 522, loss = 28.85460361
# Iteration 523, loss = 27.38359058
# Iteration 524, loss = 25.98938766
# Iteration 525, loss = 24.66812356
# Iteration 526, loss = 23.41611472
# Iteration 527, loss = 22.22985658
# Iteration 528, loss = 21.10601525
# Iteration 529, loss = 20.04141953
# Iteration 530, loss = 19.03305331
# Iteration 531, loss = 18.07804829
# Iteration 532, loss = 17.17367705
# Iteration 533, loss = 16.31734639
# Iteration 534, loss = 15.50659103
# Iteration 535, loss = 14.73906751
# Iteration 536, loss = 14.01254846
# Iteration 537, loss = 13.32491706
# Iteration 538, loss = 12.67416175
# Iteration 539, loss = 12.05837127
# Iteration 540, loss = 11.47572978
# Iteration 541, loss = 10.92451237
# Iteration 542, loss = 10.40308060
# Iteration 543, loss = 9.90987840
# Iteration 544, loss = 9.44342808
# Iteration 545, loss = 9.00232653
# Iteration 546, loss = 8.58524158
# Iteration 547, loss = 8.19090859
# Iteration 548, loss = 7.81812717
# Iteration 549, loss = 7.46575797
# Iteration 550, loss = 7.13271980
# Iteration 551, loss = 6.81798668
# Iteration 552, loss = 6.52058518
# Iteration 553, loss = 6.23959184
# Iteration 554, loss = 5.97413066
# Iteration 555, loss = 5.72337079
# Iteration 556, loss = 5.48652428
# Iteration 557, loss = 5.26284395
# Iteration 558, loss = 5.05162134
# Iteration 559, loss = 4.85218482
# Iteration 560, loss = 4.66389772
# Iteration 561, loss = 4.48615657
# Iteration 562, loss = 4.31838945
# Iteration 563, loss = 4.16005441
# Iteration 564, loss = 4.01063793
# Iteration 565, loss = 3.86965350
# Iteration 566, loss = 3.73664027
# Iteration 567, loss = 3.61116169
# Iteration 568, loss = 3.49280435
# Iteration 569, loss = 3.38117673
# Iteration 570, loss = 3.27590814
# Iteration 571, loss = 3.17664761
# Iteration 572, loss = 3.08306289
# Iteration 573, loss = 2.99483951
# Iteration 574, loss = 2.91167983
# Iteration 575, loss = 2.83330219
# Iteration 576, loss = 2.75944007
# Iteration 577, loss = 2.68984135
# Iteration 578, loss = 2.62426747
# Iteration 579, loss = 2.56249282
# Iteration 580, loss = 2.50430401
# Iteration 581, loss = 2.44949925
# Iteration 582, loss = 2.39788773
# Iteration 583, loss = 2.34928904
# Iteration 584, loss = 2.30353264
# Iteration 585, loss = 2.26045735
# Iteration 586, loss = 2.21991080
# Iteration 587, loss = 2.18174902
# Iteration 588, loss = 2.14583598
# Iteration 589, loss = 2.11204314
# Iteration 590, loss = 2.08024909
# Iteration 591, loss = 2.05033914
# Iteration 592, loss = 2.02220498
# Iteration 593, loss = 1.99574431
# Iteration 594, loss = 1.97086057
# Iteration 595, loss = 1.94746256
# Iteration 596, loss = 1.92546421
# Iteration 597, loss = 1.90478426
# Iteration 598, loss = 1.88534605
# Iteration 599, loss = 1.86707719
# Iteration 600, loss = 1.84990944
# Iteration 601, loss = 1.83377835
# Iteration 602, loss = 1.81862319
# Iteration 603, loss = 1.80438662
# Iteration 604, loss = 1.79101460
# Iteration 605, loss = 1.77845616
# Iteration 606, loss = 1.76666324
# Iteration 607, loss = 1.75559054
# Iteration 608, loss = 1.74519535
# Iteration 609, loss = 1.73543741
# Iteration 610, loss = 1.72627878
# Iteration 611, loss = 1.71768373
# Iteration 612, loss = 1.70961858
# Iteration 613, loss = 1.70205158
# Iteration 614, loss = 1.69495287
# Iteration 615, loss = 1.68829429
# Iteration 616, loss = 1.68204933
# Iteration 617, loss = 1.67619304
# Iteration 618, loss = 1.67070191
# Iteration 619, loss = 1.66555383
# Iteration 620, loss = 1.66072797
# Iteration 621, loss = 1.65620474
# Iteration 622, loss = 1.65196570
# Iteration 623, loss = 1.64799350
# Iteration 624, loss = 1.64427181
# Iteration 625, loss = 1.64078529
# Iteration 626, loss = 1.63751949
# Iteration 627, loss = 1.63446084
# Iteration 628, loss = 1.63159656
# Iteration 629, loss = 1.62891464
# Iteration 630, loss = 1.62640381
# Iteration 631, loss = 1.62405345
# Iteration 632, loss = 1.62185359
# Iteration 633, loss = 1.61979487
# Iteration 634, loss = 1.61786847
# Iteration 635, loss = 1.61606614
# Iteration 636, loss = 1.61438011
# Iteration 637, loss = 1.61280307
# Iteration 638, loss = 1.61132817
# Iteration 639, loss = 1.60994899
# Iteration 640, loss = 1.60865948
# Iteration 641, loss = 1.60745397
# Iteration 642, loss = 1.60632715
# Iteration 643, loss = 1.60527401
# Iteration 644, loss = 1.60428986
# Iteration 645, loss = 1.60337032
# Iteration 646, loss = 1.60251126
# Iteration 647, loss = 1.60170880
# Iteration 648, loss = 1.60095933
# Iteration 649, loss = 1.60025943
# Iteration 650, loss = 1.59960591
# Iteration 651, loss = 1.59899579
# Iteration 652, loss = 1.59842626
# Iteration 653, loss = 1.59789469
# Iteration 654, loss = 1.59739862
# Iteration 655, loss = 1.59693575
# Iteration 656, loss = 1.59650390
# Iteration 657, loss = 1.59610106
# Iteration 658, loss = 1.59572533
# Iteration 659, loss = 1.59537494
# Iteration 660, loss = 1.59504821
# Iteration 661, loss = 1.59474360
# Iteration 662, loss = 1.59445965
# Iteration 663, loss = 1.59419499
# Iteration 664, loss = 1.59394834
# Iteration 665, loss = 1.59371852
# Iteration 666, loss = 1.59350440
# Iteration 667, loss = 1.59330494
# Iteration 668, loss = 1.59311916
# Iteration 669, loss = 1.59294614
# Iteration 670, loss = 1.59278504
# Iteration 671, loss = 1.59263505
# Iteration 672, loss = 1.59249543
# Iteration 673, loss = 1.59236547
# Iteration 674, loss = 1.59224453
# Iteration 675, loss = 1.59213199
# Iteration 676, loss = 1.59202729
# Iteration 677, loss = 1.59192989
# Iteration 678, loss = 1.59183929
# Iteration 679, loss = 1.59175504
# Iteration 680, loss = 1.59167670
# Iteration 681, loss = 1.59160386
# Iteration 682, loss = 1.59153615
# Iteration 683, loss = 1.59147321
# Iteration 684, loss = 1.59141472
# Iteration 685, loss = 1.59136037
# Iteration 686, loss = 1.59130986
# Iteration 687, loss = 1.59126295
# Iteration 688, loss = 1.59121937
# Iteration 689, loss = 1.59117889
# Iteration 690, loss = 1.59114130
# Iteration 691, loss = 1.59110640
# Iteration 692, loss = 1.59107399
# Iteration 693, loss = 1.59104391
# Iteration 694, loss = 1.59101598
# Iteration 695, loss = 1.59099007
# Iteration 696, loss = 1.59096602
# Iteration 697, loss = 1.59094370
# Iteration 698, loss = 1.59092299
# Iteration 699, loss = 1.59090378
# Iteration 700, loss = 1.59088596
# Iteration 701, loss = 1.59086942
# Iteration 702, loss = 1.59085409
# Iteration 703, loss = 1.59083987
# Iteration 704, loss = 1.59082668
# Iteration 705, loss = 1.59081445
# Iteration 706, loss = 1.59080311
# Iteration 707, loss = 1.59079259
# Iteration 708, loss = 1.59078284
# Iteration 709, loss = 1.59077379
# Iteration 710, loss = 1.59076541
# Iteration 711, loss = 1.59075763
# Iteration 712, loss = 1.59075042
# Iteration 713, loss = 1.59074374
# Iteration 714, loss = 1.59073754
# Iteration 715, loss = 1.59073179
# Iteration 716, loss = 1.59072646
# Iteration 717, loss = 1.59072151
# Iteration 718, loss = 1.59071692
# Training loss did not improve more than tol=0.000010 for 10 consecutive epochs. Stopping.
# [4.07671125]
# -3.674144052409418

# %% [markdown]
# ###  [OPTIONAL] Qe) Neural Network with pre-scaling
#
# Now, the neurons in neural networks normally expects input data in the range `[0;1]` or sometimes in the range `[-1;1]`, meaning that for value outside this range the you put of the neuron will saturate to it's min or max value (also typical `0` or `1`).
#
# A concrete value of `X` is, say 22.000 USD, that is far away from what the MLP expects. To af fix to the problem in Qd) is to preprocess data by scaling it down to something more sensible.
#
# Try to scale X to a range of `[0;1]`, re-train the MLP, re-plot and find the new score from the rescaled input. Any better?

# %%
normalizedX = (X-min(X))/(max(X)-min(X))
normalizedM = (M-min(X))/(max(X)-min(X))

# Setup MLPRegressor
mlp = MLPRegressor( hidden_layer_sizes=(10,), solver='adam', activation='relu', tol=1E-5, max_iter=100000, verbose=True)
mlp.fit(normalizedX, y.ravel())

# lets make a MLP regressor prediction and redo the plots
y_pred_mlp = mlp.predict(normalizedM) 

plt.plot(m, y_pred_lin, "r")
plt.plot(m, y_pred_knn, "b")
plt.plot(m, y_pred_mlp, "k")

normalizedP = (22587-min(X))/(max(X)-min(X))
print(normalizedP)
print(mlp.predict([normalizedP]))

#Extract score with test data
test_samples = pd.read_csv(datapath + "lifesat.csv", thousands=',')

Xsample = np.c_[test_samples["GDP per capita"]]
ysample = np.c_[test_samples["Life satisfaction"]]

normalizedTestX = (Xsample-min(Xsample))/(max(Xsample)-min(Xsample))

score = mlp.score(normalizedTestX, ysample)
print(score)
# Since MLP expects scaled data from 0.0 to 1.0, the data fed to the model in the previous exercise made it unable to train properly.
# This time we observe much better results, although it does not compare to Lin.Reg and KNN in this case, although we need to remember that KNN currently is overfitting to the train data.
# Out:
# Iteration 1, loss = 22.38270268
# Iteration 2, loss = 22.35962476
# Iteration 3, loss = 22.33650576
# Iteration 4, loss = 22.31334508
# Iteration 5, loss = 22.29014210
# Iteration 6, loss = 22.26689622
# Iteration 7, loss = 22.24360680
# Iteration 8, loss = 22.22025040
# Iteration 9, loss = 22.19660517
# Iteration 10, loss = 22.17290475
# Iteration 11, loss = 22.14915076
# Iteration 12, loss = 22.12534422
# Iteration 13, loss = 22.10148571
# Iteration 14, loss = 22.07757558
# Iteration 15, loss = 22.05361396
# Iteration 16, loss = 22.02960084
# Iteration 17, loss = 22.00553612
# Iteration 18, loss = 21.98141962
# Iteration 19, loss = 21.95725110
# Iteration 20, loss = 21.93303030
# Iteration 21, loss = 21.90875691
# Iteration 22, loss = 21.88443061
# Iteration 23, loss = 21.86005108
# Iteration 24, loss = 21.83561797
# Iteration 25, loss = 21.81113095
# Iteration 26, loss = 21.78658967
# Iteration 27, loss = 21.76199380
# Iteration 28, loss = 21.73734300
# Iteration 29, loss = 21.71251580
# Iteration 30, loss = 21.68749384
# Iteration 31, loss = 21.66240025
# Iteration 32, loss = 21.63723674
# Iteration 33, loss = 21.61200480
# Iteration 34, loss = 21.58669817
# Iteration 35, loss = 21.56103501
# Iteration 36, loss = 21.53528732
# Iteration 37, loss = 21.50945840
# Iteration 38, loss = 21.48355109
# Iteration 39, loss = 21.45756789
# Iteration 40, loss = 21.43151095
# Iteration 41, loss = 21.40538216
# Iteration 42, loss = 21.37918317
# Iteration 43, loss = 21.35291539
# Iteration 44, loss = 21.32658007
# Iteration 45, loss = 21.30017829
# Iteration 46, loss = 21.27371101
# Iteration 47, loss = 21.24717902
# Iteration 48, loss = 21.22058305
# Iteration 49, loss = 21.19382225
# Iteration 50, loss = 21.16678441
# Iteration 51, loss = 21.13966253
# Iteration 52, loss = 21.11245960
# Iteration 53, loss = 21.08517830
# Iteration 54, loss = 21.05782094
# Iteration 55, loss = 21.03038960
# Iteration 56, loss = 21.00288610
# Iteration 57, loss = 20.97531204
# Iteration 58, loss = 20.94766884
# Iteration 59, loss = 20.91995776
# Iteration 60, loss = 20.89217990
# Iteration 61, loss = 20.86433623
# Iteration 62, loss = 20.83642760
# Iteration 63, loss = 20.80845478
# Iteration 64, loss = 20.78041843
# Iteration 65, loss = 20.75231915
# Iteration 66, loss = 20.72415744
# Iteration 67, loss = 20.69593378
# Iteration 68, loss = 20.66764857
# Iteration 69, loss = 20.63930217
# Iteration 70, loss = 20.61089489
# Iteration 71, loss = 20.58242702
# Iteration 72, loss = 20.55389881
# Iteration 73, loss = 20.52531049
# Iteration 74, loss = 20.49663890
# Iteration 75, loss = 20.46767246
# Iteration 76, loss = 20.43862769
# Iteration 77, loss = 20.40950687
# Iteration 78, loss = 20.38031205
# Iteration 79, loss = 20.35104503
# Iteration 80, loss = 20.32170745
# Iteration 81, loss = 20.29230078
# Iteration 82, loss = 20.26282631
# Iteration 83, loss = 20.23328522
# Iteration 84, loss = 20.20367856
# Iteration 85, loss = 20.17400729
# Iteration 86, loss = 20.14427225
# Iteration 87, loss = 20.11447421
# Iteration 88, loss = 20.08461386
# Iteration 89, loss = 20.05469184
# Iteration 90, loss = 20.02470870
# Iteration 91, loss = 19.99466497
# Iteration 92, loss = 19.96456111
# Iteration 93, loss = 19.93439757
# Iteration 94, loss = 19.90417472
# Iteration 95, loss = 19.87389294
# Iteration 96, loss = 19.84355256
# Iteration 97, loss = 19.81315390
# Iteration 98, loss = 19.78269723
# Iteration 99, loss = 19.75202941
# Iteration 100, loss = 19.72118998
# Iteration 101, loss = 19.69027308
# Iteration 102, loss = 19.65928117
# Iteration 103, loss = 19.62821648
# Iteration 104, loss = 19.59708100
# Iteration 105, loss = 19.56587652
# Iteration 106, loss = 19.53460469
# Iteration 107, loss = 19.50326697
# Iteration 108, loss = 19.47186470
# Iteration 109, loss = 19.44039908
# Iteration 110, loss = 19.40887122
# Iteration 111, loss = 19.37728211
# Iteration 112, loss = 19.34563266
# Iteration 113, loss = 19.31392371
# Iteration 114, loss = 19.28215602
# Iteration 115, loss = 19.25033029
# Iteration 116, loss = 19.21844716
# Iteration 117, loss = 19.18650723
# Iteration 118, loss = 19.15451106
# Iteration 119, loss = 19.12245915
# Iteration 120, loss = 19.09035199
# Iteration 121, loss = 19.05819002
# Iteration 122, loss = 19.02597366
# Iteration 123, loss = 18.99370332
# Iteration 124, loss = 18.96137937
# Iteration 125, loss = 18.92895869
# Iteration 126, loss = 18.89626663
# Iteration 127, loss = 18.86350178
# Iteration 128, loss = 18.83066665
# Iteration 129, loss = 18.79776353
# Iteration 130, loss = 18.76479448
# Iteration 131, loss = 18.73176137
# Iteration 132, loss = 18.69866590
# Iteration 133, loss = 18.66550962
# Iteration 134, loss = 18.63229393
# Iteration 135, loss = 18.59902013
# Iteration 136, loss = 18.56568940
# Iteration 137, loss = 18.53230280
# Iteration 138, loss = 18.49886135
# Iteration 139, loss = 18.46524994
# Iteration 140, loss = 18.43140077
# Iteration 141, loss = 18.39747563
# Iteration 142, loss = 18.36347783
# Iteration 143, loss = 18.32941035
# Iteration 144, loss = 18.29527590
# Iteration 145, loss = 18.26107691
# Iteration 146, loss = 18.22681561
# Iteration 147, loss = 18.19249401
# Iteration 148, loss = 18.15811395
# Iteration 149, loss = 18.12367710
# Iteration 150, loss = 18.08918497
# Iteration 151, loss = 18.05463896
# Iteration 152, loss = 18.02004034
# Iteration 153, loss = 17.98539029
# Iteration 154, loss = 17.95068988
# Iteration 155, loss = 17.91594011
# Iteration 156, loss = 17.88114190
# Iteration 157, loss = 17.84629609
# Iteration 158, loss = 17.81140349
# Iteration 159, loss = 17.77646483
# Iteration 160, loss = 17.74148081
# Iteration 161, loss = 17.70645207
# Iteration 162, loss = 17.67137924
# Iteration 163, loss = 17.63626288
# Iteration 164, loss = 17.60110357
# Iteration 165, loss = 17.56590181
# Iteration 166, loss = 17.53065811
# Iteration 167, loss = 17.49537295
# Iteration 168, loss = 17.46004680
# Iteration 169, loss = 17.42468011
# Iteration 170, loss = 17.38927330
# Iteration 171, loss = 17.35382679
# Iteration 172, loss = 17.31834101
# Iteration 173, loss = 17.28281634
# Iteration 174, loss = 17.24725318
# Iteration 175, loss = 17.21165192
# Iteration 176, loss = 17.17601293
# Iteration 177, loss = 17.14033660
# Iteration 178, loss = 17.10462328
# Iteration 179, loss = 17.06887334
# Iteration 180, loss = 17.03308715
# Iteration 181, loss = 16.99726507
# Iteration 182, loss = 16.96140745
# Iteration 183, loss = 16.92551465
# Iteration 184, loss = 16.88958703
# Iteration 185, loss = 16.85362493
# Iteration 186, loss = 16.81762872
# Iteration 187, loss = 16.78159874
# Iteration 188, loss = 16.74553534
# Iteration 189, loss = 16.70943889
# Iteration 190, loss = 16.67330973
# Iteration 191, loss = 16.63714822
# Iteration 192, loss = 16.60095470
# Iteration 193, loss = 16.56472955
# Iteration 194, loss = 16.52847310
# Iteration 195, loss = 16.49218572
# Iteration 196, loss = 16.45586777
# Iteration 197, loss = 16.41930457
# Iteration 198, loss = 16.38266930
# Iteration 199, loss = 16.34598425
# Iteration 200, loss = 16.30925195
# Iteration 201, loss = 16.27247472
# Iteration 202, loss = 16.23565467
# Iteration 203, loss = 16.19879376
# Iteration 204, loss = 16.16189375
# Iteration 205, loss = 16.12495630
# Iteration 206, loss = 16.08798291
# Iteration 207, loss = 16.05097498
# Iteration 208, loss = 16.01393380
# Iteration 209, loss = 15.97686057
# Iteration 210, loss = 15.93975642
# Iteration 211, loss = 15.90262237
# Iteration 212, loss = 15.86545942
# Iteration 213, loss = 15.82826848
# Iteration 214, loss = 15.79105041
# Iteration 215, loss = 15.75380603
# Iteration 216, loss = 15.71653611
# Iteration 217, loss = 15.67908071
# Iteration 218, loss = 15.64153324
# Iteration 219, loss = 15.60394434
# Iteration 220, loss = 15.56631658
# Iteration 221, loss = 15.52865234
# Iteration 222, loss = 15.49095380
# Iteration 223, loss = 15.45322294
# Iteration 224, loss = 15.41546160
# Iteration 225, loss = 15.37767145
# Iteration 226, loss = 15.33985407
# Iteration 227, loss = 15.30201087
# Iteration 228, loss = 15.26414320
# Iteration 229, loss = 15.22625230
# Iteration 230, loss = 15.18831576
# Iteration 231, loss = 15.15016718
# Iteration 232, loss = 15.11198167
# Iteration 233, loss = 15.07376205
# Iteration 234, loss = 15.03551088
# Iteration 235, loss = 14.99723051
# Iteration 236, loss = 14.95892307
# Iteration 237, loss = 14.92059054
# Iteration 238, loss = 14.88223472
# Iteration 239, loss = 14.84385730
# Iteration 240, loss = 14.80545981
# Iteration 241, loss = 14.76682578
# Iteration 242, loss = 14.72813369
# Iteration 243, loss = 14.68940490
# Iteration 244, loss = 14.65064281
# Iteration 245, loss = 14.61185052
# Iteration 246, loss = 14.57303088
# Iteration 247, loss = 14.53418645
# Iteration 248, loss = 14.49531960
# Iteration 249, loss = 14.45643250
# Iteration 250, loss = 14.41752714
# Iteration 251, loss = 14.37860533
# Iteration 252, loss = 14.33966876
# Iteration 253, loss = 14.30071899
# Iteration 254, loss = 14.26175746
# Iteration 255, loss = 14.22278550
# Iteration 256, loss = 14.18380436
# Iteration 257, loss = 14.14481520
# Iteration 258, loss = 14.10566388
# Iteration 259, loss = 14.06637469
# Iteration 260, loss = 14.02705777
# Iteration 261, loss = 13.98771651
# Iteration 262, loss = 13.94835403
# Iteration 263, loss = 13.90897313
# Iteration 264, loss = 13.86957641
# Iteration 265, loss = 13.83016623
# Iteration 266, loss = 13.79074474
# Iteration 267, loss = 13.75131393
# Iteration 268, loss = 13.71187564
# Iteration 269, loss = 13.67243154
# Iteration 270, loss = 13.63298319
# Iteration 271, loss = 13.59353204
# Iteration 272, loss = 13.55407941
# Iteration 273, loss = 13.51462657
# Iteration 274, loss = 13.47517467
# Iteration 275, loss = 13.43572480
# Iteration 276, loss = 13.39627798
# Iteration 277, loss = 13.35683518
# Iteration 278, loss = 13.31739730
# Iteration 279, loss = 13.27796520
# Iteration 280, loss = 13.23853970
# Iteration 281, loss = 13.19912158
# Iteration 282, loss = 13.15971158
# Iteration 283, loss = 13.12031041
# Iteration 284, loss = 13.08091875
# Iteration 285, loss = 13.04153727
# Iteration 286, loss = 13.00216660
# Iteration 287, loss = 12.96280736
# Iteration 288, loss = 12.92346014
# Iteration 289, loss = 12.88412553
# Iteration 290, loss = 12.84480410
# Iteration 291, loss = 12.80549639
# Iteration 292, loss = 12.76620295
# Iteration 293, loss = 12.72692432
# Iteration 294, loss = 12.68766101
# Iteration 295, loss = 12.64841354
# Iteration 296, loss = 12.60918242
# Iteration 297, loss = 12.56996814
# Iteration 298, loss = 12.53077120
# Iteration 299, loss = 12.49159210
# Iteration 300, loss = 12.45243130
# Iteration 301, loss = 12.41328930
# Iteration 302, loss = 12.37416657
# Iteration 303, loss = 12.33506357
# Iteration 304, loss = 12.29598078
# Iteration 305, loss = 12.25691867
# Iteration 306, loss = 12.21787769
# Iteration 307, loss = 12.17885830
# Iteration 308, loss = 12.13985568
# Iteration 309, loss = 12.10062330
# Iteration 310, loss = 12.06139365
# Iteration 311, loss = 12.02216940
# Iteration 312, loss = 11.98295300
# Iteration 313, loss = 11.94355467
# Iteration 314, loss = 11.90414921
# Iteration 315, loss = 11.86474083
# Iteration 316, loss = 11.82533318
# Iteration 317, loss = 11.78592957
# Iteration 318, loss = 11.74653302
# Iteration 319, loss = 11.70714631
# Iteration 320, loss = 11.66777195
# Iteration 321, loss = 11.62841226
# Iteration 322, loss = 11.58906935
# Iteration 323, loss = 11.54974518
# Iteration 324, loss = 11.51044153
# Iteration 325, loss = 11.47116007
# Iteration 326, loss = 11.43190233
# Iteration 327, loss = 11.39266972
# Iteration 328, loss = 11.35346355
# Iteration 329, loss = 11.31428507
# Iteration 330, loss = 11.27513541
# Iteration 331, loss = 11.23601564
# Iteration 332, loss = 11.19692678
# Iteration 333, loss = 11.15786976
# Iteration 334, loss = 11.11884549
# Iteration 335, loss = 11.07985481
# Iteration 336, loss = 11.04089852
# Iteration 337, loss = 11.00197738
# Iteration 338, loss = 10.96309213
# Iteration 339, loss = 10.92424346
# Iteration 340, loss = 10.88543204
# Iteration 341, loss = 10.84665851
# Iteration 342, loss = 10.80792350
# Iteration 343, loss = 10.76922760
# Iteration 344, loss = 10.73057140
# Iteration 345, loss = 10.69195546
# Iteration 346, loss = 10.65338033
# Iteration 347, loss = 10.61484654
# Iteration 348, loss = 10.57635462
# Iteration 349, loss = 10.53790508
# Iteration 350, loss = 10.49949841
# Iteration 351, loss = 10.46113512
# Iteration 352, loss = 10.42281567
# Iteration 353, loss = 10.38454056
# Iteration 354, loss = 10.34631024
# Iteration 355, loss = 10.30812518
# Iteration 356, loss = 10.26998584
# Iteration 357, loss = 10.23189266
# Iteration 358, loss = 10.19384609
# Iteration 359, loss = 10.15569004
# Iteration 360, loss = 10.11750124
# Iteration 361, loss = 10.07934183
# Iteration 362, loss = 10.04121429
# Iteration 363, loss = 10.00312090
# Iteration 364, loss = 9.96506374
# Iteration 365, loss = 9.92704474
# Iteration 366, loss = 9.88885260
# Iteration 367, loss = 9.85065510
# Iteration 368, loss = 9.81247964
# Iteration 369, loss = 9.77432993
# Iteration 370, loss = 9.73620935
# Iteration 371, loss = 9.69812100
# Iteration 372, loss = 9.66006766
# Iteration 373, loss = 9.62205190
# Iteration 374, loss = 9.58407606
# Iteration 375, loss = 9.54614228
# Iteration 376, loss = 9.50825252
# Iteration 377, loss = 9.47040857
# Iteration 378, loss = 9.43261209
# Iteration 379, loss = 9.39486460
# Iteration 380, loss = 9.35716751
# Iteration 381, loss = 9.31952212
# Iteration 382, loss = 9.28192964
# Iteration 383, loss = 9.24439118
# Iteration 384, loss = 9.20690779
# Iteration 385, loss = 9.16948043
# Iteration 386, loss = 9.13211004
# Iteration 387, loss = 9.09479744
# Iteration 388, loss = 9.05754346
# Iteration 389, loss = 9.02034885
# Iteration 390, loss = 8.98321433
# Iteration 391, loss = 8.94614057
# Iteration 392, loss = 8.90912823
# Iteration 393, loss = 8.87217791
# Iteration 394, loss = 8.83529021
# Iteration 395, loss = 8.79846570
# Iteration 396, loss = 8.76170490
# Iteration 397, loss = 8.72500835
# Iteration 398, loss = 8.68837655
# Iteration 399, loss = 8.65180997
# Iteration 400, loss = 8.61530910
# Iteration 401, loss = 8.57887438
# Iteration 402, loss = 8.54250627
# Iteration 403, loss = 8.50620519
# Iteration 404, loss = 8.46997156
# Iteration 405, loss = 8.43380581
# Iteration 406, loss = 8.39770832
# Iteration 407, loss = 8.36167950
# Iteration 408, loss = 8.32571973
# Iteration 409, loss = 8.28982940
# Iteration 410, loss = 8.25400888
# Iteration 411, loss = 8.21825853
# Iteration 412, loss = 8.18257873
# Iteration 413, loss = 8.14696982
# Iteration 414, loss = 8.11143216
# Iteration 415, loss = 8.07596611
# Iteration 416, loss = 8.04057199
# Iteration 417, loss = 8.00525016
# Iteration 418, loss = 7.97000095
# Iteration 419, loss = 7.93482470
# Iteration 420, loss = 7.89972172
# Iteration 421, loss = 7.86469236
# Iteration 422, loss = 7.82973692
# Iteration 423, loss = 7.79485574
# Iteration 424, loss = 7.76004912
# Iteration 425, loss = 7.72531739
# Iteration 426, loss = 7.69066084
# Iteration 427, loss = 7.65607980
# Iteration 428, loss = 7.62157457
# Iteration 429, loss = 7.58714545
# Iteration 430, loss = 7.55279274
# Iteration 431, loss = 7.51851674
# Iteration 432, loss = 7.48431775
# Iteration 433, loss = 7.45019605
# Iteration 434, loss = 7.41615195
# Iteration 435, loss = 7.38218572
# Iteration 436, loss = 7.34829766
# Iteration 437, loss = 7.31448805
# Iteration 438, loss = 7.28075717
# Iteration 439, loss = 7.24710530
# Iteration 440, loss = 7.21353272
# Iteration 441, loss = 7.18003970
# Iteration 442, loss = 7.14662651
# Iteration 443, loss = 7.11329344
# Iteration 444, loss = 7.08004073
# Iteration 445, loss = 7.04686866
# Iteration 446, loss = 7.01377750
# Iteration 447, loss = 6.98076750
# Iteration 448, loss = 6.94783892
# Iteration 449, loss = 6.91499203
# Iteration 450, loss = 6.88222706
# Iteration 451, loss = 6.84954429
# Iteration 452, loss = 6.81694394
# Iteration 453, loss = 6.78442628
# Iteration 454, loss = 6.75199155
# Iteration 455, loss = 6.71963999
# Iteration 456, loss = 6.68737185
# Iteration 457, loss = 6.65518735
# Iteration 458, loss = 6.62308674
# Iteration 459, loss = 6.59107024
# Iteration 460, loss = 6.55913810
# Iteration 461, loss = 6.52729054
# Iteration 462, loss = 6.49552778
# Iteration 463, loss = 6.46385006
# Iteration 464, loss = 6.43225759
# Iteration 465, loss = 6.40075059
# Iteration 466, loss = 6.36932927
# Iteration 467, loss = 6.33799387
# Iteration 468, loss = 6.30674457
# Iteration 469, loss = 6.27558161
# Iteration 470, loss = 6.24450517
# Iteration 471, loss = 6.21351548
# Iteration 472, loss = 6.18261272
# Iteration 473, loss = 6.15179711
# Iteration 474, loss = 6.12106884
# Iteration 475, loss = 6.09042810
# Iteration 476, loss = 6.05987509
# Iteration 477, loss = 6.02940999
# Iteration 478, loss = 5.99903301
# Iteration 479, loss = 5.96874431
# Iteration 480, loss = 5.93854409
# Iteration 481, loss = 5.90843252
# Iteration 482, loss = 5.87840978
# Iteration 483, loss = 5.84847606
# Iteration 484, loss = 5.81863151
# Iteration 485, loss = 5.78887632
# Iteration 486, loss = 5.75921065
# Iteration 487, loss = 5.72963466
# Iteration 488, loss = 5.70014852
# Iteration 489, loss = 5.67075240
# Iteration 490, loss = 5.64144644
# Iteration 491, loss = 5.61223080
# Iteration 492, loss = 5.58310564
# Iteration 493, loss = 5.55407110
# Iteration 494, loss = 5.52512734
# Iteration 495, loss = 5.49627450
# Iteration 496, loss = 5.46751272
# Iteration 497, loss = 5.43884215
# Iteration 498, loss = 5.41026291
# Iteration 499, loss = 5.38177515
# Iteration 500, loss = 5.35337900
# Iteration 501, loss = 5.32507458
# Iteration 502, loss = 5.29686203
# Iteration 503, loss = 5.26874147
# Iteration 504, loss = 5.24071302
# Iteration 505, loss = 5.21277681
# Iteration 506, loss = 5.18493294
# Iteration 507, loss = 5.15718153
# Iteration 508, loss = 5.12952270
# Iteration 509, loss = 5.10195656
# Iteration 510, loss = 5.07448320
# Iteration 511, loss = 5.04710275
# Iteration 512, loss = 5.01981528
# Iteration 513, loss = 4.99262092
# Iteration 514, loss = 4.96551974
# Iteration 515, loss = 4.93851186
# Iteration 516, loss = 4.91159734
# Iteration 517, loss = 4.88477630
# Iteration 518, loss = 4.85804880
# Iteration 519, loss = 4.83141494
# Iteration 520, loss = 4.80487480
# Iteration 521, loss = 4.77842845
# Iteration 522, loss = 4.75207596
# Iteration 523, loss = 4.72581742
# Iteration 524, loss = 4.69965289
# Iteration 525, loss = 4.67358244
# Iteration 526, loss = 4.64760614
# Iteration 527, loss = 4.62172404
# Iteration 528, loss = 4.59593621
# Iteration 529, loss = 4.57024271
# Iteration 530, loss = 4.54464358
# Iteration 531, loss = 4.51913888
# Iteration 532, loss = 4.49372867
# Iteration 533, loss = 4.46841298
# Iteration 534, loss = 4.44319186
# Iteration 535, loss = 4.41806536
# Iteration 536, loss = 4.39303351
# Iteration 537, loss = 4.36809635
# Iteration 538, loss = 4.34325391
# Iteration 539, loss = 4.31850623
# Iteration 540, loss = 4.29385333
# Iteration 541, loss = 4.26929523
# Iteration 542, loss = 4.24483197
# Iteration 543, loss = 4.22046357
# Iteration 544, loss = 4.19619003
# Iteration 545, loss = 4.17201139
# Iteration 546, loss = 4.14792764
# Iteration 547, loss = 4.12393881
# Iteration 548, loss = 4.10004489
# Iteration 549, loss = 4.07624590
# Iteration 550, loss = 4.05254184
# Iteration 551, loss = 4.02893271
# Iteration 552, loss = 4.00541851
# Iteration 553, loss = 3.98199923
# Iteration 554, loss = 3.95867486
# Iteration 555, loss = 3.93544540
# Iteration 556, loss = 3.91231083
# Iteration 557, loss = 3.88927114
# Iteration 558, loss = 3.86632631
# Iteration 559, loss = 3.84347632
# Iteration 560, loss = 3.82072115
# Iteration 561, loss = 3.79806078
# Iteration 562, loss = 3.77549517
# Iteration 563, loss = 3.75302430
# Iteration 564, loss = 3.73064813
# Iteration 565, loss = 3.70836663
# Iteration 566, loss = 3.68617977
# Iteration 567, loss = 3.66408750
# Iteration 568, loss = 3.64208978
# Iteration 569, loss = 3.62018657
# Iteration 570, loss = 3.59837781
# Iteration 571, loss = 3.57666346
# Iteration 572, loss = 3.55504348
# Iteration 573, loss = 3.53351779
# Iteration 574, loss = 3.51208635
# Iteration 575, loss = 3.49074910
# Iteration 576, loss = 3.46950597
# Iteration 577, loss = 3.44835691
# Iteration 578, loss = 3.42730183
# Iteration 579, loss = 3.40634069
# Iteration 580, loss = 3.38547340
# Iteration 581, loss = 3.36469988
# Iteration 582, loss = 3.34402008
# Iteration 583, loss = 3.32343390
# Iteration 584, loss = 3.30294126
# Iteration 585, loss = 3.28254209
# Iteration 586, loss = 3.26223629
# Iteration 587, loss = 3.24202378
# Iteration 588, loss = 3.22190448
# Iteration 589, loss = 3.20187827
# Iteration 590, loss = 3.18194509
# Iteration 591, loss = 3.16210481
# Iteration 592, loss = 3.14235735
# Iteration 593, loss = 3.12270261
# Iteration 594, loss = 3.10314047
# Iteration 595, loss = 3.08367084
# Iteration 596, loss = 3.06429361
# Iteration 597, loss = 3.04500866
# Iteration 598, loss = 3.02581589
# Iteration 599, loss = 3.00671517
# Iteration 600, loss = 2.98770639
# Iteration 601, loss = 2.96878944
# Iteration 602, loss = 2.94996418
# Iteration 603, loss = 2.93123050
# Iteration 604, loss = 2.91258828
# Iteration 605, loss = 2.89403737
# Iteration 606, loss = 2.87557765
# Iteration 607, loss = 2.85720900
# Iteration 608, loss = 2.83893127
# Iteration 609, loss = 2.82074432
# Iteration 610, loss = 2.80264803
# Iteration 611, loss = 2.78464225
# Iteration 612, loss = 2.76672683
# Iteration 613, loss = 2.74890163
# Iteration 614, loss = 2.73116651
# Iteration 615, loss = 2.71352132
# Iteration 616, loss = 2.69596589
# Iteration 617, loss = 2.67850009
# Iteration 618, loss = 2.66112376
# Iteration 619, loss = 2.64383674
# Iteration 620, loss = 2.62663886
# Iteration 621, loss = 2.60952998
# Iteration 622, loss = 2.59250992
# Iteration 623, loss = 2.57557852
# Iteration 624, loss = 2.55873562
# Iteration 625, loss = 2.54198104
# Iteration 626, loss = 2.52531462
# Iteration 627, loss = 2.50873618
# Iteration 628, loss = 2.49224556
# Iteration 629, loss = 2.47584256
# Iteration 630, loss = 2.45952701
# Iteration 631, loss = 2.44329874
# Iteration 632, loss = 2.42715757
# Iteration 633, loss = 2.41110330
# Iteration 634, loss = 2.39513575
# Iteration 635, loss = 2.37925474
# Iteration 636, loss = 2.36346008
# Iteration 637, loss = 2.34775157
# Iteration 638, loss = 2.33212903
# Iteration 639, loss = 2.31659226
# Iteration 640, loss = 2.30114106
# Iteration 641, loss = 2.28577523
# Iteration 642, loss = 2.27049459
# Iteration 643, loss = 2.25529891
# Iteration 644, loss = 2.24018801
# Iteration 645, loss = 2.22516168
# Iteration 646, loss = 2.21021972
# Iteration 647, loss = 2.19536190
# Iteration 648, loss = 2.18058804
# Iteration 649, loss = 2.16589791
# Iteration 650, loss = 2.15129130
# Iteration 651, loss = 2.13676800
# Iteration 652, loss = 2.12232779
# Iteration 653, loss = 2.10797046
# Iteration 654, loss = 2.09369579
# Iteration 655, loss = 2.07950356
# Iteration 656, loss = 2.06539354
# Iteration 657, loss = 2.05136552
# Iteration 658, loss = 2.03741926
# Iteration 659, loss = 2.02355455
# Iteration 660, loss = 2.00977116
# Iteration 661, loss = 1.99606885
# Iteration 662, loss = 1.98244740
# Iteration 663, loss = 1.96890658
# Iteration 664, loss = 1.95544615
# Iteration 665, loss = 1.94206588
# Iteration 666, loss = 1.92876553
# Iteration 667, loss = 1.91554487
# Iteration 668, loss = 1.90240366
# Iteration 669, loss = 1.88934166
# Iteration 670, loss = 1.87635863
# Iteration 671, loss = 1.86345432
# Iteration 672, loss = 1.85062850
# Iteration 673, loss = 1.83788092
# Iteration 674, loss = 1.82521133
# Iteration 675, loss = 1.81261949
# Iteration 676, loss = 1.80010515
# Iteration 677, loss = 1.78766806
# Iteration 678, loss = 1.77530797
# Iteration 679, loss = 1.76302462
# Iteration 680, loss = 1.75081778
# Iteration 681, loss = 1.73868718
# Iteration 682, loss = 1.72663256
# Iteration 683, loss = 1.71465368
# Iteration 684, loss = 1.70275028
# Iteration 685, loss = 1.69092209
# Iteration 686, loss = 1.67916886
# Iteration 687, loss = 1.66749034
# Iteration 688, loss = 1.65588625
# Iteration 689, loss = 1.64435634
# Iteration 690, loss = 1.63290034
# Iteration 691, loss = 1.62151800
# Iteration 692, loss = 1.61020904
# Iteration 693, loss = 1.59897321
# Iteration 694, loss = 1.58781023
# Iteration 695, loss = 1.57671984
# Iteration 696, loss = 1.56570177
# Iteration 697, loss = 1.55475575
# Iteration 698, loss = 1.54388151
# Iteration 699, loss = 1.53307879
# Iteration 700, loss = 1.52234730
# Iteration 701, loss = 1.51168679
# Iteration 702, loss = 1.50109697
# Iteration 703, loss = 1.49057757
# Iteration 704, loss = 1.48012833
# Iteration 705, loss = 1.46974895
# Iteration 706, loss = 1.45943918
# Iteration 707, loss = 1.44919873
# Iteration 708, loss = 1.43902732
# Iteration 709, loss = 1.42892468
# Iteration 710, loss = 1.41889054
# Iteration 711, loss = 1.40892460
# Iteration 712, loss = 1.39902660
# Iteration 713, loss = 1.38919624
# Iteration 714, loss = 1.37943327
# Iteration 715, loss = 1.36973738
# Iteration 716, loss = 1.36010830
# Iteration 717, loss = 1.35054575
# Iteration 718, loss = 1.34104945
# Iteration 719, loss = 1.33161911
# Iteration 720, loss = 1.32225445
# Iteration 721, loss = 1.31295518
# Iteration 722, loss = 1.30372103
# Iteration 723, loss = 1.29455171
# Iteration 724, loss = 1.28544692
# Iteration 725, loss = 1.27640640
# Iteration 726, loss = 1.26742984
# Iteration 727, loss = 1.25851697
# Iteration 728, loss = 1.24966750
# Iteration 729, loss = 1.24088114
# Iteration 730, loss = 1.23215761
# Iteration 731, loss = 1.22349662
# Iteration 732, loss = 1.21489787
# Iteration 733, loss = 1.20636109
# Iteration 734, loss = 1.19788599
# Iteration 735, loss = 1.18947227
# Iteration 736, loss = 1.18111965
# Iteration 737, loss = 1.17282784
# Iteration 738, loss = 1.16459655
# Iteration 739, loss = 1.15642549
# Iteration 740, loss = 1.14831438
# Iteration 741, loss = 1.14026292
# Iteration 742, loss = 1.13227082
# Iteration 743, loss = 1.12433780
# Iteration 744, loss = 1.11646357
# Iteration 745, loss = 1.10864783
# Iteration 746, loss = 1.10089030
# Iteration 747, loss = 1.09319069
# Iteration 748, loss = 1.08554870
# Iteration 749, loss = 1.07796405
# Iteration 750, loss = 1.07043646
# Iteration 751, loss = 1.06296562
# Iteration 752, loss = 1.05555125
# Iteration 753, loss = 1.04819306
# Iteration 754, loss = 1.04089076
# Iteration 755, loss = 1.03364406
# Iteration 756, loss = 1.02645267
# Iteration 757, loss = 1.01931631
# Iteration 758, loss = 1.01223468
# Iteration 759, loss = 1.00520750
# Iteration 760, loss = 0.99823447
# Iteration 761, loss = 0.99131531
# Iteration 762, loss = 0.98444973
# Iteration 763, loss = 0.97763744
# Iteration 764, loss = 0.97087816
# Iteration 765, loss = 0.96417158
# Iteration 766, loss = 0.95751744
# Iteration 767, loss = 0.95091544
# Iteration 768, loss = 0.94436529
# Iteration 769, loss = 0.93786671
# Iteration 770, loss = 0.93141941
# Iteration 771, loss = 0.92502311
# Iteration 772, loss = 0.91867751
# Iteration 773, loss = 0.91238234
# Iteration 774, loss = 0.90613730
# Iteration 775, loss = 0.89994212
# Iteration 776, loss = 0.89379651
# Iteration 777, loss = 0.88770018
# Iteration 778, loss = 0.88165285
# Iteration 779, loss = 0.87565424
# Iteration 780, loss = 0.86970407
# Iteration 781, loss = 0.86380204
# Iteration 782, loss = 0.85794789
# Iteration 783, loss = 0.85214133
# Iteration 784, loss = 0.84638207
# Iteration 785, loss = 0.84066985
# Iteration 786, loss = 0.83500437
# Iteration 787, loss = 0.82938535
# Iteration 788, loss = 0.82381253
# Iteration 789, loss = 0.81828561
# Iteration 790, loss = 0.81280433
# Iteration 791, loss = 0.80736840
# Iteration 792, loss = 0.80197754
# Iteration 793, loss = 0.79663149
# Iteration 794, loss = 0.79132996
# Iteration 795, loss = 0.78607268
# Iteration 796, loss = 0.78085938
# Iteration 797, loss = 0.77568977
# Iteration 798, loss = 0.77056359
# Iteration 799, loss = 0.76548057
# Iteration 800, loss = 0.76044043
# Iteration 801, loss = 0.75544290
# Iteration 802, loss = 0.75048771
# Iteration 803, loss = 0.74557458
# Iteration 804, loss = 0.74070326
# Iteration 805, loss = 0.73587347
# Iteration 806, loss = 0.73108494
# Iteration 807, loss = 0.72633740
# Iteration 808, loss = 0.72163060
# Iteration 809, loss = 0.71696425
# Iteration 810, loss = 0.71233810
# Iteration 811, loss = 0.70775189
# Iteration 812, loss = 0.70320534
# Iteration 813, loss = 0.69869819
# Iteration 814, loss = 0.69423019
# Iteration 815, loss = 0.68980107
# Iteration 816, loss = 0.68541057
# Iteration 817, loss = 0.68105843
# Iteration 818, loss = 0.67674439
# Iteration 819, loss = 0.67246820
# Iteration 820, loss = 0.66822958
# Iteration 821, loss = 0.66402830
# Iteration 822, loss = 0.65986409
# Iteration 823, loss = 0.65573669
# Iteration 824, loss = 0.65164586
# Iteration 825, loss = 0.64759134
# Iteration 826, loss = 0.64357287
# Iteration 827, loss = 0.63959021
# Iteration 828, loss = 0.63564310
# Iteration 829, loss = 0.63173130
# Iteration 830, loss = 0.62785455
# Iteration 831, loss = 0.62401260
# Iteration 832, loss = 0.62020522
# Iteration 833, loss = 0.61643215
# Iteration 834, loss = 0.61269315
# Iteration 835, loss = 0.60898797
# Iteration 836, loss = 0.60531637
# Iteration 837, loss = 0.60167810
# Iteration 838, loss = 0.59807293
# Iteration 839, loss = 0.59450061
# Iteration 840, loss = 0.59096091
# Iteration 841, loss = 0.58745358
# Iteration 842, loss = 0.58397839
# Iteration 843, loss = 0.58053510
# Iteration 844, loss = 0.57712347
# Iteration 845, loss = 0.57374327
# Iteration 846, loss = 0.57039426
# Iteration 847, loss = 0.56707622
# Iteration 848, loss = 0.56378890
# Iteration 849, loss = 0.56053208
# Iteration 850, loss = 0.55730553
# Iteration 851, loss = 0.55410902
# Iteration 852, loss = 0.55094231
# Iteration 853, loss = 0.54780519
# Iteration 854, loss = 0.54469742
# Iteration 855, loss = 0.54161879
# Iteration 856, loss = 0.53856906
# Iteration 857, loss = 0.53554802
# Iteration 858, loss = 0.53255544
# Iteration 859, loss = 0.52959110
# Iteration 860, loss = 0.52665478
# Iteration 861, loss = 0.52374626
# Iteration 862, loss = 0.52086532
# Iteration 863, loss = 0.51801175
# Iteration 864, loss = 0.51518533
# Iteration 865, loss = 0.51238585
# Iteration 866, loss = 0.50961309
# Iteration 867, loss = 0.50686683
# Iteration 868, loss = 0.50414688
# Iteration 869, loss = 0.50145301
# Iteration 870, loss = 0.49878501
# Iteration 871, loss = 0.49614269
# Iteration 872, loss = 0.49352582
# Iteration 873, loss = 0.49093421
# Iteration 874, loss = 0.48836765
# Iteration 875, loss = 0.48582593
# Iteration 876, loss = 0.48330886
# Iteration 877, loss = 0.48081622
# Iteration 878, loss = 0.47834782
# Iteration 879, loss = 0.47590346
# Iteration 880, loss = 0.47348293
# Iteration 881, loss = 0.47108605
# Iteration 882, loss = 0.46871261
# Iteration 883, loss = 0.46636242
# Iteration 884, loss = 0.46403528
# Iteration 885, loss = 0.46173101
# Iteration 886, loss = 0.45944940
# Iteration 887, loss = 0.45719026
# Iteration 888, loss = 0.45495342
# Iteration 889, loss = 0.45273867
# Iteration 890, loss = 0.45054582
# Iteration 891, loss = 0.44837470
# Iteration 892, loss = 0.44622511
# Iteration 893, loss = 0.44409688
# Iteration 894, loss = 0.44198981
# Iteration 895, loss = 0.43990372
# Iteration 896, loss = 0.43783843
# Iteration 897, loss = 0.43579377
# Iteration 898, loss = 0.43376955
# Iteration 899, loss = 0.43176559
# Iteration 900, loss = 0.42978171
# Iteration 901, loss = 0.42781775
# Iteration 902, loss = 0.42587352
# Iteration 903, loss = 0.42394885
# Iteration 904, loss = 0.42204356
# Iteration 905, loss = 0.42015749
# Iteration 906, loss = 0.41829047
# Iteration 907, loss = 0.41644232
# Iteration 908, loss = 0.41461287
# Iteration 909, loss = 0.41280197
# Iteration 910, loss = 0.41100943
# Iteration 911, loss = 0.40923510
# Iteration 912, loss = 0.40747881
# Iteration 913, loss = 0.40574039
# Iteration 914, loss = 0.40401969
# Iteration 915, loss = 0.40231655
# Iteration 916, loss = 0.40063080
# Iteration 917, loss = 0.39896228
# Iteration 918, loss = 0.39731084
# Iteration 919, loss = 0.39567632
# Iteration 920, loss = 0.39405856
# Iteration 921, loss = 0.39245741
# Iteration 922, loss = 0.39087271
# Iteration 923, loss = 0.38930432
# Iteration 924, loss = 0.38775207
# Iteration 925, loss = 0.38621582
# Iteration 926, loss = 0.38469543
# Iteration 927, loss = 0.38319073
# Iteration 928, loss = 0.38170158
# Iteration 929, loss = 0.38022784
# Iteration 930, loss = 0.37876936
# Iteration 931, loss = 0.37732599
# Iteration 932, loss = 0.37589760
# Iteration 933, loss = 0.37448404
# Iteration 934, loss = 0.37308516
# Iteration 935, loss = 0.37170083
# Iteration 936, loss = 0.37033091
# Iteration 937, loss = 0.36897526
# Iteration 938, loss = 0.36763374
# Iteration 939, loss = 0.36630621
# Iteration 940, loss = 0.36499255
# Iteration 941, loss = 0.36369261
# Iteration 942, loss = 0.36240626
# Iteration 943, loss = 0.36113337
# Iteration 944, loss = 0.35987381
# Iteration 945, loss = 0.35862745
# Iteration 946, loss = 0.35739415
# Iteration 947, loss = 0.35617379
# Iteration 948, loss = 0.35496625
# Iteration 949, loss = 0.35377138
# Iteration 950, loss = 0.35258908
# Iteration 951, loss = 0.35141922
# Iteration 952, loss = 0.35026166
# Iteration 953, loss = 0.34911629
# Iteration 954, loss = 0.34798299
# Iteration 955, loss = 0.34686163
# Iteration 956, loss = 0.34575210
# Iteration 957, loss = 0.34465427
# Iteration 958, loss = 0.34356803
# Iteration 959, loss = 0.34249327
# Iteration 960, loss = 0.34142986
# Iteration 961, loss = 0.34037768
# Iteration 962, loss = 0.33933664
# Iteration 963, loss = 0.33830660
# Iteration 964, loss = 0.33728747
# Iteration 965, loss = 0.33627912
# Iteration 966, loss = 0.33528145
# Iteration 967, loss = 0.33429434
# Iteration 968, loss = 0.33331770
# Iteration 969, loss = 0.33235140
# Iteration 970, loss = 0.33139535
# Iteration 971, loss = 0.33044943
# Iteration 972, loss = 0.32951355
# Iteration 973, loss = 0.32858759
# Iteration 974, loss = 0.32767146
# Iteration 975, loss = 0.32676505
# Iteration 976, loss = 0.32586825
# Iteration 977, loss = 0.32498098
# Iteration 978, loss = 0.32410312
# Iteration 979, loss = 0.32323458
# Iteration 980, loss = 0.32237526
# Iteration 981, loss = 0.32152506
# Iteration 982, loss = 0.32068389
# Iteration 983, loss = 0.31985164
# Iteration 984, loss = 0.31902824
# Iteration 985, loss = 0.31821357
# Iteration 986, loss = 0.31740754
# Iteration 987, loss = 0.31661007
# Iteration 988, loss = 0.31582107
# Iteration 989, loss = 0.31504043
# Iteration 990, loss = 0.31426808
# Iteration 991, loss = 0.31350391
# Iteration 992, loss = 0.31274785
# Iteration 993, loss = 0.31199980
# Iteration 994, loss = 0.31125968
# Iteration 995, loss = 0.31052740
# Iteration 996, loss = 0.30980288
# Iteration 997, loss = 0.30908603
# Iteration 998, loss = 0.30837676
# Iteration 999, loss = 0.30767500
# Iteration 1000, loss = 0.30698066
# Iteration 1001, loss = 0.30629366
# Iteration 1002, loss = 0.30561392
# Iteration 1003, loss = 0.30494135
# Iteration 1004, loss = 0.30427589
# Iteration 1005, loss = 0.30361744
# Iteration 1006, loss = 0.30296593
# Iteration 1007, loss = 0.30232129
# Iteration 1008, loss = 0.30168344
# Iteration 1009, loss = 0.30105230
# Iteration 1010, loss = 0.30042780
# Iteration 1011, loss = 0.29980985
# Iteration 1012, loss = 0.29919840
# Iteration 1013, loss = 0.29859336
# Iteration 1014, loss = 0.29799466
# Iteration 1015, loss = 0.29740224
# Iteration 1016, loss = 0.29681601
# Iteration 1017, loss = 0.29623592
# Iteration 1018, loss = 0.29566188
# Iteration 1019, loss = 0.29509384
# Iteration 1020, loss = 0.29453172
# Iteration 1021, loss = 0.29397545
# Iteration 1022, loss = 0.29342497
# Iteration 1023, loss = 0.29288021
# Iteration 1024, loss = 0.29234111
# Iteration 1025, loss = 0.29180760
# Iteration 1026, loss = 0.29127962
# Iteration 1027, loss = 0.29075709
# Iteration 1028, loss = 0.29023997
# Iteration 1029, loss = 0.28972818
# Iteration 1030, loss = 0.28922167
# Iteration 1031, loss = 0.28872037
# Iteration 1032, loss = 0.28822422
# Iteration 1033, loss = 0.28773317
# Iteration 1034, loss = 0.28724715
# Iteration 1035, loss = 0.28676610
# Iteration 1036, loss = 0.28628996
# Iteration 1037, loss = 0.28581869
# Iteration 1038, loss = 0.28535221
# Iteration 1039, loss = 0.28489048
# Iteration 1040, loss = 0.28443344
# Iteration 1041, loss = 0.28398102
# Iteration 1042, loss = 0.28353319
# Iteration 1043, loss = 0.28308988
# Iteration 1044, loss = 0.28265104
# Iteration 1045, loss = 0.28221661
# Iteration 1046, loss = 0.28178654
# Iteration 1047, loss = 0.28136079
# Iteration 1048, loss = 0.28093930
# Iteration 1049, loss = 0.28052201
# Iteration 1050, loss = 0.28010889
# Iteration 1051, loss = 0.27969987
# Iteration 1052, loss = 0.27929491
# Iteration 1053, loss = 0.27889396
# Iteration 1054, loss = 0.27849696
# Iteration 1055, loss = 0.27810389
# Iteration 1056, loss = 0.27771467
# Iteration 1057, loss = 0.27732928
# Iteration 1058, loss = 0.27694766
# Iteration 1059, loss = 0.27656976
# Iteration 1060, loss = 0.27619554
# Iteration 1061, loss = 0.27582496
# Iteration 1062, loss = 0.27545797
# Iteration 1063, loss = 0.27509453
# Iteration 1064, loss = 0.27473459
# Iteration 1065, loss = 0.27437811
# Iteration 1066, loss = 0.27402505
# Iteration 1067, loss = 0.27367536
# Iteration 1068, loss = 0.27332901
# Iteration 1069, loss = 0.27298595
# Iteration 1070, loss = 0.27264614
# Iteration 1071, loss = 0.27230954
# Iteration 1072, loss = 0.27197611
# Iteration 1073, loss = 0.27164582
# Iteration 1074, loss = 0.27131862
# Iteration 1075, loss = 0.27099447
# Iteration 1076, loss = 0.27067333
# Iteration 1077, loss = 0.27035518
# Iteration 1078, loss = 0.27003997
# Iteration 1079, loss = 0.26972765
# Iteration 1080, loss = 0.26941821
# Iteration 1081, loss = 0.26911160
# Iteration 1082, loss = 0.26880778
# Iteration 1083, loss = 0.26850672
# Iteration 1084, loss = 0.26820839
# Iteration 1085, loss = 0.26791275
# Iteration 1086, loss = 0.26761976
# Iteration 1087, loss = 0.26732940
# Iteration 1088, loss = 0.26704162
# Iteration 1089, loss = 0.26675640
# Iteration 1090, loss = 0.26647371
# Iteration 1091, loss = 0.26619350
# Iteration 1092, loss = 0.26591576
# Iteration 1093, loss = 0.26564044
# Iteration 1094, loss = 0.26536752
# Iteration 1095, loss = 0.26509696
# Iteration 1096, loss = 0.26482874
# Iteration 1097, loss = 0.26456282
# Iteration 1098, loss = 0.26429918
# Iteration 1099, loss = 0.26403778
# Iteration 1100, loss = 0.26377861
# Iteration 1101, loss = 0.26352161
# Iteration 1102, loss = 0.26326678
# Iteration 1103, loss = 0.26301408
# Iteration 1104, loss = 0.26276348
# Iteration 1105, loss = 0.26251496
# Iteration 1106, loss = 0.26226849
# Iteration 1107, loss = 0.26202404
# Iteration 1108, loss = 0.26178158
# Iteration 1109, loss = 0.26154110
# Iteration 1110, loss = 0.26130255
# Iteration 1111, loss = 0.26106593
# Iteration 1112, loss = 0.26083120
# Iteration 1113, loss = 0.26059833
# Iteration 1114, loss = 0.26036731
# Iteration 1115, loss = 0.26013811
# Iteration 1116, loss = 0.25991070
# Iteration 1117, loss = 0.25968506
# Iteration 1118, loss = 0.25946117
# Iteration 1119, loss = 0.25923901
# Iteration 1120, loss = 0.25901854
# Iteration 1121, loss = 0.25879976
# Iteration 1122, loss = 0.25858263
# Iteration 1123, loss = 0.25836713
# Iteration 1124, loss = 0.25815324
# Iteration 1125, loss = 0.25794095
# Iteration 1126, loss = 0.25773022
# Iteration 1127, loss = 0.25752105
# Iteration 1128, loss = 0.25731340
# Iteration 1129, loss = 0.25710725
# Iteration 1130, loss = 0.25690259
# Iteration 1131, loss = 0.25669940
# Iteration 1132, loss = 0.25649765
# Iteration 1133, loss = 0.25629734
# Iteration 1134, loss = 0.25609842
# Iteration 1135, loss = 0.25590090
# Iteration 1136, loss = 0.25570475
# Iteration 1137, loss = 0.25550994
# Iteration 1138, loss = 0.25531647
# Iteration 1139, loss = 0.25512431
# Iteration 1140, loss = 0.25493345
# Iteration 1141, loss = 0.25474387
# Iteration 1142, loss = 0.25455555
# Iteration 1143, loss = 0.25436847
# Iteration 1144, loss = 0.25418262
# Iteration 1145, loss = 0.25399798
# Iteration 1146, loss = 0.25381453
# Iteration 1147, loss = 0.25363226
# Iteration 1148, loss = 0.25345115
# Iteration 1149, loss = 0.25327118
# Iteration 1150, loss = 0.25309234
# Iteration 1151, loss = 0.25291462
# Iteration 1152, loss = 0.25273799
# Iteration 1153, loss = 0.25256244
# Iteration 1154, loss = 0.25238796
# Iteration 1155, loss = 0.25221454
# Iteration 1156, loss = 0.25204215
# Iteration 1157, loss = 0.25187078
# Iteration 1158, loss = 0.25170043
# Iteration 1159, loss = 0.25153107
# Iteration 1160, loss = 0.25136269
# Iteration 1161, loss = 0.25119527
# Iteration 1162, loss = 0.25102881
# Iteration 1163, loss = 0.25086330
# Iteration 1164, loss = 0.25069870
# Iteration 1165, loss = 0.25053503
# Iteration 1166, loss = 0.25037225
# Iteration 1167, loss = 0.25021036
# Iteration 1168, loss = 0.25004935
# Iteration 1169, loss = 0.24988920
# Iteration 1170, loss = 0.24972990
# Iteration 1171, loss = 0.24957145
# Iteration 1172, loss = 0.24941382
# Iteration 1173, loss = 0.24925700
# Iteration 1174, loss = 0.24910099
# Iteration 1175, loss = 0.24894577
# Iteration 1176, loss = 0.24879134
# Iteration 1177, loss = 0.24863767
# Iteration 1178, loss = 0.24848476
# Iteration 1179, loss = 0.24833260
# Iteration 1180, loss = 0.24818118
# Iteration 1181, loss = 0.24803049
# Iteration 1182, loss = 0.24788051
# Iteration 1183, loss = 0.24773124
# Iteration 1184, loss = 0.24758267
# Iteration 1185, loss = 0.24743478
# Iteration 1186, loss = 0.24728757
# Iteration 1187, loss = 0.24714102
# Iteration 1188, loss = 0.24699513
# Iteration 1189, loss = 0.24684989
# Iteration 1190, loss = 0.24670529
# Iteration 1191, loss = 0.24656132
# Iteration 1192, loss = 0.24641797
# Iteration 1193, loss = 0.24627522
# Iteration 1194, loss = 0.24613308
# Iteration 1195, loss = 0.24599154
# Iteration 1196, loss = 0.24585058
# Iteration 1197, loss = 0.24571019
# Iteration 1198, loss = 0.24557037
# Iteration 1199, loss = 0.24543112
# Iteration 1200, loss = 0.24529241
# Iteration 1201, loss = 0.24515425
# Iteration 1202, loss = 0.24501662
# Iteration 1203, loss = 0.24487952
# Iteration 1204, loss = 0.24474294
# Iteration 1205, loss = 0.24460687
# Iteration 1206, loss = 0.24447131
# Iteration 1207, loss = 0.24433624
# Iteration 1208, loss = 0.24420167
# Iteration 1209, loss = 0.24406758
# Iteration 1210, loss = 0.24393396
# Iteration 1211, loss = 0.24380081
# Iteration 1212, loss = 0.24366813
# Iteration 1213, loss = 0.24353590
# Iteration 1214, loss = 0.24340411
# Iteration 1215, loss = 0.24327277
# Iteration 1216, loss = 0.24314187
# Iteration 1217, loss = 0.24301139
# Iteration 1218, loss = 0.24288134
# Iteration 1219, loss = 0.24275170
# Iteration 1220, loss = 0.24262248
# Iteration 1221, loss = 0.24249365
# Iteration 1222, loss = 0.24236523
# Iteration 1223, loss = 0.24223719
# Iteration 1224, loss = 0.24210955
# Iteration 1225, loss = 0.24198228
# Iteration 1226, loss = 0.24185539
# Iteration 1227, loss = 0.24172887
# Iteration 1228, loss = 0.24160271
# Iteration 1229, loss = 0.24147691
# Iteration 1230, loss = 0.24135146
# Iteration 1231, loss = 0.24122636
# Iteration 1232, loss = 0.24110161
# Iteration 1233, loss = 0.24097719
# Iteration 1234, loss = 0.24085310
# Iteration 1235, loss = 0.24072934
# Iteration 1236, loss = 0.24060591
# Iteration 1237, loss = 0.24048279
# Iteration 1238, loss = 0.24035998
# Iteration 1239, loss = 0.24023748
# Iteration 1240, loss = 0.24011529
# Iteration 1241, loss = 0.23999339
# Iteration 1242, loss = 0.23987179
# Iteration 1243, loss = 0.23975048
# Iteration 1244, loss = 0.23962946
# Iteration 1245, loss = 0.23950872
# Iteration 1246, loss = 0.23938825
# Iteration 1247, loss = 0.23926806
# Iteration 1248, loss = 0.23914813
# Iteration 1249, loss = 0.23902848
# Iteration 1250, loss = 0.23890908
# Iteration 1251, loss = 0.23878994
# Iteration 1252, loss = 0.23867105
# Iteration 1253, loss = 0.23855241
# Iteration 1254, loss = 0.23843402
# Iteration 1255, loss = 0.23831587
# Iteration 1256, loss = 0.23819796
# Iteration 1257, loss = 0.23808028
# Iteration 1258, loss = 0.23796283
# Iteration 1259, loss = 0.23784561
# Iteration 1260, loss = 0.23772862
# Iteration 1261, loss = 0.23761185
# Iteration 1262, loss = 0.23749529
# Iteration 1263, loss = 0.23737895
# Iteration 1264, loss = 0.23726282
# Iteration 1265, loss = 0.23714689
# Iteration 1266, loss = 0.23703117
# Iteration 1267, loss = 0.23691566
# Iteration 1268, loss = 0.23680034
# Iteration 1269, loss = 0.23668521
# Iteration 1270, loss = 0.23657028
# Iteration 1271, loss = 0.23645554
# Iteration 1272, loss = 0.23634099
# Iteration 1273, loss = 0.23622662
# Iteration 1274, loss = 0.23611243
# Iteration 1275, loss = 0.23599842
# Iteration 1276, loss = 0.23588458
# Iteration 1277, loss = 0.23577092
# Iteration 1278, loss = 0.23565743
# Iteration 1279, loss = 0.23554410
# Iteration 1280, loss = 0.23543094
# Iteration 1281, loss = 0.23531795
# Iteration 1282, loss = 0.23520511
# Iteration 1283, loss = 0.23509244
# Iteration 1284, loss = 0.23497991
# Iteration 1285, loss = 0.23486755
# Iteration 1286, loss = 0.23475533
# Iteration 1287, loss = 0.23464326
# Iteration 1288, loss = 0.23453134
# Iteration 1289, loss = 0.23441956
# Iteration 1290, loss = 0.23430792
# Iteration 1291, loss = 0.23419643
# Iteration 1292, loss = 0.23408507
# Iteration 1293, loss = 0.23397385
# Iteration 1294, loss = 0.23386276
# Iteration 1295, loss = 0.23375180
# Iteration 1296, loss = 0.23364098
# Iteration 1297, loss = 0.23353028
# Iteration 1298, loss = 0.23341971
# Iteration 1299, loss = 0.23330926
# Iteration 1300, loss = 0.23319893
# Iteration 1301, loss = 0.23308873
# Iteration 1302, loss = 0.23297864
# Iteration 1303, loss = 0.23286867
# Iteration 1304, loss = 0.23275881
# Iteration 1305, loss = 0.23264907
# Iteration 1306, loss = 0.23253944
# Iteration 1307, loss = 0.23242992
# Iteration 1308, loss = 0.23232051
# Iteration 1309, loss = 0.23221121
# Iteration 1310, loss = 0.23210201
# Iteration 1311, loss = 0.23199291
# Iteration 1312, loss = 0.23188392
# Iteration 1313, loss = 0.23177503
# Iteration 1314, loss = 0.23166623
# Iteration 1315, loss = 0.23155754
# Iteration 1316, loss = 0.23144894
# Iteration 1317, loss = 0.23134044
# Iteration 1318, loss = 0.23123203
# Iteration 1319, loss = 0.23112371
# Iteration 1320, loss = 0.23101548
# Iteration 1321, loss = 0.23090734
# Iteration 1322, loss = 0.23079930
# Iteration 1323, loss = 0.23069133
# Iteration 1324, loss = 0.23058346
# Iteration 1325, loss = 0.23047567
# Iteration 1326, loss = 0.23036796
# Iteration 1327, loss = 0.23026033
# Iteration 1328, loss = 0.23015279
# Iteration 1329, loss = 0.23004533
# Iteration 1330, loss = 0.22993794
# Iteration 1331, loss = 0.22983063
# Iteration 1332, loss = 0.22972340
# Iteration 1333, loss = 0.22961625
# Iteration 1334, loss = 0.22950916
# Iteration 1335, loss = 0.22940216
# Iteration 1336, loss = 0.22929522
# Iteration 1337, loss = 0.22918836
# Iteration 1338, loss = 0.22908156
# Iteration 1339, loss = 0.22897484
# Iteration 1340, loss = 0.22886818
# Iteration 1341, loss = 0.22876159
# Iteration 1342, loss = 0.22865507
# Iteration 1343, loss = 0.22854862
# Iteration 1344, loss = 0.22844223
# Iteration 1345, loss = 0.22833590
# Iteration 1346, loss = 0.22822964
# Iteration 1347, loss = 0.22812343
# Iteration 1348, loss = 0.22801729
# Iteration 1349, loss = 0.22791122
# Iteration 1350, loss = 0.22780520
# Iteration 1351, loss = 0.22769924
# Iteration 1352, loss = 0.22759333
# Iteration 1353, loss = 0.22748749
# Iteration 1354, loss = 0.22738170
# Iteration 1355, loss = 0.22727597
# Iteration 1356, loss = 0.22717029
# Iteration 1357, loss = 0.22706467
# Iteration 1358, loss = 0.22695911
# Iteration 1359, loss = 0.22685359
# Iteration 1360, loss = 0.22674813
# Iteration 1361, loss = 0.22664272
# Iteration 1362, loss = 0.22653736
# Iteration 1363, loss = 0.22643206
# Iteration 1364, loss = 0.22632680
# Iteration 1365, loss = 0.22622159
# Iteration 1366, loss = 0.22611643
# Iteration 1367, loss = 0.22601132
# Iteration 1368, loss = 0.22590626
# Iteration 1369, loss = 0.22580124
# Iteration 1370, loss = 0.22569627
# Iteration 1371, loss = 0.22559135
# Iteration 1372, loss = 0.22548647
# Iteration 1373, loss = 0.22538164
# Iteration 1374, loss = 0.22527685
# Iteration 1375, loss = 0.22517210
# Iteration 1376, loss = 0.22506740
# Iteration 1377, loss = 0.22496275
# Iteration 1378, loss = 0.22485813
# Iteration 1379, loss = 0.22475356
# Iteration 1380, loss = 0.22464902
# Iteration 1381, loss = 0.22454453
# Iteration 1382, loss = 0.22444008
# Iteration 1383, loss = 0.22433567
# Iteration 1384, loss = 0.22423130
# Iteration 1385, loss = 0.22412697
# Iteration 1386, loss = 0.22402268
# Iteration 1387, loss = 0.22391843
# Iteration 1388, loss = 0.22381421
# Iteration 1389, loss = 0.22371004
# Iteration 1390, loss = 0.22360590
# Iteration 1391, loss = 0.22350179
# Iteration 1392, loss = 0.22339773
# Iteration 1393, loss = 0.22329370
# Iteration 1394, loss = 0.22318971
# Iteration 1395, loss = 0.22308575
# Iteration 1396, loss = 0.22298183
# Iteration 1397, loss = 0.22287794
# Iteration 1398, loss = 0.22277409
# Iteration 1399, loss = 0.22267027
# Iteration 1400, loss = 0.22256648
# Iteration 1401, loss = 0.22246273
# Iteration 1402, loss = 0.22235901
# Iteration 1403, loss = 0.22225533
# Iteration 1404, loss = 0.22215168
# Iteration 1405, loss = 0.22204806
# Iteration 1406, loss = 0.22194447
# Iteration 1407, loss = 0.22184092
# Iteration 1408, loss = 0.22173740
# Iteration 1409, loss = 0.22163391
# Iteration 1410, loss = 0.22153045
# Iteration 1411, loss = 0.22142702
# Iteration 1412, loss = 0.22132362
# Iteration 1413, loss = 0.22122025
# Iteration 1414, loss = 0.22111692
# Iteration 1415, loss = 0.22101361
# Iteration 1416, loss = 0.22091033
# Iteration 1417, loss = 0.22080709
# Iteration 1418, loss = 0.22070387
# Iteration 1419, loss = 0.22060068
# Iteration 1420, loss = 0.22049752
# Iteration 1421, loss = 0.22039439
# Iteration 1422, loss = 0.22029129
# Iteration 1423, loss = 0.22018822
# Iteration 1424, loss = 0.22008517
# Iteration 1425, loss = 0.21998216
# Iteration 1426, loss = 0.21987917
# Iteration 1427, loss = 0.21977621
# Iteration 1428, loss = 0.21967328
# Iteration 1429, loss = 0.21957037
# Iteration 1430, loss = 0.21946749
# Iteration 1431, loss = 0.21936464
# Iteration 1432, loss = 0.21926182
# Iteration 1433, loss = 0.21915902
# ...
# Iteration 3203, loss = 0.10140506
# Iteration 3204, loss = 0.10138104
# Iteration 3205, loss = 0.10135705
# Iteration 3206, loss = 0.10133311
# Iteration 3207, loss = 0.10130920
# Iteration 3208, loss = 0.10128533
# Iteration 3209, loss = 0.10126150
# Iteration 3210, loss = 0.10123771
# Iteration 3211, loss = 0.10121396
# Iteration 3212, loss = 0.10119025
# Iteration 3213, loss = 0.10116657
# Iteration 3214, loss = 0.10114294
# Iteration 3215, loss = 0.10111934
# Iteration 3216, loss = 0.10109579
# Iteration 3217, loss = 0.10107227
# Iteration 3218, loss = 0.10104879
# Iteration 3219, loss = 0.10102535
# Iteration 3220, loss = 0.10100195
# Iteration 3221, loss = 0.10097859
# Iteration 3222, loss = 0.10095527
# Iteration 3223, loss = 0.10093198
# Iteration 3224, loss = 0.10090874
# Iteration 3225, loss = 0.10088553
# Iteration 3226, loss = 0.10086236
# Iteration 3227, loss = 0.10083923
# Iteration 3228, loss = 0.10081614
# Iteration 3229, loss = 0.10079309
# Iteration 3230, loss = 0.10077007
# Iteration 3231, loss = 0.10074710
# Iteration 3232, loss = 0.10072416
# Iteration 3233, loss = 0.10070126
# Iteration 3234, loss = 0.10067840
# Iteration 3235, loss = 0.10065558
# Iteration 3236, loss = 0.10063279
# Iteration 3237, loss = 0.10061004
# Iteration 3238, loss = 0.10058734
# Iteration 3239, loss = 0.10056467
# Iteration 3240, loss = 0.10054203
# Iteration 3241, loss = 0.10051944
# Iteration 3242, loss = 0.10049688
# Iteration 3243, loss = 0.10047437
# Iteration 3244, loss = 0.10045189
# Iteration 3245, loss = 0.10042944
# Iteration 3246, loss = 0.10040704
# Iteration 3247, loss = 0.10038467
# Iteration 3248, loss = 0.10036234
# Iteration 3249, loss = 0.10034005
# Iteration 3250, loss = 0.10031780
# Iteration 3251, loss = 0.10029559
# Iteration 3252, loss = 0.10027341
# Iteration 3253, loss = 0.10025127
# Iteration 3254, loss = 0.10022916
# Iteration 3255, loss = 0.10020710
# Iteration 3256, loss = 0.10018507
# Iteration 3257, loss = 0.10016308
# Iteration 3258, loss = 0.10014113
# Iteration 3259, loss = 0.10011921
# Iteration 3260, loss = 0.10009734
# Iteration 3261, loss = 0.10007549
# Iteration 3262, loss = 0.10005369
# Iteration 3263, loss = 0.10003192
# Iteration 3264, loss = 0.10001020
# Iteration 3265, loss = 0.09998850
# Iteration 3266, loss = 0.09996685
# Iteration 3267, loss = 0.09994523
# Iteration 3268, loss = 0.09992365
# Iteration 3269, loss = 0.09990211
# Iteration 3270, loss = 0.09988060
# Iteration 3271, loss = 0.09985913
# Iteration 3272, loss = 0.09983770
# Iteration 3273, loss = 0.09981630
# Iteration 3274, loss = 0.09979494
# Iteration 3275, loss = 0.09977362
# Iteration 3276, loss = 0.09975234
# Iteration 3277, loss = 0.09973109
# Iteration 3278, loss = 0.09970988
# Iteration 3279, loss = 0.09968870
# Iteration 3280, loss = 0.09966756
# Iteration 3281, loss = 0.09964646
# Iteration 3282, loss = 0.09962540
# Iteration 3283, loss = 0.09960437
# Iteration 3284, loss = 0.09958337
# Iteration 3285, loss = 0.09956242
# Iteration 3286, loss = 0.09954150
# Iteration 3287, loss = 0.09952061
# Iteration 3288, loss = 0.09949977
# Iteration 3289, loss = 0.09947896
# Iteration 3290, loss = 0.09945818
# Iteration 3291, loss = 0.09943744
# Iteration 3292, loss = 0.09941674
# Iteration 3293, loss = 0.09939608
# Iteration 3294, loss = 0.09937545
# Iteration 3295, loss = 0.09935485
# Iteration 3296, loss = 0.09933429
# Iteration 3297, loss = 0.09931377
# Iteration 3298, loss = 0.09929329
# Iteration 3299, loss = 0.09927284
# Iteration 3300, loss = 0.09925242
# Iteration 3301, loss = 0.09923205
# Iteration 3302, loss = 0.09921170
# Iteration 3303, loss = 0.09919140
# Iteration 3304, loss = 0.09917113
# Iteration 3305, loss = 0.09915089
# Iteration 3306, loss = 0.09913069
# Iteration 3307, loss = 0.09911053
# Iteration 3308, loss = 0.09909040
# Iteration 3309, loss = 0.09907031
# Iteration 3310, loss = 0.09905025
# Iteration 3311, loss = 0.09903023
# Iteration 3312, loss = 0.09901024
# Iteration 3313, loss = 0.09899029
# Iteration 3314, loss = 0.09897037
# Iteration 3315, loss = 0.09895049
# Iteration 3316, loss = 0.09893065
# Iteration 3317, loss = 0.09891084
# Iteration 3318, loss = 0.09889106
# Iteration 3319, loss = 0.09887132
# Iteration 3320, loss = 0.09885162
# Iteration 3321, loss = 0.09883195
# Iteration 3322, loss = 0.09881232
# Iteration 3323, loss = 0.09879272
# Iteration 3324, loss = 0.09877315
# Iteration 3325, loss = 0.09875362
# Iteration 3326, loss = 0.09873413
# Iteration 3327, loss = 0.09871467
# Iteration 3328, loss = 0.09869525
# Iteration 3329, loss = 0.09867586
# Iteration 3330, loss = 0.09865650
# Iteration 3331, loss = 0.09863718
# Iteration 3332, loss = 0.09861789
# Iteration 3333, loss = 0.09859864
# Iteration 3334, loss = 0.09857943
# Iteration 3335, loss = 0.09856025
# Iteration 3336, loss = 0.09854110
# Iteration 3337, loss = 0.09852199
# Iteration 3338, loss = 0.09850291
# Iteration 3339, loss = 0.09848386
# Iteration 3340, loss = 0.09846485
# Iteration 3341, loss = 0.09844588
# Iteration 3342, loss = 0.09842694
# Iteration 3343, loss = 0.09840803
# Iteration 3344, loss = 0.09838916
# Iteration 3345, loss = 0.09837032
# Iteration 3346, loss = 0.09835152
# Iteration 3347, loss = 0.09833275
# Iteration 3348, loss = 0.09831401
# Iteration 3349, loss = 0.09829531
# Iteration 3350, loss = 0.09827664
# Iteration 3351, loss = 0.09825801
# Iteration 3352, loss = 0.09823941
# Iteration 3353, loss = 0.09822084
# Iteration 3354, loss = 0.09820231
# Iteration 3355, loss = 0.09818381
# Iteration 3356, loss = 0.09816535
# Iteration 3357, loss = 0.09814691
# Iteration 3358, loss = 0.09812852
# Iteration 3359, loss = 0.09811015
# Iteration 3360, loss = 0.09809182
# Iteration 3361, loss = 0.09807353
# Iteration 3362, loss = 0.09805527
# Iteration 3363, loss = 0.09803704
# Iteration 3364, loss = 0.09801884
# Iteration 3365, loss = 0.09800068
# Iteration 3366, loss = 0.09798255
# Iteration 3367, loss = 0.09796445
# Iteration 3368, loss = 0.09794639
# Iteration 3369, loss = 0.09792836
# Iteration 3370, loss = 0.09791037
# Iteration 3371, loss = 0.09789241
# Iteration 3372, loss = 0.09787448
# Iteration 3373, loss = 0.09785658
# Iteration 3374, loss = 0.09783872
# Iteration 3375, loss = 0.09782089
# Iteration 3376, loss = 0.09780309
# Iteration 3377, loss = 0.09778533
# Iteration 3378, loss = 0.09776759
# Iteration 3379, loss = 0.09774990
# Iteration 3380, loss = 0.09773223
# Iteration 3381, loss = 0.09771460
# Iteration 3382, loss = 0.09769700
# Iteration 3383, loss = 0.09767943
# Iteration 3384, loss = 0.09766190
# Iteration 3385, loss = 0.09764440
# Iteration 3386, loss = 0.09762693
# Iteration 3387, loss = 0.09760949
# Iteration 3388, loss = 0.09759209
# Iteration 3389, loss = 0.09757472
# Iteration 3390, loss = 0.09755738
# Iteration 3391, loss = 0.09754007
# Iteration 3392, loss = 0.09752280
# Iteration 3393, loss = 0.09750556
# Iteration 3394, loss = 0.09748835
# Iteration 3395, loss = 0.09747117
# Iteration 3396, loss = 0.09745403
# Iteration 3397, loss = 0.09743692
# Iteration 3398, loss = 0.09741984
# Iteration 3399, loss = 0.09740279
# Iteration 3400, loss = 0.09738577
# Iteration 3401, loss = 0.09736879
# Iteration 3402, loss = 0.09735184
# Iteration 3403, loss = 0.09733492
# Iteration 3404, loss = 0.09731803
# Iteration 3405, loss = 0.09730117
# Iteration 3406, loss = 0.09728435
# Iteration 3407, loss = 0.09726756
# Iteration 3408, loss = 0.09725080
# Iteration 3409, loss = 0.09723407
# Iteration 3410, loss = 0.09721737
# Iteration 3411, loss = 0.09720071
# Iteration 3412, loss = 0.09718407
# Iteration 3413, loss = 0.09716747
# Iteration 3414, loss = 0.09715090
# Iteration 3415, loss = 0.09713436
# Iteration 3416, loss = 0.09711786
# Iteration 3417, loss = 0.09710138
# Iteration 3418, loss = 0.09708494
# Iteration 3419, loss = 0.09706852
# Iteration 3420, loss = 0.09705214
# Iteration 3421, loss = 0.09703579
# Iteration 3422, loss = 0.09701947
# Iteration 3423, loss = 0.09700319
# Iteration 3424, loss = 0.09698693
# Iteration 3425, loss = 0.09697071
# Iteration 3426, loss = 0.09695451
# Iteration 3427, loss = 0.09693835
# Iteration 3428, loss = 0.09692222
# Iteration 3429, loss = 0.09690612
# Iteration 3430, loss = 0.09689005
# Iteration 3431, loss = 0.09687401
# Iteration 3432, loss = 0.09685800
# Iteration 3433, loss = 0.09684202
# Iteration 3434, loss = 0.09682607
# Iteration 3435, loss = 0.09681016
# Iteration 3436, loss = 0.09679427
# Iteration 3437, loss = 0.09677842
# Iteration 3438, loss = 0.09676260
# Iteration 3439, loss = 0.09674680
# Iteration 3440, loss = 0.09673104
# Iteration 3441, loss = 0.09671531
# Iteration 3442, loss = 0.09669961
# Iteration 3443, loss = 0.09668394
# Iteration 3444, loss = 0.09666830
# Iteration 3445, loss = 0.09665269
# Iteration 3446, loss = 0.09663711
# Iteration 3447, loss = 0.09662156
# Iteration 3448, loss = 0.09660604
# Iteration 3449, loss = 0.09659055
# Iteration 3450, loss = 0.09657509
# Iteration 3451, loss = 0.09655967
# Iteration 3452, loss = 0.09654427
# Iteration 3453, loss = 0.09652890
# Iteration 3454, loss = 0.09651356
# Iteration 3455, loss = 0.09649825
# Iteration 3456, loss = 0.09648298
# Iteration 3457, loss = 0.09646773
# Iteration 3458, loss = 0.09645251
# Iteration 3459, loss = 0.09643732
# Iteration 3460, loss = 0.09642216
# Iteration 3461, loss = 0.09640704
# Iteration 3462, loss = 0.09639194
# Iteration 3463, loss = 0.09637687
# Iteration 3464, loss = 0.09636183
# Iteration 3465, loss = 0.09634682
# Iteration 3466, loss = 0.09633184
# Iteration 3467, loss = 0.09631689
# Iteration 3468, loss = 0.09630197
# Iteration 3469, loss = 0.09628708
# Iteration 3470, loss = 0.09627221
# Iteration 3471, loss = 0.09625738
# Iteration 3472, loss = 0.09624258
# Iteration 3473, loss = 0.09622780
# Iteration 3474, loss = 0.09621306
# Iteration 3475, loss = 0.09619834
# Iteration 3476, loss = 0.09618366
# Iteration 3477, loss = 0.09616900
# Iteration 3478, loss = 0.09615437
# Iteration 3479, loss = 0.09613978
# Iteration 3480, loss = 0.09612521
# Iteration 3481, loss = 0.09611067
# Iteration 3482, loss = 0.09609615
# Iteration 3483, loss = 0.09608167
# Iteration 3484, loss = 0.09606722
# Iteration 3485, loss = 0.09605279
# Iteration 3486, loss = 0.09603840
# Iteration 3487, loss = 0.09602403
# Iteration 3488, loss = 0.09600969
# Iteration 3489, loss = 0.09599538
# Iteration 3490, loss = 0.09598110
# Iteration 3491, loss = 0.09596685
# Iteration 3492, loss = 0.09595263
# Iteration 3493, loss = 0.09593843
# Iteration 3494, loss = 0.09592427
# Iteration 3495, loss = 0.09591013
# Iteration 3496, loss = 0.09589602
# Iteration 3497, loss = 0.09588194
# Iteration 3498, loss = 0.09586789
# Iteration 3499, loss = 0.09585386
# Iteration 3500, loss = 0.09583987
# Iteration 3501, loss = 0.09582590
# Iteration 3502, loss = 0.09581196
# Iteration 3503, loss = 0.09579805
# Iteration 3504, loss = 0.09578417
# Iteration 3505, loss = 0.09577031
# Iteration 3506, loss = 0.09575649
# Iteration 3507, loss = 0.09574269
# Iteration 3508, loss = 0.09572892
# Iteration 3509, loss = 0.09571517
# Iteration 3510, loss = 0.09570146
# Iteration 3511, loss = 0.09568777
# Iteration 3512, loss = 0.09567411
# Iteration 3513, loss = 0.09566048
# Iteration 3514, loss = 0.09564688
# Iteration 3515, loss = 0.09563331
# Iteration 3516, loss = 0.09561976
# Iteration 3517, loss = 0.09560624
# Iteration 3518, loss = 0.09559275
# Iteration 3519, loss = 0.09557928
# Iteration 3520, loss = 0.09556584
# Iteration 3521, loss = 0.09555244
# Iteration 3522, loss = 0.09553905
# Iteration 3523, loss = 0.09552570
# Iteration 3524, loss = 0.09551237
# Iteration 3525, loss = 0.09549907
# Iteration 3526, loss = 0.09548580
# Iteration 3527, loss = 0.09547255
# Iteration 3528, loss = 0.09545934
# Iteration 3529, loss = 0.09544615
# Iteration 3530, loss = 0.09543298
# Iteration 3531, loss = 0.09541985
# Iteration 3532, loss = 0.09540674
# Iteration 3533, loss = 0.09539366
# Iteration 3534, loss = 0.09538060
# Iteration 3535, loss = 0.09536757
# Iteration 3536, loss = 0.09535457
# Iteration 3537, loss = 0.09534160
# Iteration 3538, loss = 0.09532865
# Iteration 3539, loss = 0.09531573
# Iteration 3540, loss = 0.09530284
# Iteration 3541, loss = 0.09528997
# Iteration 3542, loss = 0.09527713
# Iteration 3543, loss = 0.09526432
# Iteration 3544, loss = 0.09525153
# Iteration 3545, loss = 0.09523877
# Iteration 3546, loss = 0.09522604
# Iteration 3547, loss = 0.09521333
# Iteration 3548, loss = 0.09520065
# Iteration 3549, loss = 0.09518800
# Iteration 3550, loss = 0.09517537
# Iteration 3551, loss = 0.09516277
# Iteration 3552, loss = 0.09515020
# Iteration 3553, loss = 0.09513765
# Iteration 3554, loss = 0.09512513
# Iteration 3555, loss = 0.09511263
# Iteration 3556, loss = 0.09510016
# Iteration 3557, loss = 0.09508772
# Iteration 3558, loss = 0.09507530
# Iteration 3559, loss = 0.09506291
# Iteration 3560, loss = 0.09505055
# Iteration 3561, loss = 0.09503821
# Iteration 3562, loss = 0.09502590
# Iteration 3563, loss = 0.09501361
# Iteration 3564, loss = 0.09500135
# Iteration 3565, loss = 0.09498911
# Iteration 3566, loss = 0.09497690
# Iteration 3567, loss = 0.09496472
# Iteration 3568, loss = 0.09495256
# Iteration 3569, loss = 0.09494043
# Iteration 3570, loss = 0.09492833
# Iteration 3571, loss = 0.09491625
# Iteration 3572, loss = 0.09490419
# Iteration 3573, loss = 0.09489216
# Iteration 3574, loss = 0.09488016
# Iteration 3575, loss = 0.09486818
# Iteration 3576, loss = 0.09485623
# Iteration 3577, loss = 0.09484430
# Iteration 3578, loss = 0.09483240
# Iteration 3579, loss = 0.09482053
# Iteration 3580, loss = 0.09480868
# Iteration 3581, loss = 0.09479685
# Iteration 3582, loss = 0.09478505
# Iteration 3583, loss = 0.09477327
# Iteration 3584, loss = 0.09476153
# Iteration 3585, loss = 0.09474980
# Iteration 3586, loss = 0.09473810
# Iteration 3587, loss = 0.09472643
# Iteration 3588, loss = 0.09471478
# Iteration 3589, loss = 0.09470315
# Iteration 3590, loss = 0.09469155
# Iteration 3591, loss = 0.09467998
# Iteration 3592, loss = 0.09466843
# Iteration 3593, loss = 0.09465691
# Iteration 3594, loss = 0.09464541
# Iteration 3595, loss = 0.09463393
# Iteration 3596, loss = 0.09462248
# Iteration 3597, loss = 0.09461106
# Iteration 3598, loss = 0.09459965
# Iteration 3599, loss = 0.09458828
# Iteration 3600, loss = 0.09457693
# Iteration 3601, loss = 0.09456560
# Iteration 3602, loss = 0.09455430
# Iteration 3603, loss = 0.09454302
# Iteration 3604, loss = 0.09453177
# Iteration 3605, loss = 0.09452054
# Iteration 3606, loss = 0.09450933
# Iteration 3607, loss = 0.09449815
# Iteration 3608, loss = 0.09448700
# Iteration 3609, loss = 0.09447586
# Iteration 3610, loss = 0.09446476
# Iteration 3611, loss = 0.09445367
# Iteration 3612, loss = 0.09444261
# Iteration 3613, loss = 0.09443158
# Iteration 3614, loss = 0.09442057
# Iteration 3615, loss = 0.09440958
# Iteration 3616, loss = 0.09439862
# Iteration 3617, loss = 0.09438768
# Iteration 3618, loss = 0.09437677
# Iteration 3619, loss = 0.09436588
# Iteration 3620, loss = 0.09435501
# Iteration 3621, loss = 0.09434417
# Iteration 3622, loss = 0.09433335
# Iteration 3623, loss = 0.09432255
# Iteration 3624, loss = 0.09431178
# Iteration 3625, loss = 0.09430103
# Iteration 3626, loss = 0.09429031
# Iteration 3627, loss = 0.09427960
# Iteration 3628, loss = 0.09426893
# Iteration 3629, loss = 0.09425827
# Iteration 3630, loss = 0.09424764
# Iteration 3631, loss = 0.09423704
# Iteration 3632, loss = 0.09422645
# Iteration 3633, loss = 0.09421589
# Iteration 3634, loss = 0.09420536
# Iteration 3635, loss = 0.09419484
# Iteration 3636, loss = 0.09418436
# Iteration 3637, loss = 0.09417389
# Iteration 3638, loss = 0.09416345
# Iteration 3639, loss = 0.09415303
# Iteration 3640, loss = 0.09414263
# Iteration 3641, loss = 0.09413225
# Iteration 3642, loss = 0.09412190
# Iteration 3643, loss = 0.09411158
# Iteration 3644, loss = 0.09410127
# Iteration 3645, loss = 0.09409099
# Iteration 3646, loss = 0.09408073
# Iteration 3647, loss = 0.09407050
# Iteration 3648, loss = 0.09406028
# Iteration 3649, loss = 0.09405009
# Iteration 3650, loss = 0.09403993
# Iteration 3651, loss = 0.09402978
# Iteration 3652, loss = 0.09401966
# Iteration 3653, loss = 0.09400956
# Iteration 3654, loss = 0.09399948
# Iteration 3655, loss = 0.09398943
# Iteration 3656, loss = 0.09397940
# Iteration 3657, loss = 0.09396939
# Iteration 3658, loss = 0.09395940
# Iteration 3659, loss = 0.09394944
# Iteration 3660, loss = 0.09393950
# Iteration 3661, loss = 0.09392958
# Iteration 3662, loss = 0.09391968
# Iteration 3663, loss = 0.09390981
# Iteration 3664, loss = 0.09389996
# Iteration 3665, loss = 0.09389013
# Iteration 3666, loss = 0.09388032
# Iteration 3667, loss = 0.09387054
# Iteration 3668, loss = 0.09386077
# Training loss did not improve more than tol=0.000010 for 10 consecutive epochs. Stopping.
# [0.28945459]
# [5.88713522]
# 0.724263617356077
